# %% [markdown]
# # LIAR DETECTION GROUP PROJECT - Baseline Models

# %% [markdown]
# ### CONTENTS
#
# Imports
# Load ISOT data
# Pre-process ISOT data
# Train/Dev/Test split ISOT data
#
# ##### Baselines (Naive Bayes):
# - ISOT full "text" field  (using CountVectorizer)
# - Verification test by assigning random 0's and 1's to the Dev Labels and re-running
# - Train with ISOT "text"; predict ISOT "title"
# - Read and setup LIAR dataset
# - Using the ISOT "text" model, predict the liar_dev_labels and score the predictions
# - Using the LIAR model, predict the ISOT "text" and score the predictions
# - ISOT "text" field using TfidfVectorizer
# - ISOT "text" field after removing "Reuters" and location from real news
# - ISOT "title" field; ; print top misclassifications between predicted dev classes and dev labels
# - Using the ISOT "title" model, predict the ISOT "text" classes
# - Using the ISOT "title" model, predict the liar_dev_labels and score the predictions; print top misclassifications
# - Using the LIAR model, predict the ISOT "title" and score the predictions
# - Divide LIAR data into train/dev/test, train a model, and see how well it predicts on its own data type

# %%
from __future__ import absolute_import
from __future__ import print_function
from __future__ import division

import json, os, re, shutil, sys, time
from importlib import reload
import collections, itertools
import unittest
from IPython.display import display, HTML
from sklearn.utils import shuffle
# NLTK for NLP utils and corpora
import nltk

# NumPy and TensorFlow
import numpy as np
import pandas as pd
#import tensorflow as tf

# Helper libraries
from w266_common import utils, vocabulary, tf_embed_viz
#from ark-tweet-nlp-0.3.2 import

# %%
#### MAY NEED TO RUN THIS CELL TWICE

def get_data(filename, sep=',', header=0, names = None):
    '''Read CSV file into a pandas dataframe'''
      
    filepath = DATAPATH + filename
    return pd.read_csv(filepath, header=header, sep=sep, quotechar='"')

# %%
##
# from sklearn.naive_bayes import BernoulliNB  #requires all features be binary
from sklearn.naive_bayes import MultinomialNB  #appropriate for word count features from CountVectorizer
# SK-learn libraries for feature extraction from text.
from sklearn.feature_extraction.text import *
#from sklearn.grid_search import GridSearchCV   # THIS HAS BEEN DEPRECATED
from sklearn.model_selection import GridSearchCV
# SK-learn libraries for evaluation.
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Load data
# Loading the "Fake News" dataset from the Information security and object technology (ISOT) Research lab at the University of Victoria School of Engineering.
#
# The ISOT Fake News Dataset is a compilation of several thousands fake news and truthful articles, obtained from different legitimate news sites and sites flagged as unreliable by politifact.com.

# %%
# define each downloaded file
FAKE_FILENAME = 'Fake.csv'
TRUE_FILENAME = 'True.csv'

# define the downloaded file path 
DATAPATH = './datasets/ISOT_FakeNews/'

def get_data(filename):
    '''Read CSV file into a pandas dataframe'''
      
    filepath = DATAPATH + filename
    return pd.read_csv(filepath, header=0, sep=',', quotechar='"')


fake_data = get_data(FAKE_FILENAME)
true_data = get_data(TRUE_FILENAME)



# add a label column to the data with the target values
fake_data.loc[:,'target'] = '0'
true_data['target'] = '1'

#append the datasets and shuffle them
all_data = true_data.append(fake_data, ignore_index=True)
all_data = all_data.sample(frac=1).reset_index(drop=True)

all_data.describe()
# Out:
#                                                     title   text  \
# count                                               44898  44898
# unique                                              38729  38646
# top     Factbox: Trump fills top jobs for his administ...
# freq                                                   14    627
#
#              subject                date target
# count          44898               44898  44898
# unique             8                2397      2
# top     politicsNews  December 20, 2017       0
# freq           11272                 182  23481

# %%
#fake_data.head(15)
#true_data.head(16)
all_data.head(15)
# Out:
#                                                 title  \
# 0   Labor Dept. looks into delaying fiduciary rule...
# 1   Senior Republicans signal issues in Congress f...
# 2   Nearly 30,000 Kurds displaced from city near K...
# 3    WTF: Top Trump Advisor Tells Trump To Kill Li...
# 4   EPIC RESPONSE AFTER THE BOSTON GLOBE Runs Fake...
# 5   In message to Russia, Western powers demand U....
# 6   GERMAN RESIDENTS FIGHT BACK: Anti-Islamic Song...
# 7           Passenger train derails in Spain, 21 hurt
# 8   JUDGE JEANINE IS FURIOUS! RINO’s Are Plotting ...
# 9   New judge assigned to U.S. lawsuit against AT&...
# 10  New rule requires U.S. banks to allow consumer...
# 11  BREAKING: DEATH FOR WELFARE LEECH AND BOSTON J...
# 12   Obama Shows Trump What A Classy Father’s Day ...
# 13  World Bank's Kim says Trump likes lender's pri...
# 14   Ted Cruz Continues To Market In Totally Full ...
#
#                                                  text       subject  \
# 0   WASHINGTON (Reuters) - The U.S. Labor Departme...  politicsNews
# 1   WASHINGTON (Reuters) - Representative Mac Thor...  politicsNews
# 2   BAGHDAD (Reuters) - Nearly 30,000 Kurds have b...     worldnews
# 3   As if Donald Trump isn t paranoid and delusion...          News
# 4   THE BOSTON GLOBE ran a Sunday edition with a f...      politics
# 5   PARIS (Reuters) - Major Western powers appeare...     worldnews
# 6   Apparently these Germans are not interested in...     left-news
# 7   MADRID (Reuters) - A passenger train derailed ...     worldnews
# 8   Fox News Channel s Jeanine Pirro went after th...      politics
# 9   WASHINGTON (Reuters) - The U.S. Department of ...  politicsNews
# 10  WASHINGTON (Reuters) - U.S. banks and credit c...  politicsNews
# 11  No mercy for welfare leech and America hater, ...      politics
# 12  Donald Trump has been consumed with a seething...          News
# 13  WASHINGTON (Reuters) - In an era of shrinking ...  politicsNews
# 14  Arguably the most popular myth in the Pantheon...          News
#
#                   date target
# 0    February 3, 2017       1
# 1        July 6, 2016       1
# 2    October 25, 2017       1
# 3        March 6, 2017      0
# 4         Apr 11, 2016      0
# 5    November 8, 2017       1
# 6          Jan 3, 2016      0
# 7   November 29, 2017       1
# 8         Jun 18, 2017      0
# 9   November 21, 2017       1
# 10      July 10, 2017       1
# 11        May 16, 2015      0
# 12       June 18, 2017      0
# 13     April 20, 2017       1
# 14    January 26, 2016      0

# %%
print(fake_data.title[0])
print('\n', fake_data.text[0])
print('\nTRUE DATA: ', true_data.text[3000])
# Out:
#  Donald Trump Sends Out Embarrassing New Year’s Eve Message; This is Disturbing
#
#  Donald Trump just couldn t wish all Americans a Happy New Year and leave it at that. Instead, he had to give a shout out to his enemies, haters and  the very dishonest fake news media.  The former reality show star had just one job to do and he couldn t do it. As our Country rapidly grows stronger and smarter, I want to wish all of my friends, supporters, enemies, haters, and even the very dishonest Fake News Media, a Happy and Healthy New Year,  President Angry Pants tweeted.  2018 will be a great year for America! As our Country rapidly grows stronger and smarter, I want to wish all of my friends, supporters, enemies, haters, and even the very dishonest Fake News Media, a Happy and Healthy New Year. 2018 will be a great year for America!  Donald J. Trump (@realDonaldTrump) December 31, 2017Trump s tweet went down about as welll as you d expect.What kind of president sends a New Year s greeting like this despicable, petty, infantile gibberish? Only Trump! His lack of decency won t even allow him to rise above the gutter long enough to wish the American citizens a happy new year!  Bishop Talbert Swan (@TalbertSwan) December 31, 2017no one likes you  Calvin (@calvinstowell) December 31, 2017Your impeachment would make 2018 a great year for America, but I ll also accept regaining control of Congress.  Miranda Yaver (@mirandayaver) December 31, 2017Do you hear yourself talk? When you have to include that many people that hate you you have to wonder? Why do the they all hate me?  Alan Sandoval (@AlanSandoval13) December 31, 2017Who uses the word Haters in a New Years wish??  Marlene (@marlene399) December 31, 2017You can t just say happy new year?  Koren pollitt (@Korencarpenter) December 31, 2017Here s Trump s New Year s Eve tweet from 2016.Happy New Year to all, including to my many enemies and those who have fought me and lost so badly they just don t know what to do. Love!  Donald J. Trump (@realDonaldTrump) December 31, 2016This is nothing new for Trump. He s been doing this for years.Trump has directed messages to his  enemies  and  haters  for New Year s, Easter, Thanksgiving, and the anniversary of 9/11. pic.twitter.com/4FPAe2KypA  Daniel Dale (@ddale8) December 31, 2017Trump s holiday tweets are clearly not presidential.How long did he work at Hallmark before becoming President?  Steven Goodine (@SGoodine) December 31, 2017He s always been like this . . . the only difference is that in the last few years, his filter has been breaking down.  Roy Schulze (@thbthttt) December 31, 2017Who, apart from a teenager uses the term haters?  Wendy (@WendyWhistles) December 31, 2017he s a fucking 5 year old  Who Knows (@rainyday80) December 31, 2017So, to all the people who voted for this a hole thinking he would change once he got into power, you were wrong! 70-year-old men don t change and now he s a year older.Photo by Andrew Burton/Getty Images.
#
# TRUE DATA:  WASHINGTON (Reuters) - Republicans and Democrats in Congress sparred on Tuesday over U.S. states setting rules for testing and deployment of self-driving cars and a proposal to allow automakers and technology companies to bypass existing regulations in introducing autonomous cars. Democrats on a U.S. House Energy and Commerce subcommittee said that the U.S. National Highway Traffic Safety Administration (NHTSA) must play a more aggressive role in mandating self-driving car safety. A Republican draft package of 14 bills would allow NHTSA to exempt up to 100,000 vehicles per year from federal motor vehicle safety rules, which currently prevent the sale of self-driving vehicles without human controls. It would also bar states from setting self-driving rules and prevent NHTSA from preapproving self-driving car technologies. “We simply cannot have cars that stop at state lines,”  Representative Robert Latta said at a hearing of the subcommittee. “This isn’t the government saying you have to get in a self-driving car. This is government make sure that industry can innovate.” Latta said he hoped to win committee approval of a bipartisan legislative package by the end of July. General Motors Co, Alphabet Inc, Tesla Inc and others have been lobbying Congress to pre-empt rules under consideration in California and other states that could limit self-driving vehicle deployment. Representative Frank Pallone, a Democrat, said that under the Republican proposal, states would be barred from regulating self-driving car safety “without a guarantee that NHTSA will step in” to set binding rules. “We need to be sure that we get this right and that safety is the first priority,” Pallone said. Democrats noted that the administration of President Donald Trump, a Republican, has not nominated a candidate to head NHTSA, which has a number of vacant senior positions. NHTSA did not sent an official to testify. Two automaker trade associations said in testimony it is essential they do not face a “patchwork” of self-driving state rules. They said NHTSA will have to approve exemptions. Republicans, citing competition from other countries and the rising number of traffic deaths, say it is urgent Congress approve sweeping legislation to ensure automakers and technology companies test the vehicles inside the United States.  The administration of former Democratic President Barack Obama last year unveiled voluntary guidelines on self-driving cars. Trump’s Transportation Secretary Elaine Chao has vowed to quickly update those.

# %% [markdown]
# ### Cleanup
# Check for NA values.
#
# May not want the dataset to contain the 'subject' since all the true news data comes from "Reuters"

# %%
all_data.isna().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# target     0
# dtype: int64

# %%
all_data.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 5 columns):
# title      44898 non-null object
# text       44898 non-null object
# subject    44898 non-null object
# date       44898 non-null object
# target     44898 non-null object
# dtypes: object(5)
# memory usage: 151.9 MB

# %% [markdown]
# ### Tokenize and Canonicalize Text
#
# Need to work on Tokenize and Canonicalizing text. Words like "Obama's" need to be corrected. Do we need to mark of sentences within a text? Might want to use some regex code from camron.

# %%
"""
Source:  https://gist.github.com/tokestermw/cb87a97113da12acb388
"""

FLAGS = re.MULTILINE | re.DOTALL

## hashtag code does not work, needs tweaking
def hashtag(text):
    text = text.group()
    hashtag_body = text[1:]
    if hashtag_body.isupper():
        result = " {} ".format(hashtag_body.lower())
    else:
        result = " ".join(["<hashtag>"] + re.split(r"(?=[A-Z])", hashtag_body, flags=FLAGS))
    return result

def allcaps(text):
    text = text.group()
    return text.lower() + " <allcaps>"


def tokenize(text):
    # Different regex parts for smiley faces
    eyes = r"[8:=;]"
    nose = r"['`\-]?"

    # function so code less repetitive
    def re_sub(pattern, repl):
        return re.sub(pattern, repl, text, flags=FLAGS)

    text = re_sub(r"https?:\/\/\S+\b|www\.(\w+\.)+\S*", "<url>")
    text = re_sub(r"@\w+", "<user>")
    text = re_sub(r"{}{}[)dD]+|[)dD]+{}{}".format(eyes, nose, nose, eyes), "<smile>")
    text = re_sub(r"{}{}p+".format(eyes, nose), "<lolface>")
    text = re_sub(r"{}{}\(+|\)+{}{}".format(eyes, nose, nose, eyes), "<sadface>")
    text = re_sub(r"{}{}[\/|l*]".format(eyes, nose), "<neutralface>")
    text = re_sub(r"/"," / ")
    text = re_sub(r"<3","<heart>")
    text = re_sub(r"[-+]?[.\d]*[\d]+[:,.\d]*", "<number>")
    #text = re_sub(r"#\S+", hashtag)
    text = re_sub(r"([!?.]){2,}", r"\1 <repeat>")
    text = re_sub(r"\b(\S*?)(.)\2{2,}\b", r"\1\2 <elong>")
    text = re_sub(r"([A-Z]){2,}", allcaps)

       
    output = text.lower().split()
    #output = list(itertools.chain(*[re.split(r'([^\w<>])', x) for x in output]))  #Splits punctuation, keeping < and >
    return [item for item in output if item != '']  #Removes blank strings from list

teststring = "My name is ABHI :). Learning the back-portion :(. Obama's nephew. @random. http://www.abc.com"
tokenize(teststring)
# Out:
# ['my',
#  'name',
#  'is',
#  'abhi',
#  '<allcaps>',
#  '<smile>.',
#  'learning',
#  'the',
#  'back-portion',
#  '<sadface>.',
#  "obama's",
#  'nephew.',
#  '<user>.',
#  '<url>']

# %%
def CNG_tokenizer(text):
    '''tokenizer, and part-of-speech tagger from Carnegie Mellon
    created by Olutobi Owoputi, Brendan O'Connor, Kevin Gimpel, Nathan Schneider, Chris Dyer, Dipanjan Das, Daniel Mills, 
    Jacob Eisenstein, Michael Heilman, Dani Yogatama, Jeffrey Flanigan, and Noah Smith
    RunTagger [options] [ExamplesFilename]
      runs the CMU ARK Twitter tagger on tweets from ExamplesFilename, 
      writing taggings to standard output. Listens on stdin if no input filename.

    Options:
      --model <Filename>        Specify model filename. (Else use built-in.)
      --just-tokenize           Only run the tokenizer; no POS tags.
      --quiet                   Quiet: no output
      --input-format <Format>   Default: auto
                                Options: json, text, conll
      --output-format <Format>  Default: automatically decide from input format.
                                Options: pretsv, conll
      --input-field NUM         Default: 1
                                Which tab-separated field contains the input
                                (1-indexed, like unix 'cut')
                                Only for {json, text} input formats.
      --word-clusters <File>    Alternate word clusters file (see FeatureExtractor)
      --no-confidence           Don't output confidence probabilities
      --decoder <Decoder>       Change the decoding algorithm (default: greedy)

    Tweet-per-line input formats:
       json: Every input line has a JSON object containing the tweet,
             as per the Streaming API. (The 'text' field is used.)
       text: Every input line has the text for one tweet.
    We actually assume input lines are TSV and the tweet data is one field.
    (Therefore tab characters are not allowed in tweets.
    Twitter's own JSON formats guarantee this;
    if you extract the text yourself, you must remove tabs and newlines.)
    Tweet-per-line output format is
       pretsv: Prepend the tokenization and tagging as new TSV fields, 
               so the output includes a complete copy of the input.
    By default, three TSV fields are prepended:
       Tokenization \t POSTags \t Confidences \t (original data...)
    The tokenization and tags are parallel space-separated lists.
    The 'conll' format is token-per-line, blank spaces separating tweets.'''

    file = open("teststring.txt", "w") 
    file.write(text) 
    file.close() 

#! ./ark-tweet-nlp-0.3.2/runTagger.sh ./ark-tweet-nlp-0.3.2/examples/example_tweets.txt
#! ./ark-tweet-nlp-0.3.2/twokenize.sh --output-format pretsv ./ark-tweet-nlp-0.3.2/examples/casual.txt
    tokens = ! ./ark-tweet-nlp-0.3.2/runTagger.sh --output-format conll teststring.txt
    tokens_list = list([re.split(r'([\t])',x) for x in tokens])
    tokens_list = [[ item for item in word if item != '\t' ] for word in tokens_list]
    
    #pandas frame for the tokens and POS
    
    pd_tokens = pd.DataFrame(tokens_list[1:-2], columns = ['word','tag','confidence'] )
    print(pd_tokens)
    word_list = [tokenize(word) for word in pd_tokens['word'].tolist()]
    
    word_tokens = ["".join(word) for word in word_list] #concats the allcaps text at the end of string
    pos_tokens = pd_tokens['tag'].tolist()
    conf_tokens = pd_tokens['confidence'].tolist()
    return word_tokens, pos_tokens, conf_tokens

# %%
CNG_tokenizer(teststring)
# Out:
#                   word tag confidence
# 0                   My   D     0.9984
# 1                 name   N     0.9996
# 2                   is   V     0.9953
# 3                 ABHI   ^     0.6305
# 4                   :)   E     0.9775
# 5                    .   ,     0.9951
# 6             Learning   V     0.9957
# 7                  the   D     0.9960
# 8         back-portion   N     0.8512
# 9                   :(   E     0.9162
# 10                   .   ,     0.9876
# 11             Obama's   Z     0.8890
# 12              nephew   N     0.9575
# 13                   .   ,     0.9980
# 14             @random   @     0.9945
# 15                   .   ,     0.9953
# 16  http://www.abc.com   U     0.9871
# (['my',
#   'name',
#   'is',
#   'abhi<allcaps>',
#   '<smile>',
#   '.',
#   'learning',
#   'the',
#   'back-portion',
#   '<sadface>',
#   '.',
#   "obama's",
#   'nephew',
#   '.',
#   '<user>',
#   '.',
#   '<url>'],
#  ['D',
#   'N',
#   'V',
#   '^',
#   'E',
#   ',',
#   'V',
#   'D',
#   'N',
#   'E',
#   ',',
#   'Z',
#   'N',
#   ',',
#   '@',
#   ',',
#   'U'],
#  ['0.9984',
#   '0.9996',
#   '0.9953',
#   '0.6305',
#   '0.9775',
#   '0.9951',
#   '0.9957',
#   '0.9960',
#   '0.8512',
#   '0.9162',
#   '0.9876',
#   '0.8890',
#   '0.9575',
#   '0.9980',
#   '0.9945',
#   '0.9953',
#   '0.9871'])

# %%
#Make new column with tokenized, canonicalized text
all_data['text_tokcan'] = all_data['text'].apply(tokenize)
all_data.tail(5)
# Out:
#                                                    title  \
# 44893   President Obama Says He Believes The Affordab...
# 44894   A Top Republican Really Just Blamed Obama For...
# 44895  LOL! MOTHER OF TWO Just Got A BIG SURPRISE Fro...
# 44896  FLASHBACK: KEY DEMOCRATS Call for Violence in ...
# 44897  DEPLORABLE! HILLARY’S Campaign Is In PANIC Mod...
#
#                                                     text          subject  \
# 44893  The president says he doesn t think Obamacare ...             News
# 44894  Rep. Steve King (R-IA) has been in the news co...             News
# 44895  The picture, snapped by a White House photogra...        left-news
# 44896  And we wonder why violence like today s shooti...  Government News
# 44897  What happens when Hillary s poll numbers take ...        left-news
#
#                   date target  \
# 44893  January 8, 2017      0
# 44894    June 15, 2017      0
# 44895      Nov 6, 2017      0
# 44896     Jun 14, 2017      0
# 44897     Sep 16, 2016      0
#
#                                              text_tokcan
# 44893  [the, president, says, he, doesn, t, think, ob...
# 44894  [rep., steve, king, (r-ia, <allcaps>), has, be...
# 44895  [the, picture,, snapped, by, a, white, house, ...
# 44896  [and, we, wonder, why, violence, like, today, ...
# 44897  [what, happens, when, hillary, s, poll, number...

# %%
#padded_sentences = ([u"<s>", u"<s>"] + s + [u"</s>"] for s in sents)

# %%
def build_vocab(corpus, V=None, **kw):
    if isinstance(corpus, list):
        token_feed = (utils.canonicalize_word(w) for w in corpus)
        vocab = vocabulary.Vocabulary(token_feed, size=V, **kw)
    print("Vocabulary: {:,} types".format(vocab.size))
    return vocab


#utils.canonicalize_word(teststring.split())
vocab=build_vocab(tokenize(teststring))
print("{:,} words".format(vocab.size))
print("wordset: ",vocab.ordered_words())
# Out:
# Vocabulary: 17 types
# 17 words
# wordset:  ['<s>', '</s>', '<unk>', 'my', 'name', 'is', 'abhi', '<allcaps>', '<smile>.', 'learning', 'the', 'back-portion', '<sadface>.', "obama's", 'nephew.', '<user>.', '<url>']

# %%
print('ISOT ALL target=real:', len(all_data.target[all_data.target == '1']))
print('ISOT ALL target=fake:', len(all_data.target[all_data.target == '0']))
# Out:
# ISOT ALL target=real: 21417
# ISOT ALL target=fake: 23481

# %% [markdown]
# ### Train / Dev / Test Split ISOT data

# %%
#train/dev/train split
#train_dev_split = 0.8

train_fract = 0.70
dev_fract = 0.15
test_fract = 0.15

if (train_fract+dev_fract+test_fract) == 1.0:
    print('Split fractions add up to 1.0')
else:
    print('SPLIT FRACTIONS DO NOT ADD UP TO 1.0; PLEASE TRY AGAIN.............')

#train_data = all_data[:int(len(all_data)*train_dev_split)].reset_index(drop=True)
#dev_data = all_data[int(len(all_data)*train_dev_split):].reset_index(drop=True)

train_set = all_data[ :int(len(all_data)*train_fract)].reset_index(drop=True)
dev_set = all_data[int(len(all_data)*(train_fract)) : int(len(all_data)*(train_fract+dev_fract))].reset_index(drop=True)
test_set = all_data[int(len(all_data)*(train_fract+dev_fract)) : ].reset_index(drop=True)

print('training set: ',train_set.shape)
print('dev set: ',dev_set.shape)
print('test set: ',test_set.shape)
# Out:
# Split fractions add up to 1.0
# training set:  (31428, 6)
# dev set:  (6735, 6)
# test set:  (6735, 6)

# %%
train_set.head(5)
# Out:
#                                                title  \
# 0  Labor Dept. looks into delaying fiduciary rule...
# 1  Senior Republicans signal issues in Congress f...
# 2  Nearly 30,000 Kurds displaced from city near K...
# 3   WTF: Top Trump Advisor Tells Trump To Kill Li...
# 4  EPIC RESPONSE AFTER THE BOSTON GLOBE Runs Fake...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The U.S. Labor Departme...  politicsNews
# 1  WASHINGTON (Reuters) - Representative Mac Thor...  politicsNews
# 2  BAGHDAD (Reuters) - Nearly 30,000 Kurds have b...     worldnews
# 3  As if Donald Trump isn t paranoid and delusion...          News
# 4  THE BOSTON GLOBE ran a Sunday edition with a f...      politics
#
#                 date target                                        text_tokcan
# 0  February 3, 2017       1  [washington, <allcaps>, (reuters), -, the, u.s...
# 1      July 6, 2016       1  [washington, <allcaps>, (reuters), -, represen...
# 2  October 25, 2017       1  [baghdad, <allcaps>, (reuters), -, nearly, <nu...
# 3      March 6, 2017      0  [as, if, donald, trump, isn, t, paranoid, and,...
# 4       Apr 11, 2016      0  [the, <allcaps>, boston, <allcaps>, globe, <al...

# %%
dev_set.head(5)
# Out:
#                                                title  \
# 0  Kurds abandon territory in the face of Iraq go...
# 1  Trump meets with U.S. community bankers, pledg...
# 2  ‘IT’S ALL ABOUT THE KIDS’…JUST ASK THE UNIONS:...
# 3  Instant View: Comey accuses Trump administrati...
# 4                  There’s Something Hokey About Ted
#
#                                                 text       subject  \
# 0  BAGHDAD/KIRKUK (Reuters) - The Baghdad governm...     worldnews
# 1  WASHINGTON (Reuters) - President Donald Trump ...  politicsNews
# 2  If the Chicago Public Schools were a business ...     left-news
# 3  (Reuters) - Former FBI Director James Comey on...  politicsNews
# 4  21st Century Wire says At some point, the poli...   Middle-east
#
#                 date target                                        text_tokcan
# 0  October 17, 2017       1  [baghdad, <allcaps>, /, kirkuk, <allcaps>, (re...
# 1     March 9, 2017       1  [washington, <allcaps>, (reuters), -, presiden...
# 2        Jul 3, 2015      0  [if, the, chicago, public, schools, were, a, b...
# 3      June 8, 2017       1  [(reuters), -, former, fbi, <allcaps>, directo...
# 4     March 21, 2016      0  [<number>st, century, wire, says, at, some, po...

# %%
# print out ISOT dev set
#dev_set.to_csv('isot_dev_set.csv', sep=',')

# %%
test_set.head(5)
# Out:
#                                                title  \
# 0  Trump 'not thrilled' with debate dates, Clinto...
# 1   Trump Just Had A Massive MELTDOWN Over Sally ...
# 2   Hackers Reveal Trump Linked The Most Powerful...
# 3   House Republicans Begin Process To Withdraw A...
# 4  VIDEO SURFACES OF DISGRACED Alleged Pedophile ...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - Republican candidate Do...  politicsNews
# 1  After former Acting Attorney General Sally Yat...          News
# 2  Donald Trump s administration is already provi...          News
# 3  Since 1945, the United States has been a cruci...          News
# 4  Earlier today, it was reported by TMZ that an ...     left-news
#
#                date target                                        text_tokcan
# 0    July 31, 2016       1  [washington, <allcaps>, (reuters), -, republic...
# 1       May 8, 2017      0  [after, former, acting, attorney, general, sal...
# 2  January 26, 2017      0  [donald, trump, s, administration, is, already...
# 3  January 22, 2017      0  [since, <number>, the, united, states, has, be...
# 4      Oct 30, 2017      0  [earlier, today,, it, was, reported, by, tmz, ...

# %% [markdown]
# ## Baseline Model: Naive Bayes Classifier

# %% [markdown]
# ### Classify full text

# %%
##
# from sklearn.naive_bayes import BernoulliNB  #requires all features be binary
from sklearn.naive_bayes import MultinomialNB  #appropriate for word count features from CountVectorizer
# SK-learn libraries for feature extraction from text.
from sklearn.feature_extraction.text import *
#from sklearn.grid_search import GridSearchCV   # THIS HAS BEEN DEPRECATED
from sklearn.model_selection import GridSearchCV
# SK-learn libraries for evaluation.
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score


train_data, train_labels = train_set.text.values, train_set.target.values
dev_data, dev_labels = dev_set.text.values, dev_set.target.values

train_labels = train_labels.astype(int)
dev_labels = dev_labels.astype(int)

print('train_data shape:', train_data.shape)
#print(train_data[0].shape)
#print(train_data[:1])
print('\ntrain_labels shape:', train_labels.shape)
print(train_labels)
print(type(train_labels[0]))
#train_labels.head()
#dev_data.head()
#dev_labels.head()
# Out:
# train_data shape: (31428,)
#
# train_labels shape: (31428,)
# [1 1 1 ... 0 1 0]
# <class 'numpy.int64'>

# %%
print('ISOT train target=real:', len(train_labels[train_labels == 1]))
print('ISOT train target=fake:', len(train_labels[train_labels == 0]))
# Out:
# ISOT train target=real: 15036
# ISOT train target=fake: 16392

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(train_data)
X
# Out:
# <31428x105902 sparse matrix of type '<class 'numpy.int64'>'
# 	with 6598223 stored elements in Compressed Sparse Row format>

# %%
#print(X[0])

# %%
print('X.shape:', X.shape) # (). There are x documents (rows) in the corpus, with y features (unique words = vocabulary)
print('Vocabulary size (number of features or columns):', X.shape[1])  # 
print('Non-zero elements in matrix (X.nnz):', X.nnz)   # This indicates that there are z non-zero elements in the matrix.
print('Average number of non-zero features per example (per document): %.3f' %(X.nnz/X.shape[0]))  # non-zero elements in matrix / documents = xxx
print('Fraction of non-zero elements in matrix: %.4f' %( X.nnz/(X.shape[0] * X.shape[1])) )   # Fraction of entries in the matrix that are non-zero = X.nnz/(rows*columns) = 0.xxx 


# What are the 0th and last feature strings (in alphabetical order)?
print('0th feature string:', vectorizer.get_feature_names()[0])   # 
print('last feature string:', vectorizer.get_feature_names()[X.shape[1]-1])    #
# Out:
# X.shape: (31428, 105902)
# Vocabulary size (number of features or columns): 105902
# Non-zero elements in matrix (X.nnz): 6598223
# Average number of non-zero features per example (per document): 209.947
# Fraction of non-zero elements in matrix: 0.0020
# 0th feature string: 00
# last feature string: zzzzzzzzzzzzz

# %%
# Using the standard CountVectorizer, what fraction of the words in the dev data are missing from the vocabulary? 
vectorizer_dev = CountVectorizer()
X_dev = vectorizer_dev.fit_transform(dev_data)  # Independently build a vocabulary using dev_data.
print('X_dev.shape:', X_dev.shape)
print('Vocabulary using train data:', X.shape[1])  # 
print('Vocabulary using dev data:', X_dev.shape[1])                # 

# Feed dev_data into the vectorizer fit using training data.
X_dev_transformed = vectorizer.transform(dev_data)
print('X_dev_transformed shape:', X_dev_transformed.shape)
#print('X_dev_transformed.shape', X_dev_transformed.shape)  # (676, 26,879)  EXPECT .shape[1] equal to original number of features
#print('non-zero indices in X_dev_transformed:', X_dev_transformed.nonzero())  # could also use this to check which features missing...

''' This is way too slow; use set intersection instead!!
# Look at each feature (vocabulary word) in X_dev and see if it is a feature in X.
count = 0
for i in range(X_dev.shape[1]):
    if vectorizer_dev.get_feature_names()[i] in vectorizer.get_feature_names():
        count += 1
print('Count of words (features) in X_dev also in X:', count)   
print('Fraction of words in dev data missing from training vocabulary: %.3f' %((X_dev.shape[1] - count)/X_dev.shape[1]) )
count of words (features) in X_dev also in X: 12219
Fraction of words in dev data missing from training vocabulary: 0.248
'''

set1 = set(vectorizer_dev.get_feature_names())
set2 = set(vectorizer.get_feature_names())
print('Count of words (features) in X_dev also in X:', len(set1.intersection(set2)))
print('Fraction of words in dev data missing from training vocabulary: %.3f' %((X_dev.shape[1] - len(set1.intersection(set2)))/X_dev.shape[1]) )
# Out:
# X_dev.shape: (6735, 53384)
# Vocabulary using train data: 105902
# Vocabulary using dev data: 53384
# X_dev_transformed shape: (6735, 105902)
# Count of words (features) in X_dev also in X: 44900
# Fraction of words in dev data missing from training vocabulary: 0.159

# %%
# MultinomialNB
print('\nMultinomialNB')
alpha = 1.0
clf = MultinomialNB(alpha=alpha)
clf.fit(X, train_labels)

print('accuracy: %3.2f' %clf.score(X_dev_transformed, dev_labels))
# Out:
# MultinomialNB
# accuracy: 0.95

# %%
print('accuracy: %3.2f' %clf.score(X_dev_transformed, dev_labels))

y_pred = clf.predict(X_dev_transformed)

acc = accuracy_score(dev_labels, y_pred)
print("Accuracy on dev set: {:.02%}".format(acc))
# Out:
# accuracy: 0.95
# Accuracy on dev set: 95.43%

# %%
print('predict proba:', clf.predict_proba(X).shape)
print('predict proba example:', clf.predict_proba(X[0]))
# Out:
# predict proba: (31428, 2)
# predict proba example: [[3.50355978e-15 1.00000000e+00]]

# %%
print('feature_log_prob_ shape:', clf.feature_log_prob_.shape)
print('feature_log_prob_ example:', clf.feature_log_prob_[0][0])
# Out:
# feature_log_prob_ shape: (2, 105902)
# feature_log_prob_ example: -9.682948061308743

# %%
feature_names = vectorizer.get_feature_names()
print(feature_names[:20])
# Out:
# ['00', '000', '0000', '00004', '000048', '00007', '00042', '0005', '0009', '000938', '000a', '000after', '000although', '000california', '000cases', '000cylvia', '000dillon000', '000ecuador', '000florida', '000georgia']

# %%
for i in range(2):   # 2 category labels
    for j in range(10):   # top 5 weights for each class
        index = -1 - j
        feature_index = np.argsort(clf.feature_log_prob_[i,:])[index]
        #print(feature_index, vectorizer.get_feature_names()[feature_index], clf.feature_log_prob_[0,feature_index], lr2.coef_[1,feature_index], lr2.coef_[2,feature_index], lr2.coef_[3,feature_index])
        print('%19s %12.3f %12.3f' %(vectorizer.get_feature_names()[feature_index], clf.feature_log_prob_[0,feature_index], clf.feature_log_prob_[1,feature_index]))
    print()
# Out:
#                 the       -2.899       -2.825
#                  to       -3.525       -3.502
#                  of       -3.729       -3.678
#                 and       -3.772       -3.796
#                  in       -4.052       -3.798
#                that       -4.176       -4.525
#                  is       -4.481       -4.986
#                 for       -4.664       -4.629
#                  it       -4.768       -5.102
#                  on       -4.777       -4.320
#
#                 the       -2.899       -2.825
#                  to       -3.525       -3.502
#                  of       -3.729       -3.678
#                 and       -3.772       -3.796
#                  in       -4.052       -3.798
#                  on       -4.777       -4.320
#                said       -5.678       -4.407
#                that       -4.176       -4.525
#                 for       -4.664       -4.629
#                  is       -4.481       -4.986

# %%
prob_diff = clf.feature_log_prob_[1] - clf.feature_log_prob_[0]

for j in range(50):   # top 5 weights for each class
    index = -1 - j
    feat_index = np.argsort(prob_diff[:])[index]
    print('%19s %12.3f %12.3f' %(vectorizer.get_feature_names()[feat_index], clf.feature_log_prob_[0,feat_index], clf.feature_log_prob_[1,feat_index]))
# Out:
#             myanmar      -15.056       -7.935
#            rohingya      -15.056       -8.238
#             rakhine      -15.749       -9.052
#          puigdemont      -15.749       -9.424
#                zuma      -15.749       -9.473
#                 suu      -15.749       -9.724
#                 kyi      -15.749       -9.724
#              odinga      -15.749       -9.865
#               rajoy      -15.749       -9.896
#                 fdp      -15.749       -9.906
#           kuczynski      -15.749       -9.913
#           mnangagwa      -15.749       -9.953
#                 anc      -15.749       -9.990
#             juncker      -15.749      -10.045
#              hariri      -14.650       -8.990
#              tmsnrt      -15.749      -10.115
#             barnier      -15.749      -10.164
#                aung      -15.749      -10.168
#              harare      -15.749      -10.259
#              marawi      -15.749      -10.305
#                kurz      -15.749      -10.342
#           ramaphosa      -15.749      -10.347
#             nairobi      -15.749      -10.358
#             barzani      -15.749      -10.375
#               babis      -15.749      -10.444
#                 fpo      -15.749      -10.450
#              xinhua      -15.749      -10.487
#                 kem      -15.749      -10.493
#               koike      -15.749      -10.493
#               sokha      -15.749      -10.499
#                 pis      -15.749      -10.578
#           odebrecht      -15.749      -10.599
#            nasralla      -15.749      -10.606
#                 ldp      -15.749      -10.606
#                farc      -15.749      -10.620
#              carles      -15.749      -10.635
#               najib      -15.749      -10.649
#              yangon      -15.749      -10.657
#            kenyatta      -15.056       -9.971
#               gulen      -15.056       -9.971
#                kiir      -15.749      -10.702
#               asean      -15.749      -10.710
#            fujimori      -15.749      -10.835
#                cnrp      -15.749      -10.844
#                 spd      -14.363       -9.464
#             dlamini      -15.749      -10.852
#               bazar      -15.749      -10.862
#        johannesburg      -15.749      -10.908
#                 dup      -15.749      -10.918
#            yingluck      -15.749      -10.927

# %%
print('clf.feature_count_ :', clf.feature_count_.shape)

for i in range(2):   # 2 category labels
    print('\nMOST COMMON WORDS IN CLASS', i, '(Fake=0; Real=1)')
    print('%19s %12s %12s' %('WORD', 'Fake count', 'Real count'))
    for j in range(100):   # top x most frequent words for each class
        index = -1 - j
        feature_index = np.argsort(clf.feature_count_[i,:])[index]
        print('%19s %12d %12d' %(vectorizer.get_feature_names()[feature_index], clf.feature_count_[0,feature_index], clf.feature_count_[1,feature_index]))
    print()
    
    
#print('Real_News clf.feature_count_ :', np.sort(clf.feature_count_[1,:]))
#print('Real_News clf.feature_count indices :', np.argsort(clf.feature_count_[1,:]))
##print('Real_News clf.feature_count words :', vectorizer.get_feature_names()[np.argsort(clf.feature_count_[1,:])])
print()
#print('Fake_News clf.feature_count_ :', clf.feature_count_[0,:])
# Out:
# clf.feature_count_ : (2, 105902)
#
# MOST COMMON WORDS IN CLASS 0 (Fake=0; Real=1)
#                WORD   Fake count   Real count
#                 the       380761       339942
#                  to       203640       172797
#                  of       166010       144867
#                 and       159092       128832
#                  in       120166       128519
#                that       106220        62130
#                  is        78301        39178
#                 for        65180        56000
#                  it        58738        34888
#                  on        58221        76259
#               trump        55622        38572
#                  he        55511        38373
#                 was        47281        34043
#                with        44306        38196
#                 his        41016        27148
#                this        40484        14904
#                  as        40460        33368
#                  be        34351        24049
#                  by        33450        33830
#                 are        32542        18375
#                have        32263        25728
#                 not        31853        25370
#                they        31845        15647
#                  at        29813        23318
#                 has        29787        32656
#                 who        29669        19544
#                 you        28899         4066
#                from        28896        27936
#                  we        27340        15447
#                  an        24568        22948
#                 but        23959        18741
#                said        23652        69894
#               about        23204        12185
#               their        21261        11964
#           president        19479        19857
#              people        18581        10729
#                 she        18428         8484
#                 her        18340         7407
#                 all        18094         6612
#                what        17737         5908
#                  or        17537        10664
#                 one        17127         9448
#                will        16897        17734
#                 out        16517         7617
#               would        16418        22157
#                  if        16319         8764
#                been        16255        13708
#                more        15931        12117
#                when        15500         7451
#                were        15158        13385
#                  so        15106         4839
#                just        14451         3176
#                 had        14226        18166
#               there        14197         8183
#                 our        13713         5452
#                  up        13628         8250
#             clinton        13438         6763
#                 can        13401         5683
#                  no        13248         7791
#               obama        13125         6713
#                like        12701         3260
#                 him        12574         5711
#              donald        12434         7373
#               after        12429        13773
#               which        12210        14613
#                  do        11077         4679
#             because        10975         4351
#                also        10787        11145
#                news        10363         4259
#                  us        10241         1769
#                them        10211         5261
#                over        10091         9818
#                 now        10067         4507
#                 new        10046        11885
#                 how         9890         3465
#                even         9874         2736
#             hillary         9777         1929
#                time         9708         5295
#                than         9557         8037
#               other         9468         8190
#                into         9456         6845
#               white         9417         6788
#               state         9323        14748
#                only         9045         4299
#                 via         8949          349
#               being         8650         3698
#                here         8583         1214
#                  re         8432         3122
#                some         8379         8938
#               media         8238         3126
#             twitter         8166         1807
#                 any         8054         6469
#            american         7912         3489
#               house         7875        11604
#               these         7820         2142
#             against         7781         7723
#             america         7778         1762
#            campaign         7671         7633
#                 get         7605         2863
#              should         7599         4547
#
#
# MOST COMMON WORDS IN CLASS 1 (Fake=0; Real=1)
#                WORD   Fake count   Real count
#                 the       380761       339942
#                  to       203640       172797
#                  of       166010       144867
#                 and       159092       128832
#                  in       120166       128519
#                  on        58221        76259
#                said        23652        69894
#                that       106220        62130
#                 for        65180        56000
#                  is        78301        39178
#               trump        55622        38572
#                  he        55511        38373
#                with        44306        38196
#                  it        58738        34888
#                 was        47281        34043
#                  by        33450        33830
#                  as        40460        33368
#                 has        29787        32656
#                from        28896        27936
#                 his        41016        27148
#                have        32263        25728
#                 not        31853        25370
#                  be        34351        24049
#                  at        29813        23318
#                  an        24568        22948
#               would        16418        22157
#             reuters          322        20376
#           president        19479        19857
#                 who        29669        19544
#                 but        23959        18741
#                 are        32542        18375
#                 had        14226        18166
#                will        16897        17734
#                they        31845        15647
#                  we        27340        15447
#                 its         6793        15022
#                this        40484        14904
#               state         9323        14748
#               which        12210        14613
#               after        12429        13773
#                been        16255        13708
#                were        15158        13385
#          government         6480        13305
#               about        23204        12185
#                more        15931        12117
#               their        21261        11964
#                 new        10046        11885
#              states         7091        11795
#               house         7875        11604
#          republican         6445        11551
#                also        10787        11145
#              united         5572        11067
#              people        18581        10729
#                  or        17537        10664
#                year         7130        10481
#                told         6352        10030
#                over        10091         9818
#               could         7150         9637
#                 one        17127         9448
#          washington         3994         9151
#               party         5441         9054
#                last         5701         9003
#                some         8379         8938
#                 two         6405         8885
#                  if        16319         8764
#            election         6199         8688
#                 she        18428         8484
#                  up        13628         8250
#               other         9468         8190
#               there        14197         8183
#                than         9557         8037
#                  no        13248         7791
#             against         7781         7723
#            campaign         7671         7633
#                 out        16517         7617
#                when        15500         7451
#              former         5076         7431
#                 her        18340         7407
#              donald        12434         7373
#            security         4145         7195
#               north         1856         7077
#             percent         2970         7065
#                into         9456         6845
#               court         3685         6802
#               white         9417         6788
#             clinton        13438         6763
#               obama        13125         6713
#                 all        18094         6612
#              senate         2564         6559
#                 any         8054         6469
#             country         6454         6364
#               first         7454         6135
#               china          891         6124
#            minister          694         6082
#           officials         2695         6035
#                week         3432         5930
#          democratic         3360         5920
#                what        17737         5908
#      administration         4041         5866
#               since         4414         5856

# %% [markdown]
# #### Use TfidfVectorizer and compare to CountVectorizer

# %%
'''
Convert a collection of raw documents to a matrix of TF-IDF features.
Equivalent to CountVectorizer followed by TfidfTransformer.

In a large text corpus, some words will be very present (e.g. “the”, “a”, “is” in English) hence carrying very little 
meaningful information about the actual contents of the document. If we were to feed the direct count data directly to 
a classifier those very frequent terms would shadow the frequencies of rarer yet more interesting terms.

In order to re-weight the count features into floating point values suitable for usage by a classifier it is very 
common to use the tf–idf transform.

Tf means term-frequency while tf–idf means term-frequency times inverse document-frequency: 
\text{tf-idf(t,d)}=\text{tf(t,d)} \times \text{idf(t)}.
'''

t_vectorizer = TfidfVectorizer()
t_X = t_vectorizer.fit_transform(train_data)   
#print(t_X.shape)
t_X_dev = t_vectorizer.transform(dev_data)
#print(t_X_dev.shape)


# MultinomialNB
#The multinomial distribution normally requires integer feature counts. 
#However, in practice, fractional counts such as tf-idf may also work.
print('\nMultinomialNB with TfidfVectorizer')
alpha = 1.0
t_clf = MultinomialNB(alpha=alpha)
t_clf.fit(t_X, train_labels)

print('accuracy: %3.3f' %t_clf.score(t_X_dev, dev_labels))

t_dev_predicted_labels = t_clf.predict(t_X_dev)  # "predict" and report accuracy using dev set
#print(t_dev_predicted_labels.shape)

print('\nf1 score of dev predicted labels:', metrics.f1_score(dev_labels, t_dev_predicted_labels, average='weighted'))
print('classification report of dev predicted labels: \n', classification_report(dev_labels, t_dev_predicted_labels))
print()
# Out:
# MultinomialNB with TfidfVectorizer
# accuracy: 0.938
#
# f1 score of dev predicted labels: 0.9382177743796193
# classification report of dev predicted labels:
#                precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94      3527
#            1       0.94      0.93      0.93      3208
#
#    micro avg       0.94      0.94      0.94      6735
#    macro avg       0.94      0.94      0.94      6735
# weighted avg       0.94      0.94      0.94      6735

# %% [markdown]
# #### DO verification test by assigning random 0's and 1's to the Dev Labels and re-running.

# %%
sample = np.random.binomial(1, 0.5, size=dev_labels.shape[0])
print(sample.mean())
# Out:
# 0.5020044543429845

# %%
print('accuracy: %3.4f' %clf.score(X_dev_transformed, sample))
# Out:
# accuracy: 0.4953

# %%
sample2 = np.random.binomial(1, 0.2, size=dev_labels.shape[0])
print(sample2.mean())
# Out:
# 0.19510022271714922

# %%
print('accuracy: %3.4f' %clf.score(X_dev_transformed, sample2))
# Out:
# accuracy: 0.5145

# %% [markdown]
# #### This result is as expected; basically get random model predictions of ~ 50% once we randomize the dev lables in any fashion.

# %% [markdown]
# ### Train with ISOT "text"; predict ISOT "title"

# %%
train_data, train_labels = train_set.text.str.lower().values, train_set.target.values
dev_data, dev_labels = dev_set.title.str.lower().values, dev_set.target.values

train_labels = train_labels.astype(int)
dev_labels = dev_labels.astype(int)

#train_data.head()
print('train_data shape:', train_data.shape)
#print(train_data[0].shape)
print(train_data[:1])
print('\ntrain_labels shape:', train_labels.shape)
print(train_labels)

print('dev_data shape:', dev_data.shape)
# Out:
# train_data shape: (31428,)
# ['washington (reuters) - the u.s. labor department is looking into delaying the implementation date of its new fiduciary rule governing the advice that brokers can give about retirement investments, it said on friday, after president donald trump called for a review that could ultimately lead to scrapping it. “the department of labor will now consider its legal options to delay the applicability of the date as we comply with the president’s memorandum,” acting u.s. secretary of labor ed hugler said in a statement. ']
#
# train_labels shape: (31428,)
# [1 1 1 ... 0 1 0]
# dev_data shape: (6735,)

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(train_data)
X_dev_transformed = vectorizer.transform(dev_data)

print('X.shape:', X.shape)
print('X_dev_transformed.shape:', X_dev_transformed.shape)

# MultinomialNB
print('\nMultinomialNB trained using ISOT "text" field; predict ISOT "title" classes')
alpha = 1.0
clf = MultinomialNB(alpha=alpha)
clf.fit(X, train_labels)

print('accuracy: %3.3f' %clf.score(X_dev_transformed, dev_labels))
# Out:
# X.shape: (31428, 105902)
# X_dev_transformed.shape: (6735, 105902)
#
# MultinomialNB trained using ISOT "text" field; predict ISOT "title" classes
# accuracy: 0.912

# %% [markdown]
# ### Apply model to LIAR dataset text to predict results and compute score ('title' field contains the statement).

# %%
#### MAY NEED TO RUN THIS CELL TWICE

def get_data(filename, sep=',', header=0, names = None):
    '''Read CSV file into a pandas dataframe'''
      
    filepath = DATAPATH + filename
    return pd.read_csv(filepath, header=header, sep=sep, quotechar='"')

# %%
# define each downloaded file
LIAR_TEST_FILENAME = 'test.tsv'
LIAR_TRAIN_FILENAME = 'train.tsv'
LIAR_DEV_FILENAME = 'valid.tsv'

# define the downloaded file path 
DATAPATH = './datasets/LIAR/'

## title =statement, target = politifact rating

h_names= ['id', 'target', 'title', 'subject', 'speaker', 'speaker_job_title', 'state', 'party',
          'barely_true_count', 'false_count', 'half_true_count', 'mostly_true_count','pantsonfire_count',
          'context']

liar_test_data = get_data(LIAR_TEST_FILENAME, sep ='\t', header =None)
liar_train_data = get_data(LIAR_TRAIN_FILENAME, '\t', header =None)
liar_dev_data = get_data(LIAR_DEV_FILENAME, '\t', header =None)
print("LIAR training dataset: ", liar_train_data.shape)
print("LIAR test dataset: ", liar_test_data.shape)
print("LIAR dev dataset: ", liar_dev_data.shape)

liar_test_data.columns = h_names
liar_train_data.columns = h_names
liar_dev_data.columns = h_names
# ## add a label column to the data with the target values
# #fake_data.loc[:,'target'] = '0'
# #true_data['target'] = '1'

# #append the datasets and shuffle them
# all_data = true_data.append(fake_data, ignore_index=True)
# all_data = all_data.sample(frac=1).reset_index(drop=True)

## NOTE: if trouble loading, re-run get_data function.
# Out:
# LIAR training dataset:  (10240, 14)
# LIAR test dataset:  (1267, 14)
# LIAR dev dataset:  (1284, 14)

# %%
# combine all the liar data
liar_data = liar_train_data.append(liar_test_data, ignore_index =True)
liar_data = liar_data.append(liar_dev_data, ignore_index =True)
liar_data = liar_data.sample(frac=1).reset_index(drop=True)
print("Complete LIAR dataset: ",liar_data.shape)
liar_data.head()
# Out:
# Complete LIAR dataset:  (12791, 14)
#            id      target                                              title  \
# 0   6193.json       false  (Environmentalists) said Were only going to st...
# 1  12371.json        true  For the first time in over 40 years, Republica...
# 2  12409.json        true  You can import as many hemp products into this...
# 3   1770.json        true  We can prevent terror suspects from boarding a...
# 4  10700.json  pants-fire  Says Ted Cruz said, There is no place for gays...
#
#                                              subject            speaker  \
# 0                                 energy,environment         ron-ramsey
# 1                                  elections,history       ed-gillespie
# 2                       drugs,legal-issues,marijuana  william-devereaux
# 3                        civil-rights,guns,terrorism  michael-bloomberg
# 4  candidates-biography,gays-and-lesbians,marriag...     facebook-posts
#
#                  speaker_job_title             state        party  \
# 0  Speaker of the Tennessee Senate         Tennessee   republican
# 1            Republican strategist  Washington, D.C.   republican
# 2                           lawyer      Rhode Island         none
# 3                              NaN          New York  independent
# 4             Social media posting               NaN         none
#
#    barely_true_count  false_count  half_true_count  mostly_true_count  \
# 0                0.0          2.0              0.0                0.0
# 1                2.0          3.0              2.0                2.0
# 2                0.0          0.0              0.0                0.0
# 3                0.0          2.0              2.0                3.0
# 4               14.0         18.0             15.0               11.0
#
#    pantsonfire_count                 context
# 0                1.0   rally for coal miners
# 1                1.0                a speech
# 2                0.0  a legislative hearing
# 3                0.0        an op ed article
# 4               36.0          an online meme

# %%
print(liar_data.title[4])
print(liar_data.target.unique())
# Out:
# Says Ted Cruz said, There is no place for gays or atheists in my America. None. Our Constitution makes that clear.
# ['false' 'true' 'pants-fire' 'half-true' 'barely-true' 'mostly-true']

# %%
targets = liar_data.target.unique()
print(targets)

print('target,  number of examples')
for target in targets:
    print(target, len(liar_data[liar_data.target==target]))
    
print('\ntotal examples', len(liar_data))
# Out:
# ['false' 'true' 'pants-fire' 'half-true' 'barely-true' 'mostly-true']
# target,  number of examples
# false 2507
# true 2053
# pants-fire 1047
# half-true 2627
# barely-true 2103
# mostly-true 2454
#
# total examples 12791

# %%
liar_data['binary_target'] = -1

'''  # this does not work
for i in range(liar_data.shape[0]):   
    if liar_data.target.iloc[i] == ('pants-fire' or 'false' or 'barely-true') :
        liar_data.binary_target.iloc[i] = 0  # fake news
    elif liar_data.target.iloc[i] == ('true' or 'mostly-true'):
        liar_data.binary_target.iloc[i] = 1  # real news
'''

''' these do not work
#liar_data.binary_target[((liar_data.target=='pants-fire') | (liar_data.target=='false') | (liar_data.target=='barely-true')] = 0
#liar_data['binary_target'] = np.where( ( (liar_data.target=='pants-fire') | (liar_data.target=='false') | (liar_data.target=='barely-true')] = 0                                        
## example:df['points'] = np.where( ( (df['gender'] == 'male') & (df['pet1'] == df['pet2'] ) ) | ( (df['gender'] == 'female') & (df['pet1'].isin(['cat','dog'] ) ) ), 5, 0)
#liar_data['binary_target'] = np.where( (liar_data.target.isin (['pants-fire','false','barely-true']), 0,1))
'''

# This might work better!
#'''
def binary_seq_target(rating):
    ## if no rating provided assume the statement to be true
    map_r = {'pants-fire':0, 'false':0, 'barely-true':0, 'half-true':-1, 'mostly-true':1, 'true':1}
    return map_r.get(rating, 1)
    
##change the target labels to 0(false), 1(true news)
#liar_data2.loc[:,'target'] = pd.Series(liar_data2['target'].apply(seq_target), index = liar_data2.index)
liar_data.loc[:,'binary_target'] = pd.Series(liar_data['target'].apply(binary_seq_target), index = liar_data.index)
liar_data.head(10)    
#'''

'''
# these give a warning: 'A value is trying to be set on a copy of a slice from a DataFrame'
liar_data.binary_target[liar_data.target=='pants-fire'] = 0  # fake news
liar_data.binary_target[liar_data.target=='false'] = 0
liar_data.binary_target[liar_data.target=='barely-true'] = 0
liar_data.binary_target[liar_data.target=='true'] = 1        # real news
liar_data.binary_target[liar_data.target=='mostly-true'] = 1
'''

liar_data.head(10)
# Out:
#            id       target                                              title  \
# 0   6193.json        false  (Environmentalists) said Were only going to st...
# 1  12371.json         true  For the first time in over 40 years, Republica...
# 2  12409.json         true  You can import as many hemp products into this...
# 3   1770.json         true  We can prevent terror suspects from boarding a...
# 4  10700.json   pants-fire  Says Ted Cruz said, There is no place for gays...
# 5   1330.json        false  In the House health care bill, "Something like...
# 6   5727.json    half-true  Says oil productions down where Obamas in charge.
# 7   1717.json  barely-true  Obama did not open new lands to offshore drill...
# 8   4102.json    half-true  Numerous studies have shown that these so-call...
# 9  11629.json  mostly-true  In 2008, Maggie Hassan voted against legislati...
#
#                                              subject  \
# 0                                 energy,environment
# 1                                  elections,history
# 2                       drugs,legal-issues,marijuana
# 3                        civil-rights,guns,terrorism
# 4  candidates-biography,gays-and-lesbians,marriag...
# 5                                        health-care
# 6  corrections-and-updates,energy,message-machine...
# 7  economy,energy,environment,florida,transportation
# 8                                        jobs,unions
# 9                          immigration,voting-record
#
#                                          speaker  \
# 0                                     ron-ramsey
# 1                                   ed-gillespie
# 2                              william-devereaux
# 3                              michael-bloomberg
# 4                                 facebook-posts
# 5                                      ron-wyden
# 6                                 crossroads-gps
# 7  house-natural-resources-committee-republicans
# 8                                  sheila-oliver
# 9                                  jennifer-horn
#
#                           speaker_job_title             state        party  \
# 0           Speaker of the Tennessee Senate         Tennessee   republican
# 1                     Republican strategist  Washington, D.C.   republican
# 2                                    lawyer      Rhode Island         none
# 3                                       NaN          New York  independent
# 4                      Social media posting               NaN         none
# 5                              U.S. Senator            Oregon     democrat
# 6               Conservative advocacy group               NaN   republican
# 7                                       NaN               NaN   republican
# 8                             Assemblywoman        New Jersey     democrat
# 9  Chairman, New Hampshire Republican Party     New Hampshire   republican
#
#    barely_true_count  false_count  half_true_count  mostly_true_count  \
# 0                0.0          2.0              0.0                0.0
# 1                2.0          3.0              2.0                2.0
# 2                0.0          0.0              0.0                0.0
# 3                0.0          2.0              2.0                3.0
# 4               14.0         18.0             15.0               11.0
# 5                0.0          1.0              0.0                3.0
# 6                9.0          1.0              4.0                1.0
# 7                1.0          0.0              0.0                0.0
# 8                0.0          1.0              1.0                3.0
# 9                2.0          0.0              1.0                1.0
#
#    pantsonfire_count                                            context  \
# 0                1.0                              rally for coal miners
# 1                1.0                                           a speech
# 2                0.0                             a legislative hearing
# 3                0.0                                   an op ed article
# 4               36.0                                     an online meme
# 5                0.0       MSNBC's 'Morning Meeting With Dylan Ratigan'
# 6                2.0                                           a Web ad
# 7                0.0              a news release posted on his website.
# 8                0.0  a press release from Assembly Speaker Sheila O...
# 9                0.0                                             a memo
#
#    binary_target
# 0              0
# 1              1
# 2              1
# 3              1
# 4              0
# 5              0
# 6             -1
# 7              0
# 8             -1
# 9              1

# %%
binary_targets = liar_data.binary_target.unique()
print(binary_targets)

print('\nbinary_target,  number of examples')
for binary_target in binary_targets:
    print(binary_target, len(liar_data[liar_data.binary_target==binary_target]))
# Out:
# [ 0  1 -1]
#
# binary_target,  number of examples
# 0 5657
# 1 4507
# -1 2627

# %% [markdown]
# #### Must discard label = -1

# %%
liar_dev_labels = liar_data.binary_target[liar_data.binary_target >= 0].values  ## discard "half-true"!!!!
print('liar_dev_labels:\n', liar_dev_labels[:10])
# Out:
# liar_dev_labels:
#  [0 1 1 1 0 0 0 1 0 0]

# %%
print(liar_data.title)
# Out:
# 0        (Environmentalists) said Were only going to st...
# 1        For the first time in over 40 years, Republica...
# 2        You can import as many hemp products into this...
# 3        We can prevent terror suspects from boarding a...
# 4        Says Ted Cruz said, There is no place for gays...
# 5        In the House health care bill, "Something like...
# 6        Says oil productions down where Obamas in charge.
# 7        Obama did not open new lands to offshore drill...
# 8        Numerous studies have shown that these so-call...
# 9        In 2008, Maggie Hassan voted against legislati...
# 10       Hispanic students in Florida perform the best ...
# 11       Says Milwaukee County Executive Chris Abele el...
# 12       Limiting labor negotiations to only wages is h...
# 13       The governor must inform the Senate president ...
# 14       Says he was known as Veto Corleone for cutting...
# 15       Compact fluorescent light bulbs are toxic and ...
# 16       Sen. Joe Biden, the ranking member of the Fore...
# 17       Schools in some states are spending up to 100 ...
# 18       An 11-year-old girl was investigated by the FB...
# 19       You dont have to be as smart as a fifth-grader...
# 20       Atlanta Public Schools 2011 CRCT tests were gi...
# 21       Says Ron Johnson is benefiting from several su...
# 22       If you dont buy cigarettes at your local super...
# 23       Says Romney wants to take away early childhood...
# 24       McCain "said the other day that he would not m...
# 25       The loan guarantee program that helped Solyndr...
# 26       He voted twice for a budget resolution that in...
# 27       We havent had control of the House for the las...
# 28       After the 2001 and 2003 Bush tax rate cuts ......
# 29       Says Health and Human Services Secretary Kathl...
#                                ...
# 12761    Says unemployment would be at 10 percent if pe...
# 12762    The U.S. Senate has one manufacturer thatd be me.
# 12763    I supported tort reform with regard to securit...
# 12764    We have asked public employees to pay 10 perce...
# 12765    Says Mark Hass raised your taxes by $1 billion...
# 12766    25,000 businesses have been created since (Sco...
# 12767    Dozens of artists, including Justin Timberlake...
# 12768    As a prosecutor, Wisconsin Supreme Court Justi...
# 12769    The amount of interest paid on the federal deb...
# 12770    As a result of Obamacare, California seniors f...
# 12771    When George Bush said we shouldnt investigate ...
# 12772    Obamacarerepresents the largest tax increase i...
# 12773    Says he could be the first president in modern...
# 12774    More than half of our unemployed Ohioans have ...
# 12775    Were one of the only communities in the countr...
# 12776    Says President Abraham Lincoln enforced the Fu...
# 12777    Democrats already agreed to a deal that Republ...
# 12778    When Social Security started, age expectancy f...
# 12779    Says over 50 percent of U.S. job growth in Jun...
# 12780    Each Georgia taxpayer would have to send $5,00...
# 12781    Says Transportation Secretary Ray LaHood will ...
# 12782    The government made accommodation to the Fort ...
# 12783    The [Obama] administrations regulatory assault...
# 12784    Wisconsin is not walking away from a dime in f...
# 12785    A recent Gallup poll found that 72 percent of ...
# 12786    In the mid 1990s, in our state, (Florida was) ...
# 12787    Says Virginia saved $300 million by rebidding ...
# 12788    In every committee when the health care bill w...
# 12789    A foreclosure tax that would take effect in 20...
# 12790    Harry Reids plan is basically giving the presi...
# Name: title, Length: 12791, dtype: object

# %% [markdown]
# ### Using the ISOT "text" model, predict the liar_dev_labels and score the predictions. (lower case them first...)

# %%
train_data, train_labels = train_set.text.str.lower().values, train_set.target.values   # original ISOT data

#dev_data = liar_data.title[liar_data.binary_target != -1].values  
dev_data = liar_data.title[liar_data.binary_target != -1].str.lower().values      # LIAR data                                        # full LIAR data
dev_labels = liar_data.binary_target[liar_data.binary_target != -1].values

train_labels = train_labels.astype(int)
dev_labels = dev_labels.astype(int)

#train_data.head()
print('train_data shape:', train_data.shape)
#print(train_data[0].shape)
#print(train_data[:1])
print('train_labels shape:', train_labels.shape)
print(train_labels)

print('\ndev_data shape:', dev_data.shape)
print(dev_data[:1])
print('dev_labels shape:', dev_labels.shape)
print(dev_labels)
# Out:
# train_data shape: (31428,)
# train_labels shape: (31428,)
# [1 1 1 ... 0 1 0]
#
# dev_data shape: (10164,)
# ['(environmentalists) said were only going to stop coal mining above 2,000 feet. ... well guess where all the coal in the state of tennessee is? above 2,000 feet.']
# dev_labels shape: (10164,)
# [0 1 1 ... 1 1 0]

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(train_data)           # original ISOT training data
X_dev_transformed = vectorizer.transform(dev_data)

# MultinomialNB
print('\nMultinomialNB using "text" field: Fit using ISOT data; Predict on LIAR data:')
alpha = 1.0
clf = MultinomialNB(alpha=alpha)
clf.fit(X, train_labels)

print('accuracy: %3.3f' %clf.score(X_dev_transformed, dev_labels))
# Out:
# MultinomialNB using "text" field: Fit using ISOT data; Predict on LIAR data:
# accuracy: 0.541

# %%
print('Non-zero elements in matrix (X.nnz):', X.nnz)   # This indicates that there are z non-zero elements in the matrix.
print('Average number of non-zero features per example (per document): %.3f' %(X.nnz/X.shape[0]))  # non-zero elements in matrix / documents = xxx
# Out:
# Non-zero elements in matrix (X.nnz): 6598223
# Average number of non-zero features per example (per document): 209.947

# %%
print('Non-zero elements in matrix (X_dev_transformed.nnz):', X_dev_transformed.nnz)   # This indicates that there are z non-zero elements in the matrix.
print('Average number of non-zero features per example (per document): %.3f' %(X_dev_transformed.nnz/X_dev_transformed.shape[0]))  # non-zero elements in matrix / documents = xxx
# Out:
# Non-zero elements in matrix (X_dev_transformed.nnz): 161155
# Average number of non-zero features per example (per document): 15.855

# %%
print('LIAR true:', len(liar_data.binary_target[liar_data.binary_target == 1]))
#print('LIAR true:', liar_data.binary_target[liar_data.binary_target == 1].shape)
print('LIAR false:', len(liar_data.binary_target[liar_data.binary_target == 0]))
# Out:
# LIAR true: 4507
# LIAR false: 5657

# %% [markdown]
# ### REVERSE: Using LIAR model, predict the ISOT "text" and score the predictions. (lower case them first...)

# %%
train_data = liar_data.title[liar_data.binary_target != -1].str.lower().values   # full LIAR data
train_labels = liar_data.binary_target[liar_data.binary_target != -1].values 
 
dev_data = train_set.text.str.lower().values                                      # LSOT data
dev_labels = train_set.target.values 


train_labels = train_labels.astype(int)
dev_labels = dev_labels.astype(int)

#train_data.head()
print('train_data shape:', train_data.shape)
#print(train_data[0].shape)
#print(train_data[:1])
print('train_labels shape:', train_labels.shape)
print(train_labels)

print('\ndev_data shape:', dev_data.shape)
#print(dev_data[:1])
print('dev_labels shape:', dev_labels.shape)
print(dev_labels)
# Out:
# train_data shape: (10164,)
# train_labels shape: (10164,)
# [1 0 0 ... 1 0 0]
#
# dev_data shape: (31428,)
# dev_labels shape: (31428,)
# [1 0 1 ... 0 1 0]

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(train_data)           # LIAR training data
print(X.shape)
X_dev_transformed = vectorizer.transform(dev_data) # LSOT

# MultinomialNB
print('\nMultinomialNB:  Fit using LIAR data; predict on ISOT "text" data')
alpha = 1.0
clf = MultinomialNB(alpha=alpha)
clf.fit(X, train_labels)

print('accuracy: %3.3f' %clf.score(X_dev_transformed, dev_labels))
# Out:
# (10164, 12231)
#
# MultinomialNB:  Fit using LIAR data; predict on ISOT "text" data
# accuracy: 0.568

# %%
print('LIAR true:', len(liar_data.binary_target[liar_data.binary_target == 1]))
#print('LIAR true:', liar_data.binary_target[liar_data.binary_target == 1].shape)
print('LIAR false:', len(liar_data.binary_target[liar_data.binary_target == 0]))
# Out:
# LIAR true: 4507
# LIAR false: 5657

# %% [markdown]
# NOTE: Nearly same results (accuracy~0.94) for both the default CountVectorizer and TfidfVectorizer.  Using full text means all TRUE news contains the word "Reuters", which is an unfair advantage.  Will try to remove those and run again, expecting lower accuracy.
# Should also account for text starting with: "'The following statements\xa0were posted to the verified Twitter accounts of U.S. President Donald Trump, @realDonaldTrump and @POTUS.  The opinions expressed are his own.\xa0Reuters has not edited the statements or confirmed their accuracy."

# %% [markdown]
# ### Repeat Naive Bayes on text field after removing first chunk of text, including "Reuters"

# %%
true_data.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date target
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
true_data.iloc[0,1][22:]
# Out:
# ' The head of a conservative Republican faction in the U.S. Congress, who voted this month for a huge expansion of the national debt to pay for tax cuts, called himself a “fiscal conservative” on Sunday and urged budget restraint in 2018. In keeping with a sharp pivot under way among Republicans, U.S. Representative Mark Meadows, speaking on CBS’ “Face the Nation,” drew a hard line on federal spending, which lawmakers are bracing to do battle over in January. When they return from the holidays on Wednesday, lawmakers will begin trying to pass a federal budget in a fight likely to be linked to other issues, such as immigration policy, even as the November congressional election campaigns approach in which Republicans will seek to keep control of Congress. President Donald Trump and his Republicans want a big budget increase in military spending, while Democrats also want proportional increases for non-defense “discretionary” spending on programs that support education, scientific research, infrastructure, public health and environmental protection. “The (Trump) administration has already been willing to say: ‘We’re going to increase non-defense discretionary spending ... by about 7 percent,’” Meadows, chairman of the small but influential House Freedom Caucus, said on the program. “Now, Democrats are saying that’s not enough, we need to give the government a pay raise of 10 to 11 percent. For a fiscal conservative, I don’t see where the rationale is. ... Eventually you run out of other people’s money,” he said. Meadows was among Republicans who voted in late December for their party’s debt-financed tax overhaul, which is expected to balloon the federal budget deficit and add about $1.5 trillion over 10 years to the $20 trillion national debt. “It’s interesting to hear Mark talk about fiscal responsibility,” Democratic U.S. Representative Joseph Crowley said on CBS. Crowley said the Republican tax bill would require the  United States to borrow $1.5 trillion, to be paid off by future generations, to finance tax cuts for corporations and the rich. “This is one of the least ... fiscally responsible bills we’ve ever seen passed in the history of the House of Representatives. I think we’re going to be paying for this for many, many years to come,” Crowley said. Republicans insist the tax package, the biggest U.S. tax overhaul in more than 30 years,  will boost the economy and job growth. House Speaker Paul Ryan, who also supported the tax bill, recently went further than Meadows, making clear in a radio interview that welfare or “entitlement reform,” as the party often calls it, would be a top Republican priority in 2018. In Republican parlance, “entitlement” programs mean food stamps, housing assistance, Medicare and Medicaid health insurance for the elderly, poor and disabled, as well as other programs created by Washington to assist the needy. Democrats seized on Ryan’s early December remarks, saying they showed Republicans would try to pay for their tax overhaul by seeking spending cuts for social programs. But the goals of House Republicans may have to take a back seat to the Senate, where the votes of some Democrats will be needed to approve a budget and prevent a government shutdown. Democrats will use their leverage in the Senate, which Republicans narrowly control, to defend both discretionary non-defense programs and social spending, while tackling the issue of the “Dreamers,” people brought illegally to the country as children. Trump in September put a March 2018 expiration date on the Deferred Action for Childhood Arrivals, or DACA, program, which protects the young immigrants from deportation and provides them with work permits. The president has said in recent Twitter messages he wants funding for his proposed Mexican border wall and other immigration law changes in exchange for agreeing to help the Dreamers. Representative Debbie Dingell told CBS she did not favor linking that issue to other policy objectives, such as ...

# %%
true_data.iloc[:,1]
#true_data.iloc[13,1]
# Out:
# 0        WASHINGTON (Reuters) - The head of a conservat...
# 1        WASHINGTON (Reuters) - Transgender people will...
# 2        WASHINGTON (Reuters) - The special counsel inv...
# 3        WASHINGTON (Reuters) - Trump campaign adviser ...
# 4        SEATTLE/WASHINGTON (Reuters) - President Donal...
# 5        WEST PALM BEACH, Fla./WASHINGTON (Reuters) - T...
# 6        WEST PALM BEACH, Fla (Reuters) - President Don...
# 7        The following statements were posted to the ve...
# 8        The following statements were posted to the ve...
# 9        WASHINGTON (Reuters) - Alabama Secretary of St...
# 10       (Reuters) - Alabama officials on Thursday cert...
# 11       NEW YORK/WASHINGTON (Reuters) - The new U.S. t...
# 12       The following statements were posted to the ve...
# 13       The following statements were posted to the ve...
# 14        (In Dec. 25 story, in second paragraph, corre...
# 15       (Reuters) - A lottery drawing to settle a tied...
# 16       WASHINGTON (Reuters) - A Georgian-American bus...
# 17       The following statements were posted to the ve...
# 18       (Reuters) - A U.S. appeals court in Washington...
# 19       (Reuters) - A gift-wrapped package addressed t...
# 20       WASHINGTON (Reuters) - A federal judge in Seat...
# 21       NEW YORK (Reuters) - The U.S. Justice Departme...
# 22       (Reuters) - A U.S. appeals court on Friday sai...
# 23       WASHINGTON (Reuters) - A federal appeals court...
# 24       LIMA (Reuters) - Peru’s President Pedro Pablo ...
# 25       WASHINGTON (Reuters) - U.S. President Donald T...
# 26       WASHINGTON (Reuters) - U.S. financial regulato...
# 27       The following statements were posted to the ve...
# 28       MEXICO CITY (Reuters) - Mexico’s finance minis...
# 29       WASHINGTON (Reuters) - U.S. Senate Majority Le...
#                                ...
# 21387    TRIPOLI (Reuters) - Former Libyan Prime Minist...
# 21388    LONDON (Reuters) - Britain on Wednesday outlin...
# 21389    BERLIN (Reuters) - Chancellor Angela Merkel sa...
# 21390    KARACHI, Pakistan (Reuters) - Pakistan has rej...
# 21391    BUCHAREST (Reuters) - Romania s justice minist...
# 21392    BEIRUT (Reuters) - Iran and Saudi Arabia will ...
# 21393    COPENHAGEN (Reuters) - Police on Wednesday ide...
# 21394    HONG KONG (Reuters) - Typhoon Hato, a maximum ...
# 21395    WARSAW (Reuters) - Poland will allocate an add...
# 21396    DUBAI (Reuters) - Fighters loyal to the armed ...
# 21397    BERLIN (Reuters) - The leader of Germany s Soc...
# 21398    SHANGHAI (Reuters) - An old review of an acade...
# 21399    DUBAI (Reuters) - A 14-year-old boy who was de...
# 21400    LONDON (Reuters) - Abdul Daoud spilt most of t...
# 21401    BUENOS AIRES (Reuters) - Argentina s main labo...
# 21402    ON BOARD A U.S. MILITARY AIRCRAFT (Reuters) - ...
# 21403    WASHINGTON (Reuters) - The United States sugge...
# 21404    WASHINGTON (Reuters) - The United States has d...
# 21405    ISLAMABAD (Reuters) - Outlining a new strategy...
# 21406    GENEVA (Reuters) - North Korea and the United ...
# 21407    SAO PAULO (Reuters) - Cesar Mata Pires, the ow...
# 21408    GENEVA (Reuters) - North Korea and the United ...
# 21409    GENEVA (Reuters) - North Korea and the United ...
# 21410    COPENHAGEN (Reuters) - Danish police said on T...
# 21411    UNITED NATIONS (Reuters) - Two North Korean sh...
# 21412    BRUSSELS (Reuters) - NATO allies on Tuesday we...
# 21413    LONDON (Reuters) - LexisNexis, a provider of l...
# 21414    MINSK (Reuters) - In the shadow of disused Sov...
# 21415    MOSCOW (Reuters) - Vatican Secretary of State ...
# 21416    JAKARTA (Reuters) - Indonesia will buy 11 Sukh...
# Name: text, Length: 21417, dtype: object

# %%
# How many of the TRUE NEWS docs contain "Reuters"?  
# How many of the TRUE NEWS docs start with "The following statements"?  

reuters_counter=0
statements_counter=0

for i in range(true_data.shape[0]):
    if true_data.iloc[i,1].find("Reuters") > 0:
        reuters_counter += 1
    if (true_data.iloc[i,1].find("following") > 0) & (true_data.iloc[i,1].find("statements") > 0):
        statements_counter += 1

print('reuters_counter:', reuters_counter)
print('statement_counter:', statements_counter)
print('total true docs:', true_data.shape[0])
# Out:
# reuters_counter: 21378
# statement_counter: 156
# total true docs: 21417

# %% [markdown]
# #### Need to remove "Reuters" from True News

# %%
re.sub(r"^.?([r,R]euters) - ", "", "WASHINGTON (Reuters) - my name is reuters, Reuters is the code")
# Out:
# 'WASHINGTON (Reuters) - my name is reuters, Reuters is the code'

# %%
re.sub(r"[r,R]euters", "", "my name is reuters, Reuters is the code")
# Out:
# 'my name is ,  is the code'

# %%
re.sub(r"[\w+\s+]+[r,R]euters", "", "WASHINGTON (Reuters) - my name is reuters, Reuters is the code")
# Out:
# 'WASHINGTON (Reuters) -, is the code'

# %%
re.sub(r"[\w+\s+]+([r,R]euters) - ", "", "WASHINGTON (Reuters) - my name is reuters, Reuters is the code")
# Out:
# 'WASHINGTON (Reuters) - my name is reuters, Reuters is the code'

# %%
re.sub(r"\w.*[r,R]euters\W*", "","ASPEN, Colorado (Reuters) - The Trump administ")  ### This is the one we want...
# Out:
# 'The Trump administ'

# %%
def remove_reuters(text):
    return(re.sub(r"\w.*[r,R]euters\W*", "", text))

true_data['text2'] = true_data['text'].apply(remove_reuters)
true_data.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date target  \
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1
#
#                                                text2
# 0  The head of a conservative Republican faction ...
# 1  Transgender people will be allowed for the fir...
# 2  The special counsel investigation of links bet...
# 3  for comment. Mueller’s office declined to comm...
# 4  President Donald Trump called on the U.S. Post...

# %%
true_data['text2'] = true_data['text'].apply(remove_reuters)

# %%
true_data.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date target  \
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1
#
#                                                text2
# 0  The head of a conservative Republican faction ...
# 1  Transgender people will be allowed for the fir...
# 2  The special counsel investigation of links bet...
# 3  for comment. Mueller’s office declined to comm...
# 4  President Donald Trump called on the U.S. Post...

# %%
fake_data['text2'] = fake_data['text']

# %%
#append the datasets and shuffle them
all_data2 = true_data.append(fake_data, ignore_index=True)
all_data2 = all_data2.sample(frac=1).reset_index(drop=True)

all_data2.describe()
# Out:
#                                                     title   text  \
# count                                               44898  44898
# unique                                              38729  38646
# top     Factbox: Trump fills top jobs for his administ...
# freq                                                   14    627
#
#              subject                date target  text2
# count          44898               44898  44898  44898
# unique             8                2397      2  38228
# top     politicsNews  December 20, 2017       0
# freq           11272                 182  23481    627

# %%
all_data2.head()
# Out:
#                                                title  \
# 0  U.S. to review energy royalty rates on federal...
# 1  Illinois Senate votes for $454 million higher-...
# 2  New Jersey 'Bridgegate' defendant says he was ...
# 3  Spain's Rajoy calls on Catalonia leaders to ca...
# 4  BREAKING: CROOKED VA GOVERNOR, Close Hillary F...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The U.S. Interior Depar...  politicsNews
# 1  CHICAGO (Reuters) - For the second time in two...  politicsNews
# 2  NEWARK, N.J. (Reuters) - After days of complai...  politicsNews
# 3  MADRID (Reuters) - Spanish Prime Minister Mari...     worldnews
# 4  How much more criminal activity are American v...     left-news
#
#                   date target  \
# 0      March 29, 2017       1
# 1         May 5, 2016       1
# 2    October 17, 2016       1
# 3  September 20, 2017       1
# 4         Oct 23, 2016      0
#
#                                                text2
# 0  The U.S. Interior Department said on Wednesday...
# 1  For the second time in two weeks, the Illinois...
# 2  After days of complaints about traffic jams at...
# 3  Spanish Prime Minister Mariano Rajoy on Wednes...
# 4  How much more criminal activity are American v...

# %%
## Re-define train/dev/test:

train_set = all_data2[ :int(len(all_data2)*train_fract)].reset_index(drop=True)
dev_set = all_data2[int(len(all_data2)*(train_fract)) : int(len(all_data)*(train_fract+dev_fract))].reset_index(drop=True)
test_set = all_data2[int(len(all_data2)*(train_fract+dev_fract)) : ].reset_index(drop=True)

print('training set: ',train_set.shape)
print('dev set: ',dev_set.shape)
print('test set: ',test_set.shape)


train_data, train_labels = train_set.text2.values, train_set.target.values
dev_data, dev_labels = dev_set.text2.values, dev_set.target.values

train_labels = train_labels.astype(int)
dev_labels = dev_labels.astype(int)

print('\ntrain_data shape:', train_data.shape)
print('train_labels shape:', train_labels.shape)
print(train_labels)
# Out:
# training set:  (31428, 6)
# dev set:  (6735, 6)
# test set:  (6735, 6)
#
# train_data shape: (31428,)
# train_labels shape: (31428,)
# [1 1 1 ... 0 0 0]

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(train_data)
X_dev_transformed = vectorizer.transform(dev_data)

# MultinomialNB
print('\nMultinomialNB with "Reuters" removed from text field')
alpha = 1.0
clf = MultinomialNB(alpha=alpha)
clf.fit(X, train_labels)

print('accuracy: %3.3f' %clf.score(X_dev_transformed, dev_labels))
# Out:
# MultinomialNB with "Reuters" removed from text field
# accuracy: 0.947

# %%
#print(train_data)
# Out:
# ['The U.S. Interior Department said on Wednesday that it would form a new committee to review royalty rates collected from oil and gas drilling, coal mining and renewable energy production on federal lands to ensure taxpayers receive their full value. Interior Secretary Ryan Zinke said the committee would advise him on whether the government is getting a fair price from companies that lease public land for energy and natural resource development.  The committee will replace the process put in place by former Interior Secretary Sally Jewell to review and overhaul the federal coal leasing program. “The programmatic review put in place (by Jewell) was costly and unnecessary,” Zinke told reporters on Wednesday. “I have established a royalty policy committee to provide advice to me about how we value collections across the board,” he said. In January 2016, the administration of former Democratic President Barack Obama began a multiyear review of the federal coal leasing program after government and watchdog reports found Interior’s Bureau of Land Management was not properly accounting for the fair market value of coal. It also ordered a moratorium on new coal leases for at least three years during the review, which Republican President Donald Trump officially rescinded in the executive order on energy he signed Tuesday.  Zinke’s committee will instead get recommendations on adjusting royalty rates for coal, as well as oil and gas, from a panel of up to 28 members. Members will include Interior Department officials, representatives of western states and Indian tribes that produce energy, energy stakeholders and academic groups who will serve three-year terms. Federal coal, primarily from Wyoming’s Powder River Basin, accounts for more than 40 percent of all of that fuel mined in the United States and produces for 10 percent of U.S. greenhouse gas emissions. Zinke’s predecessor Jewell said a review of the program was three decades overdue and necessary after reports called for more transparency in the leasing process. Environmental groups raised concerns that replacing the more comprehensive review with a committee approach will mean that other core problems with federal energy leasing will not be addressed, such as transparency and boosting competition in lease sales. “Cancelling the coal program review is a serious mistake that only harms American taxpayers, coal states and communities,” said Dan Bucks, former director of revenue for the state of Montana. '
#  'For the second time in two weeks, the Illinois Senate moved to loosen the financial death grip on the state’s higher education system, which has been starved of operating revenue by a record-setting, 11-month state budget stalemate. The Senate on Thursday overwhelmingly approved and sent to the House of Representatives a $454 million spending package for eight public universities, community colleges and low-income students dependent on Monetary Award Program grants. The bipartisan move, which could stave off mass layoffs at several state universities, builds on a $600 million, higher-education appropriation that Republican Governor Bruce Rauner signed on April 25. Thursday’s action also represents another encouraging break in the state’s acrimonious budget fight between the governor and Democrats, who control the state legislature, as they face a scheduled legislative adjournment at the end of May. “We have since found more dollars which we can appropriate to our universities to make them more competitive, to make them more viable and to give them a bridge going forth into the 2017 budget,” said state Senator Donne Trotter, a Chicago Democrat and a sponsor of Thursday’s legislation. The latest appropriation was supported financially by companion legislation that passed the Senate on Thursday authorizing Rauner’s administration not to repay $454 million borrowed from state special-purpose funds during the 2015 fiscal year. Without legislative action, that amount would have had to be repaid June 30 from the state’s main operational fund. The approach drew isolated claims of budgetary sleight of hand during floor debate. “This is ridiculous, swapping money from one pocket to another, saying you have it when you don’t,” said state Senator Kyle McCarter, a Republican from Lebanon, Illinois, a rural enclave nearly 300 miles southwest of Chicago. The Senate-passed legislation cannot be acted on by the House until Tuesday at the earliest when that legislative chamber is scheduled to reconvene. The respite for the state’s higher-education system comes after its community colleges received rating downgrades and  negative outlooks by Moody’s Investors Service in recent weeks, and Chicago State University had faced the threat of possible closure. '
#  'After days of complaints about traffic jams at a major New York bridge in 2013, New Jersey Governor Chris Christie’s associate demanded to know if lane closures were political retribution, he testified on Monday. On trial over his alleged role in the “Bridgegate” scandal, Bill Baroni, Christie’s top political appointee at the Port Authority of New York and New Jersey, said he confronted fellow authority executive David Wildstein to ask whether the lane closures in September 2013 were an act of retribution against the Democratic mayor of a commuter town. “I said, ‘David, tell me right now, is this true?’” Baroni testified in federal court in Newark, where he is on trial on fraud charges. “He looked me in the eye and said, ‘Absolutely not.’” In his first day of testimony, Baroni asserted that Wildstein orchestrated the lane closures without his knowledge to punish Mark Sokolich, the mayor of Fort Lee, for his refusal to endorse Christie’s re-election bid. Baroni also rejected Wildstein’s contention that they discussed the scheme with Christie as it was unfolding. Christie had soared to national prominence in late 2012 for his response to Superstorm Sandy and wanted to use that spotlight, and an aura of bipartisan spirit, to catapult himself towards the White House. But the scandal hurt his image and his campaign ultimately collapsed early this year, though he has always denied involvement. Baroni’s story was entirely at odds with the narrative U.S. prosecutors have presented at trial. They have accused Baroni, Wildstein and former Christie deputy chief of staff Bridget Kelly of conspiring to create the traffic jam to punish Sokolich. Kelly, on trial alongside Baroni, is also expected to testify. Wildstein has pleaded guilty and appeared as the government’s star witness earlier in the case. Baroni said he confronted Wildstein after receiving a letter from Sokolich suggesting the closures had “punitive overtones.” But during cross-examination, Assistant U.S. Attorney Lee Cortes pointed out that days before, Sokolich left him a voicemail asking “who’s mad at me?” “So the first time you heard from him, he was asking if someone was mad at him? It wasn’t Thursday?” Cortes asked. Baroni said he believed Wildstein’s representation that the George Washington Bridge lane closure was part of a traffic study and that he should not respond to Sokolich.  “I’ve regretted it ever since,” Baroni said. Wildstein said he and Baroni invented the traffic study as a cover story. '
#  ...
#  "Mayor Bill de Blasio on Thursday skipped an NYPD swearing-in ceremony made somber by this week s assassination of a cop   then hours later revealed he was busy preparing to jet off on a surprise trip to join leftist protesters at the G-20 summit in Germany.Hizzoner s overseas jaunt was kept under wraps until just 90 minutes before he took off from Newark Airport. A last-minute announcement said he  will attend several events surrounding the G-20 Summit, including Saturday s Hamburg Zeigt Haltung rally. De Blasio will be the keynote speaker, organizers of the demonstration   Hamburg Shows Attitude   tweeted. The mayor also made sure the free trip will include a visit with his son, Dante, a Yale University student who s spending the summer on an internship in Berlin, a City Hall spokesman said.Presumptive Republican challenger Nicole Malliotakis accused de Blasio of abandoning pressing issues in the Big Apple to pursue his progressive agenda in Europe. Unbelievable. Instead of jet-setting around the world, he should be here doing his job,  said the Staten Island assemblywoman.  A police officer was murdered, street homelessness has skyrocketed and people continue to get delayed on the trains. Malliotakis   who later tweeted a doctored image showing de Blasio in an Alpine hat and lederhosen, grinning behind a plate of bratwurst, wienerschnitzel and Pilsner glasses   also blasted him for blowing off the NYPD ceremony at the Police Academy in Queens.Malliotakis jabs de Blasio with Photoshopped tweet over Germany trip https://t.co/DtTRaAQBXD via @nypmetro  carl campanile (@ccampy) July 7, 2017 The mayor should be embarrassed by the way he has treated the men and women of our police department,  she said.He is off gallivanting & I'm here pointing out problems w/ garbage collection, the most basic of city services  https://t.co/yW4MZ02u3O  Nicole Malliotakis (@NMalliotakis) July 7, 2017New Jersey Transit tweeted about a schedule change after a train was derailed yesterday while entering Penn Station in NYC, causing delays in transit for commuters:All Midtown DIRECT trains are being diverted into Hoboken Terminal. NJT is cross-honoring w/ PATH, & NJ TRANSIT & Private bus carriers.  NJ TRANSIT (@NJTRANSIT) July 7, 2017GOP Mayoral candidate Nicole Malliotakis retweeted NJ Transit s message to keep New Yorker s apprised of the change, in the absence of the protesting NYC Mayor DeBlasio:I'm retweeting this to keep #NYC residents informed since our mayor is in Germany where it is 4:57a.m. https://t.co/qV1nXSGHHM  Nicole Malliotakis (@NMalliotakis) July 7, 2017I m so old, I remember when mayors stayed in their city to do their job rather than try to make themselves ideological symbols. https://t.co/deDbXzWU3g  John Avlon (@JohnAvlon) July 7, 2017The head of the NYPD sergeants union also attacked de Blasio. As the city mourns, its leader flees,  Ed Mullins said.  And then he wonders why he has a problem with the police. A real leader stays with the city in this time of hardship. NYP"
#  'THE CONGRESS IS THERE TO DO WHAT S BEST FOR THE AMERICAN PEOPLE YET THEY RE LIKE DEER IN THE HEADLIGHTS. Listen to this former DOJ whistleblower who s been in the belly of the Obama regime beast and knows the deal.'
#  'The employees went on twitter to speak about global warming and immigration The Twitter accounts themselves went beyond the official National Park Service accounts. The @AltUSNatParkService account, which calls itself an  Unofficial  Resistance  team of the U.S. National Park Service,  has garnered over half a million followers.Climate-related tweets sent out by the official Badlands park account were deleted after they went viral on Twitter, sparking debate over whether the park was defying the Trump administration.YES! THIS IS DEFIANT AND SINCE THE FEDS ARE THEIR EMPLOYER, THEY SHOULD BE FIRED! ']

# %% [markdown]
# ### Run Naive Bayes on the Title field

# %%
fake_data.title

#print(fake_data.title.iloc[:15])
# Out:
# 0         Donald Trump Sends Out Embarrassing New Year’...
# 1         Drunk Bragging Trump Staffer Started Russian ...
# 2         Sheriff David Clarke Becomes An Internet Joke...
# 3         Trump Is So Obsessed He Even Has Obama’s Name...
# 4         Pope Francis Just Called Out Donald Trump Dur...
# 5         Racist Alabama Cops Brutalize Black Boy While...
# 6         Fresh Off The Golf Course, Trump Lashes Out A...
# 7         Trump Said Some INSANELY Racist Stuff Inside ...
# 8         Former CIA Director Slams Trump Over UN Bully...
# 9         WATCH: Brand-New Pro-Trump Ad Features So Muc...
# 10        Papa John’s Founder Retires, Figures Out Raci...
# 11        WATCH: Paul Ryan Just Told Us He Doesn’t Care...
# 12        Bad News For Trump — Mitch McConnell Says No ...
# 13        WATCH: Lindsey Graham Trashes Media For Portr...
# 14        Heiress To Disney Empire Knows GOP Scammed Us...
# 15        Tone Deaf Trump: Congrats Rep. Scalise On Los...
# 16        The Internet Brutally Mocks Disney’s New Trum...
# 17        Mueller Spokesman Just F-cked Up Donald Trump...
# 18        SNL Hilariously Mocks Accused Child Molester ...
# 19        Republican Senator Gets Dragged For Going Aft...
# 20        In A Heartless Rebuke To Victims, Trump Invit...
# 21        KY GOP State Rep. Commits Suicide Over Allega...
# 22        Meghan McCain Tweets The Most AMAZING Respons...
# 23        CNN CALLS IT: A Democrat Will Represent Alaba...
# 24        White House: It Wasn’t Sexist For Trump To Sl...
# 25        Despicable Trump Suggests Female Senator Woul...
# 26        Accused Child Molesting Senate Candidate Roy ...
# 27        WATCH: Fox Host Calls For A ‘Cleansing’ Of Th...
# 28        Liberal Group Trolls Trump At Roy Moore Rally...
# 29        Don Jr. Tries To Mock Al Franken’s Resignatio...
#                                ...
# 23451    3.57 Degrees: Kevin Bacon’s Cultural Mantle Sh...
# 23452             Bernie Sanders Could End Up Winning Iowa
# 23453    Plastic Persona: Behind the Scenes of the Ted ...
# 23454            ‘Meet Jeb’ – Going For Your Sympathy Vote
# 23455    BOILER ROOM – Examination, Exclamation, Excita...
# 23456    Eyewash: CIA Elites Misleading Employees Indic...
# 23457    Activist: ‘This is where you can make the most...
# 23458    Episode #120 – SUNDAY WIRE: ‘Crisis of Liberty...
# 23459    FBI Release Oregon Video Footage Depicting Dea...
# 23460    Trial By YouTube: Mainstream Media Use Second-...
# 23461    REPORT: ‘Federal Government Escalated the Viol...
# 23462    BOILER ROOM – Oregon Standoff, Cuddle Parties,...
# 23463    Eyewitness Says Feds Ambushed Bundys, 100 Shot...
# 23464    Episode #119 – SUNDAY WIRE: ‘You Know the Dril...
# 23465    ‘There’ll be boots on the ground’: US making n...
# 23466    Boston Brakes? How to Hack a New Car With Your...
# 23467    Oregon Governor Says Feds ‘Must Act’ Against P...
# 23468    Ron Paul on Burns Oregon Standoff and Jury Nul...
# 23469       BOILER ROOM: As the Frogs Slowly Boil – EP #40
# 23470    Arizona Rancher Protesting in Oregon is Target...
# 23471    Seven Iranians freed in the prisoner swap have...
# 23472                        #Hashtag Hell & The Fake Left
# 23473    Astroturfing: Journalist Reveals Brainwashing ...
# 23474            The New American Century: An Era of Fraud
# 23475    Hillary Clinton: ‘Israel First’ (and no peace ...
# 23476    McPain: John McCain Furious That Iran Treated ...
# 23477    JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478    Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479    How to Blow $700 Million: Al Jazeera America F...
# 23480    10 U.S. Navy Sailors Held by Iranian Military ...
# Name: title, Length: 23481, dtype: object

# %%
train_data, train_labels = train_set.title.values, train_set.target.values
dev_data, dev_labels = dev_set.title.values, dev_set.target.values

train_labels = train_labels.astype(int)
dev_labels = dev_labels.astype(int)

#train_data.head()
print('train_data shape:', train_data.shape)
#print(train_data[0].shape)
print(train_data[:1])
print('\ntrain_labels shape:', train_labels.shape)
print(train_labels)

print('dev_data shape:', dev_data.shape)
# Out:
# train_data shape: (31428,)
# ["Labor Dept. looks into delaying fiduciary rule after Trump's order"]
#
# train_labels shape: (31428,)
# [1 1 1 ... 0 1 0]
# dev_data shape: (6735,)

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(train_data)


print('X.shape:', X.shape) # (). There are x documents (rows) in the corpus, with y features (unique words = vocabulary)
print('Vocabulary size (number of features or columns):', X.shape[1])  # 
print('Non-zero elements in matrix (X.nnz):', X.nnz)   # This indicates that there are z non-zero elements in the matrix.
print('Average number of non-zero features per example (per document): %.3f' %(X.nnz/X.shape[0]))  # non-zero elements in matrix / documents = xxx
print('Fraction of non-zero elements in matrix: %.4f' %( X.nnz/(X.shape[0] * X.shape[1])) )   # Fraction of entries in the matrix that are non-zero = X.nnz/(rows*columns) = 0.xxx
# Out:
# X.shape: (31428, 18801)
# Vocabulary size (number of features or columns): 18801
# Non-zero elements in matrix (X.nnz): 382390
# Average number of non-zero features per example (per document): 12.167
# Fraction of non-zero elements in matrix: 0.0006

# %%
# Using the standard CountVectorizer, what fraction of the words in the dev data are missing from the vocabulary? 
vectorizer_dev = CountVectorizer()
X_dev = vectorizer_dev.fit_transform(dev_data)  # Independently build a vocabulary using dev_data.
print('X_dev.shape:', X_dev.shape)
print('Vocabulary using train data:', X.shape[1])  # 
print('Vocabulary using dev data:', X_dev.shape[1])                # 

# Feed dev_data into the vectorizer fit using training data.
X_dev_transformed = vectorizer.transform(dev_data)
print('X_dev_transformed shape:', X_dev_transformed.shape)
#print('X_dev_transformed.shape', X_dev_transformed.shape)  # ()  EXPECT .shape[1] equal to original number of features
#print('non-zero indices in X_dev_transformed:', X_dev_transformed.nonzero())  # could also use this to check which features missing...

''' This is way too slow; use set intersection instead!!
# Look at each feature (vocabulary word) in X_dev and see if it is a feature in X.
count = 0
for i in range(X_dev.shape[1]):
    if vectorizer_dev.get_feature_names()[i] in vectorizer.get_feature_names():
        count += 1
print('Count of words (features) in X_dev also in X:', count)   
print('Fraction of words in dev data missing from training vocabulary: %.3f' %((X_dev.shape[1] - count)/X_dev.shape[1]) )
count of words (features) in X_dev also in X: 12219
Fraction of words in dev data missing from training vocabulary: 0.248
'''

set1 = set(vectorizer_dev.get_feature_names())
set2 = set(vectorizer.get_feature_names())
print('Count of words (features) in X_dev also in X:', len(set1.intersection(set2)))
print('Fraction of words in dev data missing from training vocabulary: %.3f' %((X_dev.shape[1] - len(set1.intersection(set2)))/X_dev.shape[1]) )
# Out:
# X_dev.shape: (6735, 10418)
# Vocabulary using train data: 18801
# Vocabulary using dev data: 10418
# X_dev_transformed shape: (6735, 18801)
# Count of words (features) in X_dev also in X: 9275
# Fraction of words in dev data missing from training vocabulary: 0.110

# %%
# MultinomialNB
print('\nMultinomialNB using "title" field')
alpha = 1.0
clf = MultinomialNB(alpha=alpha)
clf.fit(X, train_labels)

print('accuracy: %3.3f' %clf.score(X_dev_transformed, dev_labels))
# Out:
# MultinomialNB using "title" field
# accuracy: 0.949

# %%
#print('title, target label\n', train_set.title, train_set.target)
print('title, target label\n', train_set.title[4], train_set.target[4])
# Out:
# title, target label
#  EPIC RESPONSE AFTER THE BOSTON GLOBE Runs Fake Cover Bashing Trump…THIS IS GREAT! 0

# %%
type(train_set.target)
# Out:
# pandas.core.series.Series

# %%
type(train_labels)
# Out:
# numpy.ndarray

# %% [markdown]
# #### ONE OFF: Human Baseline Examples: read in ISOT examples previously scored by humans in the project group.   Add the predicted class to the file.

# %%
isot_human = pd.read_csv('human_isot_examples.csv')
isot_human.head()
# Out:
#                                                title
# 0  Turkey condemns U.S. move on Jerusalem as 'irr...
# 1  UK finance minister's future questioned by PM ...
# 2  Canada government facing resistance from Senat...
# 3  Tillerson says would support maintaining Russi...
# 4  DEPLORABLE! HILLARY’S Campaign Is In PANIC Mod...

# %%
X_dev_transformed = vectorizer.transform(isot_human.title)

# %%
cols = ['title', 'pred_class']
row_list = []

for i in range(len(isot_human.title)):  
    print('\nDev Title: ', isot_human.title.iloc[i])
    print('predicted class =', clf.predict(X_dev_transformed)[i],'\n' )
    row_list.append(dict( [('title',isot_human.title.iloc[i]), ('pred_class', clf.predict(X_dev_transformed)[i])]  ))


isot_human_df = pd.DataFrame(row_list, columns=cols)
# Out:
# Dev Title:  Turkey condemns U.S. move on Jerusalem as 'irresponsible'
# predicted class = 1
#
#
# Dev Title:  UK finance minister's future questioned by PM May's allies as budget nears
# predicted class = 1
#
#
# Dev Title:  Canada government facing resistance from Senate over pot law
# predicted class = 1
#
#
# Dev Title:  Tillerson says would support maintaining Russia sanctions for now
# predicted class = 1
#
#
# Dev Title:  DEPLORABLE! HILLARY’S Campaign Is In PANIC Mode…Their Latest “RACIST FROG” Story Proves It [VIDEO]
# predicted class = 0
#
#
# Dev Title:   Kentucky Woman Brutally Beaten By Man For Looking Too ‘Masculine’ While Onlookers Do NOTHING
# predicted class = 0
#
#
# Dev Title:   ALL Of The GOP Candidates Would WRECK Our Environment – Here’s How
# predicted class = 0
#
#
# Dev Title:  Canadian judge suspends Quebec niqab ban
# predicted class = 1
#
#
# Dev Title:  THE HIGHEST TAXED PLACES TO LIVE Also Happen To Be Democrat Controlled Cesspools Of Corruption
# predicted class = 0
#
#
# Dev Title:  BREAKING: BLIND OPERA SINGER Gets DEATH Threats From Left…Forced To Back Out Of Performance At Trump Inauguration [Video]
# predicted class = 0
#
#
# Dev Title:  In India's Punjab, Haley relatives cheer appointment as UN envoy
# predicted class = 1
#
#
# Dev Title:   Trump STUNS An Entire Room Into DUMBFOUNDED Silence With His ‘Proof’ Of Voter Fraud
# predicted class = 0
#
#
# Dev Title:   Kellyanne Conway Cannot Name One Performer Lined Up For Trump’s Inauguration (VIDEO)
# predicted class = 0
#
#
# Dev Title:  Hillary Clinton Is Asked The Difference Between A Socialist and A Democrat [Video]
# predicted class = 0
#
#
# Dev Title:  Congressman Franks says resigning immediately
# predicted class = 1
#
#
# Dev Title:  German minister favors longer ban on Syrian refugees bringing families
# predicted class = 1
#
#
# Dev Title:  OBAMA’S DREAM TEAM: ILLEGAL ALIEN DRUG DEALERS SUSPECTED Of KILLING Innocent Woman Sleeping In Apt Below Illegals [VIDEO]
# predicted class = 0
#
#
# Dev Title:   China Openly MOCKS Trump By Turning Him Into A Rooster, And It’s HILARIOUS (IMAGES)
# predicted class = 0
#
#
# Dev Title:  Timeline: Pivotal moments in Trump's presidential campaign
# predicted class = 1
#
#
# Dev Title:  China's Xi: stable development of China-U.S. economic ties to drive global growth
# predicted class = 1
#
#
# Dev Title:   Christian Charity President Embezzled The Entire Fund To Finance Sex Addiction
# predicted class = 0
#
#
# Dev Title:  Can Trump cut funds to UC Berkeley? Experts say not really
# predicted class = 0
#
#
# Dev Title:  SEAN SPICER Fires Off Tweet After Resignation as Media Speculation Explodes
# predicted class = 0
#
#
# Dev Title:  First two Democrats back Trump's Supreme Court pick
# predicted class = 1
#
#
# Dev Title:  UNRECOGNIZABLE After Major Plastic Surgery…HOLLYWOOD LIB Renee Zellweger Criticizes Trump: “Why are we talking about how women look?” [VIDEO]
# predicted class = 0
#
#
# Dev Title:  WATCH: Wildly Popular, Outspoken Geert Wilders Is Being Called “The Dutch Trump”…Why His Plan To De-Islamize The Netherlands Is Resonating With Voters
# predicted class = 0
#
#
# Dev Title:   The Army Field Manual Proves That Trump Is Too Mentally Unstable To Be President (DETAILS)
# predicted class = 0
#
#
# Dev Title:  MICHIGAN STATE POLICE CHIEF Under Fire For Sharing Meme On Social Media About NFL Players Anti-Cop Movement
# predicted class = 0
#
#
# Dev Title:  Rohingya women, children die in desperate boat escape from Myanmar
# predicted class = 1
#
#
# Dev Title:  Presidents Bush and Clinton: Be humble in victory, responsible with power
# predicted class = 0
#
#
# Dev Title:  HOLY CASH COW! Check Out How Much Wall Street Funneled Into HILLARY’s Foundation/Slush Fund
# predicted class = 0
#
#
# Dev Title:  Russian pipeline monopoly says will weather well U.S. sanctions
# predicted class = 1
#
#
# Dev Title:  Obama: Sanders has 'luxury' of being long shot in Democratic race
# predicted class = 0
#
#
# Dev Title:   Bernie Sanders Just Dropped A Bomb On Debbie Wasserman-Schultz That Could End Her Career
# predicted class = 0
#
#
# Dev Title:  NANCY PELOSI ASKED: Who’s the Leader of the Dems?…Any Guesses? Soros? [Video]
# predicted class = 0
#
#
# Dev Title:  A South Sudan vote would heap disaster upon catastrophe, U.N. says
# predicted class = 1
#
#
# Dev Title:  Anti-nuclear campaign group wins 2017 Nobel Peace Prize
# predicted class = 1
#
#
# Dev Title:  Pope holds emotional meeting with refugees, says "Rohingya" for first time
# predicted class = 1
#
#
# Dev Title:  Fujimori family pulls Peru back into political turmoil
# predicted class = 1
#
#
# Dev Title:  OOPS! HOMELAND SECURITY CANDIDATE Accidentally Shows Plan For Border And Illegal Criminals…You’ll Love It!
# predicted class = 0
#
#
# Dev Title:  Republicans block Democrats' bid to see Treasury files on Trump
# predicted class = 1
#
#
# Dev Title:  Yellen to testify at House Financial Services panel February 10: committee
# predicted class = 1
#
#
# Dev Title:  STUNNING: Podesta Brothers and Manafort Connected to Russia Scandal…NOT Trump [Video]
# predicted class = 0
#
#
# Dev Title:  Two Somali soldiers wounded in gun fight with fellow troops
# predicted class = 1
#
#
# Dev Title:  Trump to meet with Petraeus, Corker, Romney this week: transition team
# predicted class = 1
#
#
# Dev Title:  Spain pushes EU to adopt restrictive measures against Venezuela
# predicted class = 1
#
#
# Dev Title:  Bundy Ranch ‘Standoff’ Defendants Prepare for Trial in Nevada
# predicted class = 0
#
#
# Dev Title:  Celebrity U.S. presidential picks prompt alliances, rifts
# predicted class = 1
#
#
# Dev Title:  BOMBSHELL: Frustrated Outgoing Army General Says Obama’s Military Cuts Making Enemies More Emboldened…Iraq Didn’t Need To Collapse [VIDEO]
# predicted class = 0
#
#
# Dev Title:  U.S.-backed Syrian militias raise flag in Raqqa stadium
# predicted class = 1
#
#
# Dev Title:   ‘Small Government’ GOP Rep. Wants A Law To Dictate Exotic Dancers’ Max Weight
# predicted class = 0
#
#
# Dev Title:  Senate rejects bid to repeal war authorizations
# predicted class = 1
#
#
# Dev Title:  NEWT GINGRICH: Why Obama, NOT TRUMP, Should Testify Under Oath Before Congress in Russia Probe [VIDEO]
# predicted class = 0
#
#
# Dev Title:  WATCH: SEAN HANNITY Offers To Step In After He Sees Heartbreaking Viral Video Of Young Boy Crying Over Being Bullied For His Appearance
# predicted class = 0
#
#
# Dev Title:  U.S. President Trump to visit Britain in February: Daily Mail
# predicted class = 1
#
#
# Dev Title:   You Won’t Believe The Insane Anti-Obama Bullsh*t This Idiot ACTUALLY Wrote To His Local Paper
# predicted class = 0
#
#
# Dev Title:  Trump tells Sisi U.S., Egypt will fight Islamist militants together
# predicted class = 1
#
#
# Dev Title:   NAACP Members Arrested For Protesting Trump’s Racist Attorney General Pick (VIDEO)
# predicted class = 0
#
#
# Dev Title:   Watergate Reporter Says Trump’s Russia Scandal Is Way WORSE Than Watergate (DETAILS)
# predicted class = 0
#
#
# Dev Title:  Hungary eases pressure on international universities in Soros row
# predicted class = 1
#
#
# Dev Title:  WOW! DID “Open Borders” Paul Ryan’s Top Advisor Leak Trump Tapes To Liberal Press…Is GOP Setting Up Ryan And Romney For Presidential Bid In 2020?
# predicted class = 0
#
#
# Dev Title:  KARMA: GAY PASTOR SUES WHOLE FOODS For “Anti-Gay Slur” On Cake…Didn’t Count On Baker Being Gay [VIDEO]
# predicted class = 0
#
#
# Dev Title:  Trump says Britain would be better off outside EU
# predicted class = 1
#
#
# Dev Title:   Second-Largest U.S. Paper Now Wants Readers To Decide If Trump’s Lies Are Lies (VIDEO)
# predicted class = 0
#
#
# Dev Title:   Governor Of Texas Unveils Detailed Plan To OVERTHROW The Federal Government
# predicted class = 1
#
#
# Dev Title:  Details emerge of Republicans' plans to replace Obamacare
# predicted class = 0
#
#
# Dev Title:  EU's Tusk: no deadlock on Brexit, very cautious but optimistic
# predicted class = 1
#
#
# Dev Title:  U.S. appeals court voids forfeiture of Iran-linked New York office tower
# predicted class = 1
#
#
# Dev Title:  State Department memo shows unconstitutionality of Trump travel ban: ACLU
# predicted class = 1
#
#
# Dev Title:  Pentagon says fourth U.S. soldier killed in Niger ambush
# predicted class = 1
#
#
# Dev Title:  U.S. Homeland Security probes possible abuse in Twitter summons case
# predicted class = 1
#
#
# Dev Title:   Trump’s Biggest, Most Pansy-A** Apologist Now Says He Is ‘Unacceptable’
# predicted class = 0
#
#
# Dev Title:  Indonesia questions fireworks factory owner after deadly blaze
# predicted class = 1
#
#
# Dev Title:  DAY 2 RESULTS Of Wisconsin Recount Are In…And Hillary’s Not Gonna Like It
# predicted class = 0
#
#
# Dev Title:   The Russia Investigation’s Special Counsel Just Made Trump’s Problems A Whole Lot Worse
# predicted class = 0
#
#
# Dev Title:  France and Qatar sign deals worth 12 billion euros: Macron
# predicted class = 1
#
#
# Dev Title:  UK's May to visit China around Jan. 31: Sky News
# predicted class = 1
#
#
# Dev Title:   WATCH: Giuliani Demands That Democrats Apologize For Trump’s Racist Birtherism
# predicted class = 0
#
#
# Dev Title:  Russia's Medvedev says the world shouldn't be dominated by one currency
# predicted class = 1
#
#
# Dev Title:  COLLEGE SOCIALIST GROUP Incites Children To Yell: “Kill Donald Trump!” [VIDEO]
# predicted class = 0
#
#
# Dev Title:   Trump Breaks ANOTHER Huge Campaign Promise, Stabs Followers In The Back Yet Again
# predicted class = 0
#
#
# Dev Title:   Fox News Host Megyn Kelly Completely Embarrasses Traitorous Bundy Terrorist (VIDEO)
# predicted class = 0
#
#
# Dev Title:   For Bannon, The Losses Just Keep Coming
# predicted class = 0
#
#
# Dev Title:   Ellen DeGeneres Refuses To Have Donald Trump On Her Show; Here’s Why (VIDEO)
# predicted class = 0
#
#
# Dev Title:   Man Who Said There Was No Recession DURING The Great Recession Is Rumored For Top Economic Post
# predicted class = 0
#
#
# Dev Title:  DINESH D’SOUZA: “Not Since Lincoln, Have The Democrats So Obstinately Refused To Accept The Result Of A Lawful Election” [VIDEO]
# predicted class = 0
#
#
# Dev Title:  BLACK HARVARD STUDENTS Host Separate Segregated Graduation Ceremony
# predicted class = 0
#
#
# Dev Title:  Top advisers in more displays of disagreement with Trump
# predicted class = 1
#
#
# Dev Title:   Twitter Destroys Trump For Using Dwyane Wade’s Personal Tragedy To Pander For Black Votes
# predicted class = 0
#
#
# Dev Title:   Trump BETRAYED: GOP Rep. DEFENDS Refugees Against His Muslim Ban
# predicted class = 0
#
#
# Dev Title:  Arsonists attack building used by controversial Russian director
# predicted class = 0
#
#
# Dev Title:  Sri Lanka arrests two over hacking of Taiwan bank accounts
# predicted class = 1
#
#
# Dev Title:  Swiss dismiss ETA activist's asylum bid, but she is free to stay
# predicted class = 1
#
#
# Dev Title:  Mnangagwa will be sworn in as Zimbabwe president: ZANU-PF
# predicted class = 1
#
#
# Dev Title:  Palestinians say they won't be blackmailed by U.S. move to close PLO office
# predicted class = 1
#
#
# Dev Title:  Russia may seize U.S. property if its own compounds not returned: Kommersant
# predicted class = 1
#
#
# Dev Title:  Trump unlikely to pick Cohn for Fed as he is crucial to tax reform drive: official
# predicted class = 1
#
#
# Dev Title:  Macron touts European initiative to evacuate Africans trapped in Libya
# predicted class = 1
#
#
# Dev Title:  U.S. civil liberties group to challenge Trump's new travel ban
# predicted class = 1
#
#
# Dev Title:  Four killed as militants attack airport security camp in Indian-controlled Kashmir
# predicted class = 1

# %%
isot_human_df.head()
# Out:
#                                                title  pred_class
# 0  Turkey condemns U.S. move on Jerusalem as 'irr...           1
# 1  UK finance minister's future questioned by PM ...           1
# 2  Canada government facing resistance from Senat...           1
# 3  Tillerson says would support maintaining Russi...           1
# 4  DEPLORABLE! HILLARY’S Campaign Is In PANIC Mod...           0

# %%
isot_human_df.to_csv('human_isot_examples.csv', sep=',')

# %% [markdown]
# #### Re-do training and dev eval using only LOWER CASE text.  (Not relevant since CountVectorizer already does this??)

# %%
print(train_set.title.values)
# Out:
# ['Senate panel sets hearing for Trump tax nominee'
#  '“WOODY” KAINE One Of Six ARRESTED After Peaceful Pro-Trump Supporters Were Attacked By VIOLENT RIOTERS At MN State Capitol [VIDEO]'
#  'Armed faction takes over protection of Libyan oil and gas complex, fresh concern over migrants'
#  ...
#  'Authorities Allowed NYC Chain Migration Terrorist To Stop Interrogation Several Times To Pray After Admitting He Was Triggered By CHRISTMAS Posters'
#  'Unpopularity of Clinton, Trump puts spotlight on potential running mates'
#  'TRUMP FINANCIAL ADVISOR Has Great Tax News For Job Creators: “I think they need to get that done quickly”…MAGA! [VIDEO]']

# %%
print(all_data['title'].str.lower().values)
# Out:
# ['senate panel sets hearing for trump tax nominee'
#  '“woody” kaine one of six arrested after peaceful pro-trump supporters were attacked by violent rioters at mn state capitol [video]'
#  'armed faction takes over protection of libyan oil and gas complex, fresh concern over migrants'
#  ... 'tillerson underlines cooperation with japan, seoul on north korea'
#  'austrian coalition talks set to begin, far right likely partner'
#  ' usa swimming metes out punishment that stanford rapist really deserves']

# %%
train_data, train_labels = train_set.title.str.lower().values, train_set.target.values
dev_data, dev_labels = dev_set.title.str.lower().values, dev_set.target.values

# %%
print(train_data)
print()
print(dev_data)
print(train_data.shape, dev_data.shape)
# Out:
# ['senate panel sets hearing for trump tax nominee'
#  '“woody” kaine one of six arrested after peaceful pro-trump supporters were attacked by violent rioters at mn state capitol [video]'
#  'armed faction takes over protection of libyan oil and gas complex, fresh concern over migrants'
#  ...
#  'authorities allowed nyc chain migration terrorist to stop interrogation several times to pray after admitting he was triggered by christmas posters'
#  'unpopularity of clinton, trump puts spotlight on potential running mates'
#  'trump financial advisor has great tax news for job creators: “i think they need to get that done quickly”…maga! [video]']
#
# ['proposed budget deal is much worse on u.s. border security than we originally thought'
#  "australian, american, malaysian arrested in indonesia's bali for drugs"
#  ' muslim woman who turned in paris terrorist shares important thought with the world'
#  ...
#  'lol! social media users respond to hillary’s birthday tweet to herself…and they’re hilarious!'
#  'white house optimistic congress will avoid government shutdown'
#  'brexit would hurt britain, eu and global economy: white house adviser in newspaper']
# (31428,) (6735,)

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(train_data)
X_dev_transformed = vectorizer.transform(dev_data)

# MultinomialNB
print('\nMultinomialNB using "title" field')
alpha = 1.0
clf = MultinomialNB(alpha=alpha)
clf.fit(X, train_labels)

print('accuracy: %3.3f' %clf.score(X_dev_transformed, dev_labels))
# Out:
# MultinomialNB using "title" field
# accuracy: 0.947

# %%
# PRINT ISOT DEV TITLES WITH LABELS AND PREDICTED VALUES

cols = ['ISOT title', 'Label', 'Predicted Class']
row_list = []

for i in range(dev_data.shape[0]):
    #print(dev_data[i], dev_labels[i], clf.predict(X_dev_transformed)[i])
    row_list.append(dict( [('ISOT title', dev_data[i]), ('Label', dev_labels[i]), ('Predicted Class', clf.predict(X_dev_transformed)[i])]  ))

dev_set_df = pd.DataFrame(row_list, columns=cols)

# %%
print(dev_set_df.size)
print(len(dev_set_df))
dev_set_df.head()
# Out:
# 20205
# 6735
#                                           ISOT title Label Predicted Class
# 0  proposed budget deal is much worse on u.s. bor...     0               0
# 1  australian, american, malaysian arrested in in...     1               1
# 2   muslim woman who turned in paris terrorist sh...     0               0
# 3  unreal! house moves to ban sale or display of ...     0               0
# 4  democrat accused of sexual harassment just thr...     0               0

# %%
#dev_set_df.to_csv('isot_dev_set.csv', sep=',')

# %%
print('clf.feature_count_ :', clf.feature_count_.shape)

for i in range(2):   # 2 category labels
    print('\nMOST COMMON WORDS IN CLASS', i, '(Fake=0; Real=1)')
    print('%19s %12s %12s' %('WORD', 'Fake count', 'Real count'))
    for j in range(100):   # top x most frequent words for each class
        index = -1 - j
        feature_index = np.argsort(clf.feature_count_[i,:])[index]
        print('%19s %12d %12d' %(vectorizer.get_feature_names()[feature_index], clf.feature_count_[0,feature_index], clf.feature_count_[1,feature_index]))
    print()
# Out:
# clf.feature_count_ : (2, 18779)
#
# MOST COMMON WORDS IN CLASS 0 (Fake=0; Real=1)
#                WORD   Fake count   Real count
#                  to         6587         5401
#               trump         6494         3920
#               video         5952           18
#                 the         4417          396
#                  of         3570         2133
#                 for         3329         1991
#                  in         3259         3293
#                 and         2597          433
#                  on         2540         2328
#                  is         2031          304
#               obama         1820          455
#                with         1707         1047
#             hillary         1617           32
#               watch         1354           18
#               about         1197          182
#                 his         1140          151
#                  it         1136          173
#                  he         1095          244
#               after         1088          701
#                just          989           15
#                  at          969          630
#                  by          956          421
#                 you          920           20
#                this          908           76
#                from          868          512
#                 who          825           96
#           president          806          372
#             clinton          796          476
#                that          750          100
#                 are          735           55
#                 out          732          169
#                 not          722          565
#                over          694          708
#                  as          675          786
#                 her          671           31
#                will          662          508
#                 new          636          627
#            breaking          631            7
#                 why          624           15
#                  be          620          347
#                news          619           87
#               black          618           27
#                 him          615           48
#               white          607          557
#                  up          582          235
#              donald          579           39
#                 was          578           95
#                what          565           54
#                 how          565           55
#                 gop          550            5
#                 has          507          156
#                they          505           33
#             america          489           33
#              muslim          467           46
#               media          461          153
#                  we          450           35
#                 one          442           90
#                have          441          103
#                down          435           92
#                  us          433           18
#                gets          419           46
#                anti          418          141
#                 she          415           18
#              tweets          410           23
#                bill          398          490
#             against          398          303
#                says          394         2116
#                 cnn          382           33
#               house          367          998
#                 can          366          112
#              people          363           82
#               their          355           27
#                  if          346          142
#                 all          345           70
#            election          336          406
#                  no          330          307
#               calls          323          287
#                 fbi          323          134
#                when          322           17
#              racist          321            4
#                 fox          319           32
#                 off          317          100
#            campaign          310          202
#         republicans          302          231
#              during          297           65
#                 man          296           52
#                more          296          248
#               state          295          481
#                back          294          138
#                 won          291           74
#            american          290           33
#          republican          290          458
#                like          289           14
#             liberal          287            9
#                into          286          131
#            democrat          286           88
#              speech          284           90
#               makes          284           35
#                here          278            0
#                 gun          278           63
#
#
# MOST COMMON WORDS IN CLASS 1 (Fake=0; Real=1)
#                WORD   Fake count   Real count
#                  to         6587         5401
#               trump         6494         3920
#                  in         3259         3293
#                  on         2540         2328
#                  of         3570         2133
#                says          394         2116
#                 for         3329         1991
#                with         1707         1047
#               house          367          998
#                  as          675          786
#                over          694          708
#               after         1088          701
#              russia          275          671
#               north           78          653
#               korea           63          644
#                  at          969          630
#                 new          636          627
#                 not          722          565
#               white          607          557
#              senate          131          538
#               china           39          536
#                from          868          512
#                will          662          508
#               court          184          500
#                bill          398          490
#               state          295          481
#             clinton          796          476
#          republican          290          458
#               obama         1820          455
#                 tax          113          444
#                 and         2597          433
#                  by          956          421
#            election          336          406
#                  eu           23          399
#                 the         4417          396
#                 may          119          391
#                vote          251          386
#           president          806          372
#                deal          118          371
#                iran          142          371
#               talks           15          362
#                  be          620          347
#                  pm           12          337
#            minister           36          330
#               south           24          329
#               syria           97          321
#              brexit           13          309
#                  no          330          307
#                  is         2031          304
#             against          398          303
#               chief           94          296
#             factbox            0          296
#          government          146          294
#               calls          323          287
#              police          273          285
#              leader           98          281
#              turkey           10          278
#               probe           37          266
#            congress          114          265
#             russian          204          264
#                  uk           30          257
#               party          192          254
#           sanctions           13          250
#                more          296          248
#                plan          122          246
#                  he         1095          244
#            official           74          237
#             nuclear           69          236
#                  up          582          235
#            military           87          233
#         republicans          302          231
#                 top          157          229
#            security          119          228
#                  ex           33          224
#            governor          113          214
#                 ban          119          214
#               saudi           37          213
#                 law          190          209
#           democrats          268          202
#            campaign          310          202
#           lawmakers           16          200
#               urges            4          197
#             myanmar            0          196
#               trade           11          192
#               putin          107          192
#             sources           13          191
#        presidential           87          191
#             senator          183          190
#          opposition            4          190
#             foreign          104          190
#          healthcare           70          189
#              former          226          188
#             islamic           64          188
#              mexico           67          185
#               about         1197          182
#              attack          209          182
#              border           84          182
#              syrian           52          178
#              german           35          177
#             britain           21          176

# %% [markdown]
# #### Many words in the Title show an imbalance between Fake News and Real News.  For example, "trump" is favored by nearly a 2:1 ratio in Fake vs. Real news.  "hillary" is favored by ~ 400:1 in Fake vs. Real news.  "watch" is favored ~ 700:1 in Fake vs. Real news.  Words such as "he", "his", "she", "her", "him", "it", "they", "them", "we", "us", "like", "here", "donald", "gop", "liberal",  "media", "america", "muslim", "racist", "breaking", are also heavily favored in Fake news in this dataset.

# %%
## Print out top MISCLASSIFICATIONS

# Make predictions on the dev data and show the top n documents where the ratio R is largest, where R is:
# R = maximum predicted probability / predicted probability of the correct label

n=2000
print('X_dev_transformed.shape:', X_dev_transformed.shape)  # (6735, 18745)
print()

r_array = np.zeros(X_dev_transformed.shape[0])  # one array element for each dev example (6735)
for i in range(X_dev_transformed.shape[0]):
    max_pred_prob = np.max(clf.predict_proba(X_dev_transformed)[i,:])
    #print(max_pred_prob)
    correct_label = int(dev_labels[i])
    pred_prob_correct_label = clf.predict_proba(X_dev_transformed)[i,correct_label]
    R = max_pred_prob / pred_prob_correct_label
    r_array[i] = R

print('max R:', np.max(r_array)) 
#print('mean R:', np.mean(r_array))
sorted_r = -np.sort(-r_array)
print()

cols = ['text', 'label', 'pred_class', 'R']
row_list = []

for i in range(n):
    index = -1 - i
    label_index = np.argsort(r_array)[index]
    print('R:', r_array[label_index])    
    print('\nDev Title',str(label_index)+':\n', dev_data[label_index])
    print('\nLABEL =', dev_labels[label_index])
    print('predicted class =', clf.predict(X_dev_transformed)[label_index],'\n' )
    print(70*'-')
    row_list.append(dict( [('text',dev_data[label_index]), ('label', dev_labels[label_index]), 
                         ('pred_class', clf.predict(X_dev_transformed)[label_index]), ('R', r_array[label_index])]  ))


error_df = pd.DataFrame(row_list, columns=cols)
#error_df.loc[i] = [dev_data[label_index], dev_labels[label_index], clf.predict(X_dev_transformed)[label_index], r_array[label_index]]
# Out:
# X_dev_transformed.shape: (6735, 18779)
#
# max R: 4999260.399758549
#
# R: 4999260.399758549
#
# Dev Title 4655:
#  stockholm study: us & europe top arms trade globally – saudi arabia’s weapons imports skyrocket over 200 percent
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 4999260.399758549
#
# Dev Title 6658:
#  stockholm study: us & europe top arms trade globally – saudi arabia’s weapons imports skyrocket over 200 percent
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 385986.37565659604
#
# Dev Title 4432:
#  russian lawmaker warns: north korea ready to launch missile capable of hitting u.s.
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 192188.46410006026
#
# Dev Title 6270:
#  n. korea’s latest missile launch aimed at testing carrying “large scale heavy nuclear warhead”
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 30778.045745197414
#
# Dev Title 3734:
#   trump’s plan to rein in wall street? tax cuts, no oversight, industry insiders in the white house
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 27702.044695647044
#
# Dev Title 3634:
#  trump says 'nothing funny' about 'saturday night live,' but audience soars
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 20966.055827336822
#
# Dev Title 1916:
#  forsaken sultan: erdogan isolated ahead trump meeting in washington
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 19843.2387581486
#
# Dev Title 2491:
#  north korea: trump’s recklessness could trigger all-out conflict on korean peninsula
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 4512.152971910082
#
# Dev Title 3903:
#  trump cabinet's first world problem: omitting a few million here and there
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 4166.1090042451715
#
# Dev Title 1577:
#  “senior u.s. official” releases damaging information on russian involvement in syria gas attack
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 3364.9234883189138
#
# Dev Title 4081:
#  judge seals all video depositions in clinton email case: the hill
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 3234.2914365259835
#
# Dev Title 836:
#  sweet home chicago: obama re-emerges in city where it all began
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 2690.4786993879184
#
# Dev Title 4510:
#  gop voters like trump despite seeing him as not religious: poll
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1887.537487680782
#
# Dev Title 1865:
#  art of the spin: trump bankers question his portrayal of financial comeback
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1861.8491280325363
#
# Dev Title 3802:
#  sec of state rex tillerson: “steps are under way” to remove syria’s bashar al-assad…“russian government” should “consider carefully continued support for assad regime” [video]
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1546.2108514679142
#
# Dev Title 5770:
#  trump finally backs off obama birth claim, falsely says clinton started it
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1485.8108889636974
#
# Dev Title 4082:
#  washington state judge issues temporarily block on trump’s immigration ban nationwide
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1447.913675874145
#
# Dev Title 2064:
#  tears and joy on britain’s st. helena as 'world's most useless airport' finally opens
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1349.149073581865
#
# Dev Title 492:
#  putin accuses u.s. of leaking flight path of russian plane shot down by turkey…turkey buying isis oil
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1255.2171686495828
#
# Dev Title 3541:
#   house gop holds zika bill hostage, proposes plan to slash birth control funding
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1248.2603433736647
#
# Dev Title 4127:
#  wmd fraud: sexed-up un ‘chemical weapons’ report on syria contrived to trigger more sanctions, intervention
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1248.2603433736647
#
# Dev Title 3781:
#  wmd fraud: sexed-up un ‘chemical weapons’ report on syria contrived to trigger more sanctions, intervention
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1212.7196314056837
#
# Dev Title 3432:
#  disillusionment, u.s.a. where voters are just hoping for change.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 965.6425526478383
#
# Dev Title 1414:
#  what do i need to know about the cia's hacking program?
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 959.6114597541324
#
# Dev Title 35:
#   report: trump businesses seeking dozens of special visas for foreign workers
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 927.2517247882342
#
# Dev Title 5876:
#  special report: why an emblematic american city has turned to trump
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 864.763302512889
#
# Dev Title 1072:
#  trump: sexual-assault accusers 'want to stop our movement'
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 862.4398072879025
#
# Dev Title 4552:
#  donald trump jr. appears with white supremacist on radio show
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 856.838327166791
#
# Dev Title 5282:
#  senator rand paul returns to work after being tackled while mowing lawn
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 818.5140955221691
#
# Dev Title 5723:
#  obama: trump doesn't know much about foreign policy, world
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 771.6786081058149
#
# Dev Title 560:
#  daughter chelsea casts clinton as great mom, driven public servant
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 734.5222398143559
#
# Dev Title 6317:
#  what's a 'dotard' anyway? kim's insult to trump
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 734.5222398143559
#
# Dev Title 5589:
#  what's a 'dotard' anyway? kim's insult to trump
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 632.9332701379245
#
# Dev Title 5015:
#  facebook partners with news outlets for election day live video blitz
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 591.5640016631653
#
# Dev Title 3485:
#   china warns trump: provoke north korea and ‘pay the price’
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 528.373025346269
#
# Dev Title 3039:
#  'we like paris but are a bit scared,' chinese tourists say after muggings
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 368.7874037933966
#
# Dev Title 6335:
#  billy bush: it was trump's voice on "access hollywood" tape
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 346.0775272578834
#
# Dev Title 71:
#   tennessee house speaker warns interns to stay far away from sleazy male lawmakers
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 260.69209814191305
#
# Dev Title 3994:
#  many 'lost' voters say they have found their candidate in trump
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 256.9547765647772
#
# Dev Title 620:
#  trump campaign manager says he called reporter after run-in: cnn
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 235.51011961339083
#
# Dev Title 5159:
#  jimmy carter: ‘koreans want peace treaty to replace 1953 ceasefire’
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 232.97467671065206
#
# Dev Title 6198:
#  teen jackie evancho first singer confirmed for trump inauguration
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 224.5916777161191
#
# Dev Title 2246:
#  indian hindu tried to raise money with video of killing of muslim: police
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 215.41896683683402
#
# Dev Title 5216:
#  trump revives keystone and dakota access pipelines
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 210.42855495182928
#
# Dev Title 3604:
#  north korean mock-up birthday video shows missiles blowing up u.s.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 205.87427957135998
#
# Dev Title 85:
#  canada sends troops to u.s. border to deal with illegals and asylum seekers running from trump’s new policies on immigration
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 181.17619017122718
#
# Dev Title 2526:
#  text: mitt romney speech slamming donald trump
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 167.989242376205
#
# Dev Title 4793:
#  pence not offended by comments to him at 'hamilton' show
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 162.23182876673704
#
# Dev Title 3868:
#  hillary clinton makes surprise appearance at new york film panel
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 158.03087690546639
#
# Dev Title 114:
#  obama’s epa pushes for tougher mileage standards for trucks
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 134.6350165378123
#
# Dev Title 5999:
#  trump allies falsely link reuters to claim detroit video feed was cut short
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 127.01834381539528
#
# Dev Title 4439:
#  top us spy agency refuses to endorse cia’s ‘russian hacking’ assessment due to “lack of evidence”
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 124.85594777524324
#
# Dev Title 2038:
#  official photo released to mark 70th wedding anniversary of queen elizabeth
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 120.52612988177677
#
# Dev Title 4406:
#  trump on putin: 'we get along very, very well' - cbn interview
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 119.53710958663243
#
# Dev Title 386:
#  schwarzenegger fired, didn't quit 'apprentice': trump
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 102.09176423505026
#
# Dev Title 3839:
#  hud asks for $4 billion more after spending millions on lobbying congress???
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 101.27207597715916
#
# Dev Title 5462:
#  fake ‘us embassy’ bust in ghana exposes danger of eu schengen deal with turkey
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 101.27207597715916
#
# Dev Title 2537:
#  fake ‘us embassy’ bust in ghana exposes danger of eu schengen deal with turkey
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 100.28352013272593
#
# Dev Title 5080:
#  senators up in arms over obama administration plans to move gitmo to two different states
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 98.83618327931282
#
# Dev Title 2621:
#  u.s. apologizes for human rights violations at u.n. review to countries with worse human rights violations
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 92.95696500681166
#
# Dev Title 3010:
#  man who accused seattle mayor of sexual abuse drops lawsuit
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 88.12632972658922
#
# Dev Title 3068:
#  israel will name new train station near western wall after president donald trump
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 84.63573898701779
#
# Dev Title 1707:
#  firebrand milo quits breitbart news after child sex remarks
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 84.49906889494906
#
# Dev Title 5684:
#  woman who accused bill clinton of assault to campaign against hillary presidential run
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 81.08262170678785
#
# Dev Title 1501:
#   it begins: supreme court rejects racially gerrymandered n.c. districts
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 80.98881010269943
#
# Dev Title 4438:
#  former fox news chief ailes is not advising trump: campaign
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 75.48436637839737
#
# Dev Title 118:
#  immigrants across the u.s. skip work, school in anti-trump protest
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 75.24452296488349
#
# Dev Title 2790:
#  obama to protesters: we're all americans - white house
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 72.45882345904435
#
# Dev Title 2452:
#   several bars will be opening early thursday for comey’s hearing, serving cheap russian vodka
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 71.75524926065182
#
# Dev Title 5339:
#  brief overview: us military sales to lebanon
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 69.81978684094798
#
# Dev Title 5125:
#  without evidence, trump launches 59 cruise missiles, destroying syrian air force base
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 68.57197011221045
#
# Dev Title 3680:
#  russia’s strange 45-acre maryland compound closed down to punish diplomats
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 65.31641131628749
#
# Dev Title 1637:
#  clinton turns down fox news offer to debate sanders again
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 63.42803373596544
#
# Dev Title 261:
#  the final control: tpp, ttip, tisa global corporate takeover
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 60.52574756343899
#
# Dev Title 5543:
#  obama to democrats: 'i want us to run scared' in election
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 58.53700561362937
#
# Dev Title 6192:
#  u.s. congressman to resign after report alleged he asked woman to have an abortion
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 54.926465923857016
#
# Dev Title 77:
#  biden says obama won't be able to pick the 'most liberal jurist'
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 54.704510556540754
#
# Dev Title 819:
#  blue-collar democrats to party: it's still the economy, stupid
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 54.4729823552668
#
# Dev Title 3935:
#  sterling quarterback crop lead way into the playoffs
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 49.07837750782733
#
# Dev Title 3822:
#  asked about russia sanctions, trump says 'we ought to get on with our lives'
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 48.510440088780946
#
# Dev Title 5085:
#  in georgia, a democrat's 'make trump furious' campaign rattles republicans
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 48.106117015749305
#
# Dev Title 1452:
#  family of australian woman fatally shot wants minnesota cop charged
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 43.653004435901174
#
# Dev Title 5633:
#  obama torches trump at his final washington correspondents' dinner
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 43.37344871969161
#
# Dev Title 3052:
#  comey to confirm trump pressured him on flynn investigation: cnn
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 43.27341513679046
#
# Dev Title 3362:
#  german police arrest man after posting photo of child abuse victim
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 42.96767096231324
#
# Dev Title 6562:
#  obama on fbi: 'we don't operate on innuendo,' leaks
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 41.60854344326593
#
# Dev Title 3406:
#  baseball field shooting shakes american symbol of fair play
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 41.412201772009496
#
# Dev Title 6097:
#  powell reveals disgust with trump, distaste for clinton in hacked emails
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 41.18756515969392
#
# Dev Title 508:
#  peter thiel tells republican convention he is 'proud to be gay'
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 40.74668265940241
#
# Dev Title 51:
#  republicans block pentagon’s climate scam plan
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 40.408837203123674
#
# Dev Title 2117:
#  the jerusalem decision: from creative chaos to effective turmoil
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 40.17367553272998
#
# Dev Title 2378:
#   trump considers ‘terminating nafta’ with executive order (details)
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 37.38443553653345
#
# Dev Title 481:
#  internet giants, once above the fray, on the defensive in washington
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 37.366783528470094
#
# Dev Title 2339:
#  'i feel like i'm going crazy:' migrant health crumbles in greece
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 34.94894036663322
#
# Dev Title 4941:
#   clinton promises plan to overturn citizens united in first 30 days
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 34.769051336804985
#
# Dev Title 4494:
#  michigan senate approves bill to allow concealed carry in “gun free zones” or “mass murderer empowerment zones”
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 34.54858755307247
#
# Dev Title 6618:
#  no transparency on trade bill from the most transparent administration in history
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 31.418868605001208
#
# Dev Title 4738:
#  trump jr. was told of russian effort to help father's campaign: ny times
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 30.866360321457318
#
# Dev Title 2438:
#   lawsuit filed against intelligence agencies for records on russian election tampering
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 28.297874891311547
#
# Dev Title 3439:
#  mcconnell calls army captain khan 'an american hero'
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 28.141544173081584
#
# Dev Title 34:
#   trump threatens government shutdown if congress doesn’t approve billions to fund his border wall
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 27.640885508828674
#
# Dev Title 1833:
#   poll: clinton ahead of trump by a staggering 12 points
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 26.14111798306174
#
# Dev Title 6544:
#  waving german flag, far-right and anti-islam groups rally together before vote
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 25.023334957016857
#
# Dev Title 6059:
#  clinton attacks trump's outreach to black voters in new ad
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 24.953894231467242
#
# Dev Title 2116:
#  u.s. state department tweets, then deletes congratulations for iran oscar win
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 24.599802438453995
#
# Dev Title 619:
#  clinton's it aide to plead the fifth in email lawsuit: the hill
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 22.955570315306826
#
# Dev Title 651:
#  cpac says trump drops out at 'last minute'
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 22.24789289877772
#
# Dev Title 5793:
#   trump plans to issue executive order allowing cia to use torture
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 22.044218392086
#
# Dev Title 1809:
#   three key states turn themselves solidly blue as trump train derails
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 21.43226005987349
#
# Dev Title 1308:
#   kentucky republicans propose bill to delay school year to accommodate creationist museum
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 21.316950150014712
#
# Dev Title 5137:
#  first $200 admission for a trump rally; more to come?
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 20.996484321775675
#
# Dev Title 5220:
#  ex-president george h.w. bush moved to intensive care; wife hospitalized
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 19.666827472245497
#
# Dev Title 4398:
#  kerry warns against pointing finger at religion after orlando
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 19.64308846460718
#
# Dev Title 5357:
#   house republicans forcing fetal tissue researchers to reveal identities despite risk of violence
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 19.528734228903026
#
# Dev Title 1874:
#  hillary clinton for nyc mayor? probably not, but rumors persist
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 18.82521068186602
#
# Dev Title 4896:
#  obama jokes about a trump state of the union address
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 18.779079846244002
#
# Dev Title 1271:
#  trump wins! supreme court rules on travel ban in unanimous decision [video]
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 18.61669357792454
#
# Dev Title 4295:
#  obamacare sign-up challenge: proving the law is not dead
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 18.56752032279268
#
# Dev Title 2080:
#   former candidate ben carson declines trump cabinet position, cites lack of experience
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 18.403963084627716
#
# Dev Title 1195:
#  trump executive order on ethics commitments bans lobbying for executive branch employees
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 17.782439627618402
#
# Dev Title 5730:
#  trump asks congress to investigate former obama administration
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 17.74711254348765
#
# Dev Title 6703:
#   illinois republicans attack single mothers, want to deny children aid for being fatherless
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 17.659607587205127
#
# Dev Title 2164:
#   new poll: clinton picks up unprecedented, historical support among young voters
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 17.647625842118615
#
# Dev Title 2149:
#   military expert vows to take trump up on his challenge
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 17.223756963351764
#
# Dev Title 3647:
#  bill clinton delivers defense of his foundation's 'profound' work
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 16.749041611627835
#
# Dev Title 3224:
#  trump and christie laid foundation of their alliance years ago
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 16.256614654169244
#
# Dev Title 3866:
#  sketchy firm behind salacious allegations against trump tries to pull a fast one on senate judiciary committee
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 16.029568126269766
#
# Dev Title 1305:
#  war and the prize: how some nobel laureates turn away from peace
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 15.736107334117609
#
# Dev Title 860:
#  soros says hungarian government lying in attacks against him
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 15.681969413981458
#
# Dev Title 1370:
#  factbox: the nasty things trump, romney have said about each other
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 15.598815470475081
#
# Dev Title 1436:
#  white house intruder was on grounds for 16 minutes before arrest: secret service
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 15.53052427817532
#
# Dev Title 2802:
#  peace prize president obama approved $200 billion in arms deals since 2009
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 15.128557815777212
#
# Dev Title 5377:
#  sanders supporters seethe over clinton's leaked remarks to wall st.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 14.964002216740086
#
# Dev Title 1850:
#   idaho republican outrageously says female lawmakers only rise in rank by giving sexual favors
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 14.900760875937655
#
# Dev Title 3085:
#  syria: british and american presence directly escalating conflict near al-tanf
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 14.671471261388273
#
# Dev Title 2345:
#   republican leaders and activists plan to back third-party candidate if trump is nominated
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 14.621453403075156
#
# Dev Title 6147:
#  house democrats will stage sit-in until they get gun control bill: pelosi
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 14.255883726771996
#
# Dev Title 6001:
#  alert: flood of cubans breeze across texas border as tensions rise
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 14.035637417568832
#
# Dev Title 4354:
#  pope asks trump to be peacemaker, gives him environmental letter
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 14.023506524284855
#
# Dev Title 6330:
#  trump in mexico: outlines 5 goals he wants to accomplish with mexican government [video]
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 13.911434887524594
#
# Dev Title 226:
#  pay 2 play: democratic convention ends amid controversy, empty seats & white noise
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 13.839294940353287
#
# Dev Title 4382:
#  trump says he had very good meeting with ryan: fox news
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 13.736180369463934
#
# Dev Title 4036:
#  guantanamo jihadist freed after murder of sfc christopher speer
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 13.400524463156211
#
# Dev Title 2410:
#  as trump’s popularity soars abroad…village in india renames itself “trump” [video]
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 12.628475798793307
#
# Dev Title 444:
#  u.s. knew of indonesian anti-communist massacre as it unfolded
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 12.595903200216444
#
# Dev Title 4358:
#  pope says its crazy to see his meeting with bernie sanders as political
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 12.573679726102084
#
# Dev Title 2853:
#  trump's team seeks top-secret clearance for his children: cbs news
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 12.44116006527581
#
# Dev Title 4416:
#  senator gillibrand calls trump twitter post 'sexist smear'
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 12.420059310263946
#
# Dev Title 1138:
#  beating rivals and the odds, trump captures republican nomination
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 11.901766546374791
#
# Dev Title 136:
#  ex-south carolina cop gets 20 years in prison for black motorist's death
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 11.551361005010207
#
# Dev Title 1232:
#  clinton accuses trump of scapegoating muslim soldier's parents
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 11.408098697286734
#
# Dev Title 6447:
#  trump says north korea's kim insulted him by calling him 'old'
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 11.341127105121318
#
# Dev Title 3097:
#  obama visits a mosque to send pointed message to non-muslims
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 11.22844529292499
#
# Dev Title 11:
#  no love lost with daily news after trump wins new hampshire
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 11.190961017291563
#
# Dev Title 28:
#   a bi-partisan miracle: federal employee health plans add critical autism benefit
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 11.090813605823751
#
# Dev Title 87:
#  clinton tells wells fargo customers ceo owes them an explanation
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 10.765162275357437
#
# Dev Title 3133:
#  filmmaker michael moore launches 'trumpileaks' website for whistleblowers
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 10.52189027265216
#
# Dev Title 6608:
#  trump tells state department to make cut more than 50% of funding to u.n.
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 10.198961202017005
#
# Dev Title 5783:
#   senate gives trump jr. ultimatum: respond by friday or face subpoena
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 10.129908188171132
#
# Dev Title 277:
#  bill clinton, tim kaine cancel iowa event after police shooting
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 9.94694774806254
#
# Dev Title 4377:
#  tiffany & co. takes big risk…sides against trump on very controversial issue
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 9.755222672868836
#
# Dev Title 5452:
#  in ohio, a struggle for the soul of the democratic party is playing out
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 9.723915256714237
#
# Dev Title 4538:
#  trump celebrates first 100 days as president, blasts media
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 9.552786196296262
#
# Dev Title 2049:
#  danish submarine owner has not said how journalist died: police
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 9.395679341899559
#
# Dev Title 2142:
#  president obama arrives in cuba
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 9.329602276882037
#
# Dev Title 3695:
#  sales to people on terrorism watch lists should be delayed: nra
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 9.036529976072396
#
# Dev Title 5702:
#  clinton aide abedin leaves husband weiner after sexting report
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 8.849579356877735
#
# Dev Title 5822:
#  senate passes usa freedom act
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 8.790755418682808
#
# Dev Title 934:
#   petty north carolina gop governor signs bills crippling power of his democratic successor
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 8.71710619892388
#
# Dev Title 2775:
#  in day of pro-trump rallies, california march turns violent
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 8.580654387181724
#
# Dev Title 1416:
#  trump's san diego rally draws more than 1,000 chanting protesters
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 8.40401603653618
#
# Dev Title 2585:
#  u.s. towns, cities fear taxpayer revolt if republicans kill deduction
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 8.242919773512586
#
# Dev Title 5145:
#  iran ‘will respond’ if us moves to designate revolutionary guard as ‘terrorist group’
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 8.108206835712128
#
# Dev Title 6438:
#  'big bang theory' trumps tv audience for latest republican debate
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 8.092724609817811
#
# Dev Title 2665:
#  'i'm not ranting and raving.' trump on defensive in first solo news conference
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 8.018454118607632
#
# Dev Title 1787:
#  the court case against the ‘travel ban’ executive order
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 7.948725485625958
#
# Dev Title 3737:
#   trump cancels trip to israeli historic site after authorities say he can’t land his helicopter on it
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 7.6343875943097625
#
# Dev Title 1792:
#  trump says he is sending federal help to fight chicago crime
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 7.596599449347801
#
# Dev Title 4172:
#  democrat clinton picks kaine as running mate, bypassing liberals
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 7.466217839694508
#
# Dev Title 6431:
#  swiss right-wing's blocher: trump win a warning to world establishment
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 7.196510269279182
#
# Dev Title 3381:
#  women knit pink 'pussyhats' for rally after trump inauguration
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 7.021050846802303
#
# Dev Title 4336:
#  breaking: close aide to bill clinton: “i arranged for $50 million in payments to bill clinton”
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 6.740446216757144
#
# Dev Title 5710:
#   republican senator blasts trump’s administration for ‘unconstitutional’ attempt to hide information from congress
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 6.5831573852874365
#
# Dev Title 234:
#  hackers play 30 minutes of islamic state propaganda on swedish radio
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 6.531623250848522
#
# Dev Title 4571:
#  clinton campaign: no evidence computer systems were compromised
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 6.438171191850898
#
# Dev Title 98:
#   republican greg abbott picks supporting israel over obama – plans with bibi to antagonize iran
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 6.192883595798445
#
# Dev Title 4947:
#  expert claims n. korea’s second missile test demonstrates they now have ability to hit 3 major cities on u.s. mainland
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 6.135624212418609
#
# Dev Title 5335:
#  suffering from pneumonia, clinton falls ill at 9/11 memorial, cancels california trip
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 6.127633327176993
#
# Dev Title 4214:
#   marvel vows to boycott georgia if discriminatory religious liberty bill becomes law
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 6.1092024115427845
#
# Dev Title 4234:
#  comey testimony disturbing, trump appears to threaten job: warner
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.945849090675138
#
# Dev Title 3989:
#  factbox: what trump has said about the united nations
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.945849090675138
#
# Dev Title 3575:
#  factbox: what trump has said about the united nations
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.752864529926792
#
# Dev Title 5860:
#  charlottesville schools, parents address children's fears after violence
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.74210866722101
#
# Dev Title 5741:
#  trump is now president, but he still sees himself as leading an insurgency
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.679597184238831
#
# Dev Title 6365:
#  trump pushes melania back onto campaign stage: interview
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.5764399563187546
#
# Dev Title 6263:
#  chinese fans prepare to welcome rich, powerful, 'free-spirit' trump
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.488134518677546
#
# Dev Title 3980:
#  leftists on cusp of power as weary icelanders go to polls
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.307475544916306
#
# Dev Title 5923:
#  trump backers sue san jose for allowing 'mob' assault
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.303321569950477
#
# Dev Title 594:
#  for republican rubio, a moment of truth in race to lead u.s.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.289700425637826
#
# Dev Title 5746:
#  trump's unpredictability already troubles u.s. friends
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.274997244346395
#
# Dev Title 3267:
#  trump not planning to invoke executive privilege for comey testimony: ny times
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.271686493326033
#
# Dev Title 2462:
#  trump to fundraise for campaign if he wins republican nomination: cnn
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.216285197484675
#
# Dev Title 4726:
#  democrats' new line on gun control: do it for national security
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.19977354396626
#
# Dev Title 5804:
#  trump's opponents race to the courthouse to thwart him
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.173863409560183
#
# Dev Title 1118:
#  russia sets out why it thinks u.n. wrongly accused syria over sarin attack
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.15719812460325
#
# Dev Title 1229:
#  trump takes populist message to u.s. heartland in 'thank you' tour
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.134641765959553
#
# Dev Title 1899:
#  trading algorithm shows how mass shootings, politics boost gun shares
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.087541493042257
#
# Dev Title 3003:
#   dem. senator blasts mitch mcconnell for excluding women from panel drafting new senate health plan
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 5.034618804185088
#
# Dev Title 1120:
#   senator asks doj to step in after white supremacists vow to engage in poll watching
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 5.024745768964768
#
# Dev Title 227:
#  new york times stands by trump story, rebuts claim of libel
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.019481064502187
#
# Dev Title 3351:
#  scared by trump, some migrants on mexico border give up american dream
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 4.988175386826036
#
# Dev Title 3177:
#   case regarding cruz’s birthright citizenship reaches supreme court
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 4.875482140850389
#
# Dev Title 6049:
#  russian-american lobbyist met with trump jr., russian lawyer: nbc news
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 4.847491070506571
#
# Dev Title 1454:
#  democrat gun control sit-in sparks social media sensation
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 4.784578500422363
#
# Dev Title 3099:
#  mccain, once belittled by trump, hands him big defeat in healthcare vote
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 4.7723401611703835
#
# Dev Title 2441:
#  gitmo prisoner obama released in 2012 identified as al-qaeda leader in yemen
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 4.7723401611703835
#
# Dev Title 5729:
#  gitmo prisoner obama released in 2012 identified as al-qaeda leader in yemen
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 4.691303772536246
#
# Dev Title 135:
#  powerful koch brothers rebuff big donors' calls to back trump for white house
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 4.662172856420113
#
# Dev Title 1600:
#  trump’s awkward first date with frau merkel
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 4.662172856420113
#
# Dev Title 5791:
#  trump’s awkward first date with frau merkel
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 4.62570276678857
#
# Dev Title 803:
#  suspicious substance at cruz's houston headquarters is non-toxic
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 4.494581840079912
#
# Dev Title 644:
#  is the sky blue? depends on what donald trump says
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 4.430637120236317
#
# Dev Title 3481:
#  canada's liberals look to economy to guide them past ethics scandal
#
# LABEL = 1
# predicted class = 0
#
# ...
# R: 1.0
#
# Dev Title 626:
#  trump leaves some on wall street wary and confused
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 548:
#  somali refugee faces terror charges in canada stabbing, car attacks
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 547:
#   here’s a long list of bernie sanders’ accomplishments (with citations)
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 546:
#  clinton aide abedin seeks to review clinton emails search warrant
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 476:
#  exclusive: trump says republican border tax could boost u.s. jobs
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 466:
#  eu embassies urge romania to rethink judicial overhaul
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 467:
#  body language expert gives clear examples of susan rice lying about trump surveillance during interview [video]
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 468:
#   bombshell: the trump foundation cannot legally raise money
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 469:
#  republican senator collins likely 'yes' vote to advance tax reform
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 470:
#  senator hatch to healthcare protesters: ‘if you want a hearing, you better shut up’ [video]
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 471:
#   creepy: trump promised teenage ivanka he’d never date anyone younger than she is (audio)
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 472:
#  powerful letter to cowardly steelers coach will make you want to stand up and cheer: “you’ve taken something that unites americans of every color, creed, and religion and managed to divide them”
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 473:
#  mainstream media ignores massive protest against obama’s sweetheart deal for corporations: “biggest protest this country has seen for many, many years”
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 474:
#  iranian, iraqi government forces to hold joint border drills - iran tv
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 475:
#  u.s. lawmakers want 'supercharged' response to north korea nuclear tests
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 477:
#  wow! “‘haley’s’ comet” just collided with hypocritical, anti-israel, terror-nation supporting u.n.…and the results were spectacular! [video]
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 490:
#  police detain dozens in moscow amid fear of anti-government attacks
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 478:
#  in the age of amazon, are traditional shopping malls dead?
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 479:
#  wow! legal hispanic american immigrant unloads on racist hillary supporters: “liberals are desperate because they know they’re gonna lose” [video]
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 480:
#   trump’s white house implodes as kellyanne conway attacks fellow top staffer (video)
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 482:
#  nation of islam joins #blacklivesmatter terrorists to shut down chicago’s popular “miracle mile” on busiest shopping day of year [videos and photos]
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 483:
#  awesome! tucker carlson and stephen cohen: “something’s going on…i’ve never seen anything like this” [video]
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 484:
#  trump would undo obama's cuba moves unless religious freedom allowed
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 485:
#  trump decides against russia 'war room' in the white house: official
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 486:
#  17-year-old danish girl jailed for planning bomb attacks on schools
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 487:
#  syrian army, allies break islamic state siege in eastern city
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 488:
#  msnbc’s mika attacks melania trump…a furious melania issues immediate response
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 465:
#   you won’t believe who the white house wants to replace scaramucci with
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 464:
#   jorge ramos slams fox hosts o’reilly and hannity for coddling trump (video)
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 463:
#  turkish mayor says forced to quit in erdogan purge of local government
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 462:
#  flake's retirement could upend senate race in arizona
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 439:
#  katie couric tweets disgust after two of her producers are sprayed with urine at charlottesville protest…doesn’t mention antifa thugs sprayed them
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 440:
#  nfl nightmare continues…seahawks player caught on video taunting female officer during arrest: “are you scared of me?”…“i got a lot of f**king money you broke-ass n*ggas”
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 441:
#  trump discusses gulf-qatar dispute with erdogan: white house
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 442:
#  watch: black trump supporter blasts ca city council over “racist” sanctuary cities…and it’s spectacular!
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 443:
#   breaking: russia scandal explodes in trump admin.; top russian stooge is out
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 445:
#  white house says trump to sign spending bill thursday or friday
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 446:
#   petition demanding the electoral college take action to stop trump has just made history
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 447:
#  what the media’s not telling you about the manchester terror attack [video]
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 448:
#  pope's comments on trump not a personal attack: papal spokesman
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 449:
#  ‘half my family’ is here illegally!…state senator wants entire state to be sanctuary state [video]
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 450:
#   watch elizabeth warren clobber trump and scott brown: ‘celebrity apprentice meets biggest loser’
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 451:
#  trump meets wireless, drone executives on new technologies
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 452:
#  exclusive: trump says he does not fault son for meeting russian lawyer
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 453:
#   recused house russia investigation committee member didn’t really recuse himself at all
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 454:
#   sarah palin calls for executing democratic ‘cheaters’ on election day
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 455:
#  this company puts up a billboard that finally gets #blacklivesmatter right… without the racist connotation
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 456:
#  group of 40 u.s. house democrats oppose delay of labor dept retirement rule
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 457:
#  former presidential rival jeb bush says he will not vote for trump
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 458:
#  (video) repeat offenders: clintons corralled the press in 1992
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 460:
#  icelandic voters give center-left opposition narrow win in parliament
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 461:
#  yahoo caves in to nsa, fbi – and secretly monitors customer email accounts for us gov’t
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 489:
#  south korea finds traces of radioactive gas, 'can't yet link it' to nuclear test
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 491:
#  white house says expects guantanamo transfers announced before jan. 20
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 545:
#  trump's 'big announcement' on tax to be broad principles: official
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 533:
#  wow! jeb bush claims roy moore should “step aside” on same day sixth woman accuses george hw bush of sexual assault: groped her when she “was a child”
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 522:
#  sara carter and jay sekulow with the latest on obama spying on trump: “i think this goes to the highest levels of the obama administration” [video]
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 523:
#  ‘angel’ moms of sons killed by illegals weigh in on rockville rape of 14-year old by illegals: “this poor child is scarred forever” [video]
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 524:
#  exclusive: trump to approve keystone xl at meeting with transcanada ceo - official
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 525:
#  trump's epa budget proposal targets climate, lead cleanup programs
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 526:
#  leaked email: hillary’s team caught bashing “backwards” catholics
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 527:
#  highlights: the trump presidency on march 21 at 6:14 p.m. edt
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 528:
#  louisiana governor urges tax hike, tapping reserves to fix budget gap
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 529:
#  key republican says trump must work with europe on iran
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 530:
#  new zealand's ruling party ahead after poll but kingmaker in no rush to decide
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 532:
#  america first! how trump’s silent majority is america’s brexit
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 534:
#   report: trump tried to pull his own saturday night massacre, wh aides said hell no
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 493:
#  giuliani pulls out of consideration to serve in administration: trump
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 535:
#   trump comes unglued, continues miss universe feud with insane early morning twitter rant
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 536:
#  wow! trump reveals embarrassing story about anti-trump msnbc hacks “crazy mika” and “psycho joe” [video]
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 537:
#  malaysia's dissent on myanmar statement reveals cracks in asean facade
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 538:
#  the very idea of a president trump scares some, bolsters others in asia
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 539:
#  france opens door to strengthen iran nuclear deal for post-2025
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 540:
#   barbaric bullies set disabled 13-year-old boy on fire (video)
#
# LABEL = 0
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.0
#
# Dev Title 541:
#  nepal holds final round of municipal polls, ethnic grievances remain
#
# LABEL = 1
# predicted class = 1
#
# ----------------------------------------------------------------------

# %%
print(error_df.size)
print(len(error_df))
error_df.head()
# Out:
# 8000
# 2000
#                                                 text label pred_class  \
# 0  stockholm study: us & europe top arms trade gl...     0          1
# 1  stockholm study: us & europe top arms trade gl...     0          1
# 2  russian lawmaker warns: north korea ready to l...     0          1
# 3  n. korea’s latest missile launch aimed at test...     0          1
# 4   trump’s plan to rein in wall street? tax cuts...     0          1
#
#               R
# 0  4.999260e+06
# 1  4.999260e+06
# 2  3.859864e+05
# 3  1.921885e+05
# 4  3.077805e+04

# %%
error_df.to_csv('nb_isot_title_errors.csv', sep=',')

# %% [markdown]
# ### Using the ISOT "title" model, predict the ISOT "text" classes

# %%
train_data, train_labels = train_set.title.str.lower().values, train_set.target.values
dev_data, dev_labels = dev_set.text.str.lower().values, dev_set.target.values

train_labels = train_labels.astype(int)
dev_labels = dev_labels.astype(int)

#train_data.head()
print('train_data shape:', train_data.shape)
#print(train_data[0].shape)
print(train_data[:1])
print('\ntrain_labels shape:', train_labels.shape)
print(train_labels)

print('dev_data shape:', dev_data.shape)
# Out:
# train_data shape: (31428,)
# ['senate panel sets hearing for trump tax nominee']
#
# train_labels shape: (31428,)
# [1 0 1 ... 0 1 0]
# dev_data shape: (6735,)

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(train_data)
X_dev_transformed = vectorizer.transform(dev_data)

print('X.shape:', X.shape)
print('X_dev_transformed.shape:', X_dev_transformed.shape)

# MultinomialNB
print('\nMultinomialNB trained using ISOT "title" field; predict ISOT "text" classes')
alpha = 1.0
clf = MultinomialNB(alpha=alpha)
clf.fit(X, train_labels)

print('accuracy: %3.3f' %clf.score(X_dev_transformed, dev_labels))
# Out:
# X.shape: (31428, 18779)
# X_dev_transformed.shape: (6735, 18779)
#
# MultinomialNB trained using ISOT "title" field; predict ISOT "text" classes
# accuracy: 0.771

# %% [markdown]
# ### Using the ISOT "title" model, predict the liar_dev_labels and score the predictions. (lower case them first...)

# %%
#train_data, train_labels = train_set.title.values, train_set.target.values   # original ISOT data
train_data, train_labels = train_set.title.str.lower().values, train_set.target.values   # original ISOT data

#dev_data = liar_data.title[liar_data.binary_target != -1].values  
dev_data = liar_data.title[liar_data.binary_target != -1].str.lower().values                                            # full LIAR data
dev_labels = liar_data.binary_target[liar_data.binary_target != -1].values

train_labels = train_labels.astype(int)
dev_labels = dev_labels.astype(int)

#train_data.head()
print('train_data shape:', train_data.shape)
#print(train_data[0].shape)
print(train_data[:1])
print('train_labels shape:', train_labels.shape)
print(train_labels)

print('\ndev_data shape:', dev_data.shape)
print(dev_data[:1])
print('dev_labels shape:', dev_labels.shape)
print(dev_labels)
# Out:
# train_data shape: (31428,)
# ['senate panel sets hearing for trump tax nominee']
# train_labels shape: (31428,)
# [1 0 1 ... 0 1 0]
#
# dev_data shape: (10164,)
# ['we have a $2 trillion to $3 trillion infrastructure deficit. weve got work that needs to get done. weve got people that want to go to work.']
# dev_labels shape: (10164,)
# [1 0 0 ... 1 0 0]

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(train_data)           # original ISOT training data
X_dev_transformed = vectorizer.transform(dev_data)

# MultinomialNB
print('\nMultinomialNB using "title" field: Fit using ISOT data; Predict on LIAR data:')
alpha = 1.0
clf = MultinomialNB(alpha=alpha)
clf.fit(X, train_labels)

print('accuracy: %3.3f' %clf.score(X_dev_transformed, dev_labels))
# Out:
# MultinomialNB using "title" field: Fit using ISOT data; Predict on LIAR data:
# accuracy: 0.535

# %%
print('Non-zero elements in matrix (X.nnz):', X.nnz)   # This indicates that there are z non-zero elements in the matrix.
print('Average number of non-zero features per example (per document): %.3f' %(X.nnz/X.shape[0]))  # non-zero elements in matrix / documents = xxx
# Out:
# Non-zero elements in matrix (X.nnz): 381492
# Average number of non-zero features per example (per document): 12.139

# %%
print('Non-zero elements in matrix (X_dev_transformed.nnz):', X_dev_transformed.nnz)   # This indicates that there are z non-zero elements in the matrix.
print('Average number of non-zero features per example (per document): %.3f' %(X_dev_transformed.nnz/X_dev_transformed.shape[0]))  # non-zero elements in matrix / documents = xxx
# Out:
# Non-zero elements in matrix (X_dev_transformed.nnz): 154189
# Average number of non-zero features per example (per document): 15.170

# %%
#print(X_dev_transformed)
print(train_data)
# Out:
# ['senate panel sets hearing for trump tax nominee'
#  '“woody” kaine one of six arrested after peaceful pro-trump supporters were attacked by violent rioters at mn state capitol [video]'
#  'armed faction takes over protection of libyan oil and gas complex, fresh concern over migrants'
#  ...
#  'authorities allowed nyc chain migration terrorist to stop interrogation several times to pray after admitting he was triggered by christmas posters'
#  'unpopularity of clinton, trump puts spotlight on potential running mates'
#  'trump financial advisor has great tax news for job creators: “i think they need to get that done quickly”…maga! [video]']

# %%
print(dev_data)
# Out:
# ['we have a $2 trillion to $3 trillion infrastructure deficit. weve got work that needs to get done. weve got people that want to go to work.'
#  'says bag litter increased after san francisco banned single-use shopping bags.'
#  'human activity is not causing these dramatic changes to our climate.'
#  ...
#  'says that during his eight years as florida governor, we created 1.3 million net new jobs -- more jobs created than texas.'
#  'says chris koster fell silentas attorney general in pursuing a case against a free classified service accused of promoting prostitution after accepting over $12,000 in campaign contributions from people affiliated with the service.'
#  'the auditor [for the city of providence] was not locked out of access to the citys finances.']

# %%
## Print out top MISCLASSIFICATIONS

# Make predictions on the dev data and show the top n documents where the ratio R is largest, where R is:
# R = maximum predicted probability / predicted probability of the correct label

n=2000
print('X_dev_transformed.shape:', X_dev_transformed.shape)  # (10164, 18698)
print()

r_array = np.zeros(X_dev_transformed.shape[0])  # one array element for each dev example (6735)
for i in range(X_dev_transformed.shape[0]):
    max_pred_prob = np.max(clf.predict_proba(X_dev_transformed)[i,:])
    #print(max_pred_prob)
    correct_label = int(dev_labels[i])
    pred_prob_correct_label = clf.predict_proba(X_dev_transformed)[i,correct_label]
    R = max_pred_prob / pred_prob_correct_label
    r_array[i] = R

print('max R:', np.max(r_array)) 
#print('mean R:', np.mean(r_array))
sorted_r = -np.sort(-r_array)
print()

cols = ['text', 'label', 'pred_class', 'R']
row_list = []

for i in range(n):
    index = -1 - i
    label_index = np.argsort(r_array)[index]
    print('R:', r_array[label_index])    
    print('\nDev Title',str(label_index)+':\n', dev_data[label_index])
    print('\nLABEL =', dev_labels[label_index])
    print('predicted class =', clf.predict(X_dev_transformed)[label_index],'\n' )
    print(70*'-')
    row_list.append(dict( [('text',dev_data[label_index]), ('label', dev_labels[label_index]), 
                         ('pred_class', clf.predict(X_dev_transformed)[label_index]), ('R', r_array[label_index])]  ))


error_df2 = pd.DataFrame(row_list, columns=cols)
# Out:
# X_dev_transformed.shape: (10164, 18779)
#
# max R: 1.0068274792602476e+39
#
# R: 1.0068274792602476e+39
#
# Dev Title 8003:
#  hospitals, doctors, mris, surgeries and so forth are more extensively used and far more expensive in this country than they are in many other countries.''	health-care	mitt-romney	former governor	massachusetts	republican	34	32	58	33	19	a fox news sunday interview
# 9874.json	barely-true	obamacare cuts seniors medicare.	health-care,medicare	ed-gillespie	republican strategist	washington, d.c.	republican	2	3	2	2	1	a campaign email.
# 3072.json	mostly-true	the refusal of many federal employees to fly coach costs taxpayers $146 million annually.	government-efficiency,transparency	newsmax	magazine and website	florida	none	0	0	0	1	0	an e-mail solicitation
# 2436.json	mostly-true	florida spends more than $300 million a year just on children repeating pre-k through 3rd grade.	education	alex-sink		florida	democrat	1	2	2	4	0	figures cites on campaign website
# 9721.json	true	milwaukee county sheriff david a. clarke jr. advised citizens to point that barrel center mass and pull the trigger because 911 is not our best option.	crime,criminal-justice,guns,legal-issues	greater-wisconsin-political-fund		wisconsin	none	3	3	3	1	1	a campaign tv ad
# 3627.json	false	almost 37 percent of the total income from planned parenthood is from abortions.	abortion	ronald-renuart	state representative	florida	republican	0	1	0	0	0	comments during a committee hearing
# 11900.json	half-true	the united states has the highest rate of childhood poverty of almost any major country on earth.	children,poverty	bernie-s	u.s. senator	vermont	independent	18	12	22	41	0	comments during the pbs democratic debate
# 4611.json	true	under governor almond the ri dmv had a program that allowed undocumented [people to] use their personal tax identification number . . . to apply [for] and receive a ri drivers license.	civil-rights,homeland-security,immigration,public-safety,transportation,workers	david-quiroa	prresident, guatemalan-american alliance of rhode island	rhode island	newsmaker	0	0	0	0	0	a news release
# 3168.json	pants-fire	illegal aliens cost the state of rhode island $400 million a year.	census,crime,education,health-care,immigration,state-budget,taxes	terry-gorman	president, rhode islanders for immigration law enforcement	rhode island	newsmaker	1	0	0	0	1	a radio interview
# 6832.json	pants-fire	says eric cantor voted to assure congress would be paid if the government shut down and against guaranteeing troops would be paid.	congressional-rules,federal-budget,military	wayne-powell	lawyer	virginia	democrat	1	1	0	0	1	a debate.
# 5893.json	mostly-true	if congress froze the current spending level and then cut it by 2 percent annually, we could balance the budget in five years.	deficit,federal-budget	jamie-radtke		virginia	republican	1	1	1	2	0	a statement
# 3304.json	true	every (wisconsin) legislator that votes for this bill will have to give up the same amount of pay as other state employees.	labor,state-budget	jeff-fitzgerald	incoming speaker of state assembly	wisconsin	republican	2	0	1	2	2	an interview on the fox news channel
# 1638.json	half-true	marco rubio controlled funds that out of the $600,000 that were raised, only $4,000 went to candidates to try to improve their chances to be elected to office."
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 4.538944030873061e+31
#
# Dev Title 4733:
#  georgia has the most restrictive ballot access laws in the country.	elections	mary-n			independent	0	0	0	0	0	a television interview
# 3666.json	false	on whether the federal debt limit should be raised	federal-budget	barack-obama	president	illinois	democrat	70	71	160	163	9	an interview with george stephanopoulos
# 4608.json	half-true	when george w. bush was governor of texas, the percentage uninsured went down. under his successor, rick perry, its gone up.	children,health-care,new-hampshire-2012	mitt-romney	former governor	massachusetts	republican	34	32	58	33	19	a republicam debate in hanover, n.h.
# 11023.json	false	says his book,the art of the deal,is the no. 1 selling business book of all time.	candidates-biography,job-accomplishments	donald-trump	president-elect	new york	republican	63	114	51	37	61	remarks on cnn.
# 2096.json	half-true	democrats in the 1930s wanted president franklin roosevelt to be more conservative.	history,pundits,abc-news-week	george-will	columnist	maryland	columnist	7	6	3	5	1	a roundtable discussion on abc's this week
# 12853.json	true	says danny tarkanian wants to defund planned parenthood and would outlaw a womans right to choose, even in cases of rape or incest.	abortion	jacky-rosen		nevada	democrat	0	0	0	0	0	a press release.
# 12670.json	pants-fire	condemning violence against the police and urging support for the police is markedly absent from president barack obamas public remarks.	criminal-justice	william-johnson			organization	0	0	0	0	1	an interview on fox news
# 1508.json	half-true	florida leads the nation in elected officials charged with crimes."
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.774790498281866e+27
#
# Dev Title 2348:
#  let's pay attention to kids who are not going to college, which ends up being about 60 percent of the kids... and get them trained for the jobs that are there. because, you know, there are auto mechanic jobs paying $50,000, $60,000 that they can't get filled. there are airline mechanic jobs paying a lot of money that can't get filled. remarks at afscme forum 6/19/2007
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 9.824991956116368e+22
#
# Dev Title 6241:
#  fifty-six percent decline in overall crime. a 73 percent decline in motor-vehicle theft. a 67 percent decline in robbery. a 66 percent decline in murder. this is way beyond what happened in the nation during this period of time.	crime	rudy-giuliani	attorney	new york	republican	9	11	10	7	3	new york, n.y.
# 5122.json	mostly-true	in 1958, there were 16 states in this country that prohibited -- prohibited -- an african-american and a caucasian from being married.	civil-rights,gays-and-lesbians,marriage	sheila-oliver	assemblywoman	new jersey	democrat	0	1	1	3	0	a news conference
# 11191.json	true	says donald trump has changed his mind on abortion.	abortion	carly-fiorina		california	republican	5	5	4	3	2	the first republican presidential debate
# 10315.json	mostly-true	it has been many years, if ever, since an inmate has completed his or her high school diploma while incarcerated in a state correctional facility for adults.	corrections-and-updates,criminal-justice,public-safety	lc-buster-evans	assistant commissioner	georgia	none	0	0	0	1	0	in a press release
# 1964.json	mostly-true	says u.s. rep. michael mccaul is the sixth-richest person in congress.	candidates-biography	ted-ankrum	retired	texas	democrat	0	1	0	1	0	a speech
# 624.json	true	mccain is raising campaign cash with one of (jack) abramoff's closest business partners: scandal-plagued conservative activist ralph reed."
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 2.8650316239536745e+22
#
# Dev Title 8995:
#  what difference, at this point, does it make? i am the guy that got under her skin and provoked that infamous response from hillary clinton by asking a pretty simple question, why didnt you just pick up the phone and call the survivors (of the benghazi attack)?
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5.067506588980656e+20
#
# Dev Title 6023:
#  the mayor said 'if you happen to be in this country in an undocumented status . . . then we welcome you here. we want you here. we'll protect you here.'
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 2.5600536631383337e+18
#
# Dev Title 9029:
#  [when i was mayor] providence was one of the five renaissance cities of america, according to usa today in those days. money magazine said it was the fifth best city to live in in america. in addition to that, all cities almanac said in 1994, i believe, that it was the safest city in america.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 6.625451541468741e+16
#
# Dev Title 9722:
#  people want the minimum wage, they want marriage equality, they want womens health care. theres issues that actually that really do matter, social issues that matter to the people of this state. so i know barbara would support those issues, i know the governor hasnt. youve seen the actions hes taken on them.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 2.8277128192559484e+16
#
# Dev Title 8158:
#  these people that we were going to deport for good reason ended up becoming citizens. ended up becoming citizens. and it was 800. and now it turns out it might be 1,800, and they dont even know.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 2.7887400186495052e+16
#
# Dev Title 7396:
#  under president barack obamas jobs bill, you can sue if you are unemployed and dont get the job and think you werent hired because you are unemployed.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 2.1063577098616944e+16
#
# Dev Title 6160:
#  if you ask how many times did ronald reagan attend a fundraiser when he ran for re-election in 1984, the answer is eight times. if you say how many times did barack obama attend a fundraiser in 2012, the answer is 228 times.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.7218515276977866e+16
#
# Dev Title 8473:
#  i'm the first person who really took up the issue of the war. four years ago i said that there was no proof that iraq had weapons of mass destruction, and, actually... did an analysis which disproved the cause for the war.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1.1836579198634586e+16
#
# Dev Title 2922:
#  i'm proud of the fact that i've raised more money from small donors than anybody else, and that we're getting $25, $50, $100 donations, and we've done very well doing it that way.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1932798080094404.8
#
# Dev Title 6554:
#  tommy thompson created the first school choice program in the nation, giving thousands of milwaukee students the choice of where they go to school no matter where they live or how much money their parents make.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1679370532110182.0
#
# Dev Title 5008:
#  says ted strickland in this campaign bragged about his a-plus rating with the nra. ... he has said he has a mixed and spotty record on this issue and that he can be criticized for it. those are his words, not mine. so i dont know where he is on this issue.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1534132005256757.2
#
# Dev Title 450:
#  oregon concealed gun applications include home phone numbers, home address, social security numbers, what kinds of guns you have in the house whether you were dishonorably discharged from the military, what controlled substances you are taking and were you ever accused of -- accused, mind you -- of stalking.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1030170158416744.9
#
# Dev Title 4343:
#  you know we can't just pull out now... the truth of the matter is: if we started today, it would take one year, one year to get 160,000 troops physically out of iraq, logistically.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1016198997533071.9
#
# Dev Title 8117:
#  congressman john lewis, an american hero, made allegations that sarah palin and i were somehow associated with ... the worst chapter in american history. ... and, senator obama, you didn't repudiate those remarks.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 449681655093283.94
#
# Dev Title 8997:
#  i think [a little] less than half of the people in our prisons are in there for less than a year. ... we have people who are check kiters and dont pay child support and we are locking them up in the state pen.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 193043042839915.3
#
# Dev Title 7508:
#  says a youtube video shows thomas dimassimo, the man who rushed trump at an ohio rally, dragging the american flag on the ground like it was a piece of garbage.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 96385949479223.78
#
# Dev Title 1402:
#  i've seen (life) from the factory floor when i was working the graveyard shift ...and i'd be ankle-deep in water at the murray ohio bicycle plant where i was running a machine that was so loud i couldn't hear myself yell if i wanted to.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 80390665957780.55
#
# Dev Title 1519:
#  do you know that, statistically, when you take the sat a second time, one third of the people that take the sat, even if theyve been studying, will get a lower score than they did the first time around?
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 63409831381333.01
#
# Dev Title 7090:
#  if you already have health insurance through your job, or medicare, or medicaid, or the va, nothing in this plan will require you or your employer to change the coverage or the doctor you have.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 48782059892703.49
#
# Dev Title 5174:
#  22 times barack obama said he did not have the authority to implement this type of anti-deportation measure. and then the day after he signed this into law, he said, quote, i just changed the law.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 17148998015352.19
#
# Dev Title 8092:
#  just this week we received the news that for the first time social security is now paying out more in benefits than it's taking in. that was something that was supposed to happen in 2016.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 13195118318592.984
#
# Dev Title 8225:
#  parents and teachers are already worrying about what they call the trump effect. they report that bullying and harassment are on the rise in our schools, especially targeting students of color, muslimsand immigrants.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 12569103483318.613
#
# Dev Title 4315:
#  in 1947, when i was born, there were about 450,000 lions. in the mid-70s, when my kids were born, there were about 100,000. today, there are less than 30,000.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 11952931214501.559
#
# Dev Title 8029:
#  go look on the west point website and youll see those specific words, full scholarship to west point. so even though it is, you know, given as a grant for anybody who gets in, those words are used.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5283589493210.798
#
# Dev Title 2394:
#  in almost every other country in the world, artists and musicians are paid when their music is played on the radio. in fact, the only countries besides the u.s. who do not have a radio-performance right are china, iran and north korea.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 3556457479878.446
#
# Dev Title 8007:
#  with her solution, terrorists can still today and by the way isis knows it, they have been advertising it buy guns online and at gun shows in the united states of america.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 3364035185874.06
#
# Dev Title 56:
#  the first time he ever voted as a democrat was here in florida in 2008. he only voted four times in his life, and he's asking floridians to come out and vote for him.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 2673457014432.879
#
# Dev Title 6362:
#  weve outdrawn the super bowl for a little while now in the arenas and stadiums that weve followed them in for the super bowl. weve gone in after [the nfl] and surpassed their ticket sales.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 2402143847852.2944
#
# Dev Title 3628:
#  likens obamas predicament to 1982, saying, when reagan just started out, (unemployment was at) exactly the same point. he was two years into his term. the unemployment was well over 10 percent, and it did come out of it.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1381139272427.7778
#
# Dev Title 7475:
#  (deborah) ross defends those who want to burn the american flag, and even called efforts to ban flag-burning ridiculous, yet refused to help a disabled veteran fly the flag.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1152286933898.4456
#
# Dev Title 4708:
#  when we passed (the stand your ground law), we said it portends horrific events when peoples lives were put into these situations.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 996640276431.7708
#
# Dev Title 3284:
#  the iranians are now saying that what were saying the deal is and what they understand it to be are two different things.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 771393772384.4912
#
# Dev Title 873:
#  women have come through the recession worse off than men the numbers bear that out. we went from a 7 percent unemployment rate for women when he (president barack obama) was elected to an 8.1 percent now.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 563081635769.678
#
# Dev Title 2666:
#  house speaker nancy pelosi said this week that the democrats have to pass their terrible health care bill so that the american people can actually find out what's in it.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 539582286639.05774
#
# Dev Title 4828:
#  if you are a federally licensed gun dealer and your license is revoked because youve engaged in misconduct ... your entire inventory under prevailing law is deemed your personal collection. you then can sell it free from any background checks.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 292209555888.1614
#
# Dev Title 781:
#  the oddest thing is he doesn't want to do for america what he did for massachusetts. he did mandate health care for massachusetts, which is hillarycare, and he doesn't want to do that for america.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 273514369793.5988
#
# Dev Title 6790:
#  under barack obama's health care proposal, "if you've got a health care plan that you like, you can keep it."
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 201901997450.6916
#
# Dev Title 2647:
#  democrats have said that "even one hearing (on the stimulus bill) would be one too many, and that we have a single day to approve these five complex propositions that will affect the lives of millions."
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 198803787974.62555
#
# Dev Title 6510:
#  when we look at the number of murders in the united states (in) 2009, we had 9,500 people murdered. when we look around the world, we see ... large countries, the u.k., germany, japan had 200 or less killed in a year.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 191540885630.29904
#
# Dev Title 9417:
#  in florida, the number of voters who now register as other has grown by a million in the last 10 years. compare that with the democrats, who only grew by 300,000 and the republicans who grew by just 200,000.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 158878411107.29004
#
# Dev Title 267:
#  the people who want president barack obama impeached are all white, theyre all older, and guess what, theyre in the far right wing of the republican party.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 127939406021.09818
#
# Dev Title 4158:
#  it used to be the policy of the republican party to get rid of the department of education. we finally get in charge and a chance to do something, so we double the size of the department of education.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 121608349923.2681
#
# Dev Title 8924:
#  the fact of the matter is that my colleague from new york, senator clinton, there are 50 percent of the american public that say they're not going to vote for her.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 114544910422.10178
#
# Dev Title 5815:
#  again today (ahmadinejad) made light of 9/11, and said that he's not even sure it happened and that people actually died.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 92901757571.46664
#
# Dev Title 6623:
#  opponent holly benson said that just because youre poor doesnt mean youre unhealthy, it just means you have a lot more time to go running.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 73549437916.98701
#
# Dev Title 4024:
#  anywhere in the world, when someone uses a mobile phone, e-mail, the internet or gps, they are enjoying the benefits of the american miracle.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 67452017786.65966
#
# Dev Title 9656:
#  barack obama said "people making less than $250,000 would benefit from his plan" then said "if you're a family making less than $200,000, you'll benefit."
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 61167566805.0193
#
# Dev Title 2575:
#  the top man at yale law school came out ... with just a raging report about former hp ceo carly fiorina,saying she isone of the worst executives in his memory in history running the company.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 56122748312.59729
#
# Dev Title 341:
#  the lawyer who brought the case against nationsbank said publicly that alex sink had nothing to do with the case, had nothing to do with the situation and didnt know about the problems.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 51892361747.93569
#
# Dev Title 4218:
#  understand, this is unemployment insurance. its not welfare, as a lot of my republican colleagues like to suggest it is. you pay into it when youre working. you get help when youre not.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 50782053464.52398
#
# Dev Title 1168:
#  you cant give a child an aspirin in school without permission. you cant do any kind of medication, but we can secretly take the child off and have an abortion.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 50152805414.79013
#
# Dev Title 4010:
#  before this day is out, 18 more veterans will have taken their own lives. that is the daily average, it is intolerable, and it has to stop.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 48845800342.90944
#
# Dev Title 10066:
#  if you look at latino kids between 17 and 20 who graduated high school, 36 percent of them are unemployed or underemployed. african-american kids are unemployed or underemployed to the tune of 51 percent.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 41355935113.419846
#
# Dev Title 4780:
#  if you are going to kill the families of terrorists, realize that theres something called the geneva convention were going to have to pull out of.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 38160597624.08263
#
# Dev Title 8000:
#  says alex jones said that the victims of the sandy hook massacre were child actors and no one was actually killed there.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 37161103517.289085
#
# Dev Title 6797:
#  says hillary clinton tripled the number of people with aids whose lives are being saved .. and it did not cost you any more money.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 35840886716.051575
#
# Dev Title 3365:
#  to give the proposed economic stimulus plan some perspective, "if you started the day jesus christ was born and spent $1 million every day since then, you still wouldnt have spent $1 trillion."
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 31652652232.184772
#
# Dev Title 375:
#  if you rent a u-haul to move your company, it costs twice as much to go from san francisco to austin than the other way around, because you cant find enough trucks to flee the golden state.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 29884985386.196693
#
# Dev Title 187:
#  even members of the nra, when they were polled recently, were under the impression that everyone has a criminal background check.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 26728790111.093506
#
# Dev Title 2090:
#  the dream act was written by members of both parties. when it came up for a vote a year and a half ago, republicans in congress blocked it. the bill hadnt changed. ... the only thing that had changed was politics.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 25879355212.33303
#
# Dev Title 1438:
#  $50,000. thats what every child owes today because washington politicians have run up a huge spending tab and left our kids the bill.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 25035119109.156372
#
# Dev Title 3562:
#  a small majority of americans dont think they like the affordable care act, but a large majority of americans dont want to do away with the protections that are in the affordable care act.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 24714793682.116577
#
# Dev Title 8089:
#  just about everyone everywhere is spending more hours on the job, less time with their families, bringing home smaller and smaller paychecks, while theyre paying more and more at the gas pump and the grocery stores.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 23964946992.1742
#
# Dev Title 6547:
#  the words subhuman mongrel, which ted nugent called president barack obama, were used by the nazis to justify the genocide of the jewish community.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 19537635606.428047
#
# Dev Title 3108:
#  the president has added close to 68,000 troops in the last year, since he came into office, not just the 30,000 you hear, but the others that were added before that.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 18016006400.996063
#
# Dev Title 8881:
#  the so-called defense minister of the peoples republic of donetsk ... actually posted a bragging social media posting of having shot down a military transport. and then when it became apparent it was civilian, they pulled it down from social media.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 17282542098.586575
#
# Dev Title 8760:
#  tells president barack obama that he also asked former president george w. bush about how he felt about americans hating him.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 16554759801.51636
#
# Dev Title 5103:
#  what happens is people like warren buffett and he says this himself...pay 15 percent on the millions of dollars that they earn from wealth income... while their secretary is paying a higher rate on her work income. it's not right.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 15945306853.720758
#
# Dev Title 3055:
#  my property taxes went down largely because my technical college portion went down 35.5% because of the money we put in at state.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 14605901728.410236
#
# Dev Title 9352:
#  in the mid 1990s, in our state, (florida was) no. 1 in violent crime in america. ... the only concern i had was for the citizens of florida, who were subjected to a violent crime every three minutes and 45 seconds.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 13916525155.325489
#
# Dev Title 1338:
#  some criminals have learned how to spy on americans, hacking into our home computers and looking out through the video camera attached to the screen.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 13866803035.132212
#
# Dev Title 9743:
#  boston is just 60 minutes away and its offering subsidies to developers who can charge higher rent than you can get in providence while construction costs are more or less equal. as a result, the boston skyline is completely dominated by the cranes.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 11985592567.26458
#
# Dev Title 1375:
#  washing your hands and covering your mouth when you cough makes a huge difference in reducing transmission of the flu.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 11128981418.31366
#
# Dev Title 5528:
#  we could save all the oil that they're talking about getting off drilling, if everybody was just inflating their tires and getting regular tune-ups.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 10957858898.247095
#
# Dev Title 2736:
#  says a baby in coos county is two times as likely to be born to a mother who is someone who used tobacco during her pregnancy as is the average baby born in oregon or the u.s.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 10344978191.06567
#
# Dev Title 9175:
#  there was a recent report out that the premiums for medicare and the payroll withholdings are only paying about half the program. so it is not financially solvent.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 10035217744.428871
#
# Dev Title 4981:
#  fox news uses photo of a married couple promoting traditional marriage and the photo is actually of a same-sex couple.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 9952077136.004362
#
# Dev Title 7605:
#  wild bill hickok had his first duel in the town square here. and the family legend is that he is a distant cousin of mine.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 9935288342.929298
#
# Dev Title 2706:
#  this year, newt gingrich has raised as much money as mitt romney, tim pawlenty, sarah palin, and mike huckabee combined.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 7445020863.659343
#
# Dev Title 3502:
#  the average student in florida, what they actually pay out of pocket at our major universities for tuition is as much or less than what they spend on cellphones.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 7083778581.132841
#
# Dev Title 7026:
#  a gay man who survived #orlando hate crime can still show up to work in fl tomorrow and have his boss fire him simply because he is gay.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 6245166121.070981
#
# Dev Title 7724:
#  if you are born poor in america, we rank ninth or tenth in our citizens ability to climb up through that ladder and get themselves into the middle class.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5846657635.885588
#
# Dev Title 4352:
#  we've got some 37-million of our fellow citizens who are living in poverty; about 12-million or 13-million are children.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5698660391.8190975
#
# Dev Title 8520:
#  since john f. kennedy was assassinated in 1963, more americans have died by gunfire within our own country than american servicemen and women who were killed in all our wars.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5301035047.349009
#
# Dev Title 5940:
#  says the u.s. attorneys office said that neither i nor my campaign had any idea what was going on regarding my fathers illegal campaign contributions. and thats why they closed this case.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 5214717564.921735
#
# Dev Title 9202:
#  i have something in common with my husband. he never carried caucuses either. he lost all of the ones that i've lost.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 4928936777.076158
#
# Dev Title 4034:
#  the great lakes compact has a loophole. and the loophole is that while you cannot remove the water in a big transport, you can remove it in containers of 5.7 gallons or less.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 4890125973.343351
#
# Dev Title 10021:
#  it has been the law since the beginning of the country that the children of american citizens born ... abroad are american citizens by birth.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 4632225116.056317
#
# Dev Title 6058:
#  says donald trump was one of the people who rooted for the housing crisis. he said back in 2006, gee, i hope it does collapse because then i can go in and buy some and make some money.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 4614360057.180036
#
# Dev Title 3419:
#  amajority of the men and women on this stage have previously and publicly embraced amnesty. i am the only candidate on this stage who has never supportedamnesty.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 3672516104.4614344
#
# Dev Title 1306:
#  oregon schools receive millions of dollars per year in federal school lunch assistance and yet they are required to spend that money almost anywhere but oregon.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 3582660652.72882
#
# Dev Title 7624:
#  the president promised to close the space gap, but he now seems intent on repeating the events that created the space gap in the first place -- putting in place a new rocket design and then trying to underfund the effort...
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 3484559600.3223386
#
# Dev Title 9061:
#  during the bush administration, you actually had a prominent liberal write a book about how bush was preparing for a fascist takeover of this country.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 3148196742.2602096
#
# Dev Title 8265:
#  the marijuana that kids are smoking today is not the same as the marijuana that jeb bush smoked 40 years ago.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 3077476665.457691
#
# Dev Title 5126:
#  i took on the worst road system in the country, according to trucker's magazine. when i left, they said it was the most improved road system in the country.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 3041962742.115956
#
# Dev Title 7483:
#  wisconsin is called the badger state because our ancestors came here with the hopes of living the american dream by mining.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 2846131101.0922775
#
# Dev Title 6397:
#  at the time that (medicare part d) was passed (it) was actually less popular than the affordable care act, according to the polls.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 2783974973.927851
#
# Dev Title 6517:
#  classified material has a header which says top-secret, secret, confidential. nothing, and i will repeat this and this is verified in the report by the department of justice, none of the emails sent or received by me had such a header.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 2499358617.0495577
#
# Dev Title 2322:
#  75 percent of the jobs created in the state of ohio are created in small business. they are not created by huge corporations and those who are very wealthy.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 2325866066.401942
#
# Dev Title 2382:
#  why are muslim armies so useless against isis? ... there are 20,000 or 30,000 (isis fighters). the countries surrounding isis have armies totaling 5 million people.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 2222072986.726406
#
# Dev Title 3075:
#  if someone is in a room that has measles and leaves and you walk in two hours later, you could get measles from that person.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 2147400941.3346393
#
# Dev Title 9436:
#  women in oregon are paid 79 cents for every dollar paid to men. if the wage gap was eliminated, a working woman in oregon would have enough money for 2,877 gallons of gas, 72 more weeks of food for her family or nearly 12 more months of rent.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 2019323189.4162507
#
# Dev Title 2363:
#  harry reid was against (the nuclear option) before he was for it. mitch mcconnell was for it before he was against it. president obama was against it before he was for it.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1995086691.8266997
#
# Dev Title 3791:
#  while (barack) obama preaches we are our brothers keeper, his brother and aunt live in real poverty in kenya.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1879356527.1413298
#
# Dev Title 3033:
#  why is january 8th an important date in american history? this day in 1835 is the only day in our history when we have not been in debt.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1878574315.8256493
#
# Dev Title 237:
#  the clinton foundation is a charity where president and secretary clinton and their daughter, they take no salary, they get no money from it, they take no personal benefit from it.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1658722617.5362096
#
# Dev Title 1034:
#  when we've got ceos making more in 10 minutes than ordinary workers are making in a year ... then something is wrong.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1594777086.0120811
#
# Dev Title 6430:
#  when a gallup poll asked about presidential candidate characteristics, when they get to the question on, would you vote for a socialist, it is even less popular than voting for atheists.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1495405044.4570382
#
# Dev Title 4798:
#  in 1981, matagorda, brazoria, and galveston counties all opted out of the social security program for their employees. today, their program is very, very well-funded and there is no question about whether its going to be funded in years to come.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1325598575.2077694
#
# Dev Title 2279:
#  more than 12,500 service men and women have been discharged on the basis of sexual orientation since the don't ask, don't tell" policy was implemented, at a cost of over $360 million. many of those forced out had special skills in high demand, such as translators, engineers, and pilots."
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1271081406.544071
#
# Dev Title 5770:
#  says bernie sanders was there when it came to (same-sex) marriage 20 years ago. ... he was there when it wasnt popular.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 1079941195.8724742
#
# Dev Title 3635:
#  says president barack obama came into office very concerned about wiretappings but then he became president of the united states, he got all the briefings (and) he decided the balance is probably pretty appropriately struck.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 995934446.299145
#
# Dev Title 675:
#  i have repeatedly said that many of the predatory loans that were made in the mortgage system did target african-american and latino communities.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 975473011.2736928
#
# Dev Title 10098:
#  the federal debt is more than $14 trillion, almost equal to the size of our entire economy, and every child born today inherits a $45,000 share of the national debt before they take their first breath.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 965087478.8593496
#
# Dev Title 6735:
#  she stood by ground zero workers who sacrificed their health after so many sacrificed their lives and kept standing till this administration took action.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 947272138.1958814
#
# Dev Title 9985:
#  when students leave our high schools and they go to the community college, 70-75 percent of them have to pay to take remedial math.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 938925399.8404682
#
# Dev Title 7821:
#  the president of the united states came in the tuesday before the election in a ward that went 99% for him in the last election and they couldnt even (increase) the vote there.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 910845811.1563847
#
# Dev Title 10034:
#  if you look at the number of illegal immigrants coming into the country, it is net zero. its been that way now for almost two years.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 856650510.915764
#
# Dev Title 7827:
#  by the end of governor rick perry's term, he will have drained texas taxpayers ... of more than $360,000 to pay for the rental mansion he has been living in while the historic governor's mansion is repaired.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 824804413.8352369
#
# Dev Title 2034:
#  florida has 1,200 golf courses. i think 58 million rounds played a year in florida. weve got 44 percent of all travel golf in the country here. 5 million people come here just for golf.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 818308778.7206765
#
# Dev Title 9815:
#  we had a no child left behind a similar piece of legislation in our state a number of years ago, well before the federal law. and it's had a big impact here. it's improved schools.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 773714171.6238719
#
# Dev Title 661:
#  eleven years ago, the city of detroit lifted the residency requirement for police officers and today, 53 percent of officers live outside of the city. if we want the tax base of milwaukee to resemble the tax base of detroit, this is the way to go.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 671761237.3956021
#
# Dev Title 3332:
#  saysthere are actually more people in poverty now than there were when we started the war on poverty.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 652279766.0312594
#
# Dev Title 3143:
#  al-qaida operatives, have said, hey, we want you to use this loophole (for purchasing guns despite being on a watch list) to attack and kill americans.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 643816316.8559713
#
# Dev Title 5213:
#  the typical white male worker in this country is making in real terms what he was making in 1973 and the average worker is making what they were making in 1996.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 642594360.3074553
#
# Dev Title 1247:
#  this is the most generous country in the world when it comes to immigration. there are a million people a year who legally immigrate to the united states.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 638285146.8798432
#
# Dev Title 2478:
#  this (schip) is socialized medicine. it is going to go to families that make $60,000 a year. those aren't poor children.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 619440569.7840726
#
# Dev Title 6317:
# ...
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 414.1937528459519
#
# Dev Title 7855:
#  i have always opposed drivers licenses for illegal aliens.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 413.8024556920849
#
# Dev Title 8433:
#  u.s. sen. lindsey graham says south carolina has a labor shortage and wants more immigration.
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 413.1050716054811
#
# Dev Title 1119:
#  texas had the worst voter participation in the country in the november 2014 elections.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 412.30952952033607
#
# Dev Title 898:
#  sixty million americans depend on social security, and one-third of all the seniors in america depend on social security for 90 percent of their income.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 411.7569333263515
#
# Dev Title 9650:
#  goldman sachs was barack obama's "no. 1 private contributor."
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 410.5094727130007
#
# Dev Title 3418:
#  says barack obama is the first president in modern history not to have a single year of 3 percent growth.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 408.8223189120721
#
# Dev Title 276:
#  thirty-four of the last 44 (debt ceiling increases) have been for less than a year. so, this notion that short-term is somehow the exception, its actually the rule.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 408.31569541040557
#
# Dev Title 7006:
#  during the recession, the consumer in his native perversity has begun to save. the savings rate is now 6.2 percent.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 407.3798791301307
#
# Dev Title 7525:
#  says john kitzhabers proposed budget for upcoming biennium represents 8 percent increase over last
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 406.37353191814503
#
# Dev Title 951:
#  despite opposition from national club for growth, club for growth wisconsin has endorsed him for u.s. senate.
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 405.33984972099177
#
# Dev Title 5757:
#  says u.s. is giving seven alaskan islands to russia.
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 405.04870085141744
#
# Dev Title 4097:
#  john mccain's health care plan "won't guarantee coverage of cancer screenings or maternity care."
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 404.01748749506584
#
# Dev Title 8948:
#  according to a recent poll, there are more young republicans enrolled in their parents (health insurance) plans than young democrats.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 402.7736725150013
#
# Dev Title 6631:
#  the deal to raise the nations debt ceiling will directly link a debt ceiling increase to spending cuts for the first time ever.
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 402.2216865766079
#
# Dev Title 8805:
#  the day president obama took office, gasoline was $1.79 a gallon.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 401.89916471457786
#
# Dev Title 391:
#  obamas approval numbers are in the low 40s.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 396.2001239142738
#
# Dev Title 9283:
#  says donald trump mocked someone with a disability.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 396.1878267560475
#
# Dev Title 3343:
#  as a result of climate change, ice fishermen in wisconsin are already noticing fewer days they can be out on our ice covered lakes.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 395.99139530914766
#
# Dev Title 8631:
#  says chris christie inherited the highest taxes in america and the worst unemployment in the region.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 395.70344648571955
#
# Dev Title 3490:
#  says ted cruzswife heidi will be the very first pro-life first lady.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 394.14159492374307
#
# Dev Title 5299:
#  says health and human services secretary kathleen sebelius told insurance companies they couldnt inform their policyholders of what they thought the impact of obamacare would be on them.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 391.89258624133646
#
# Dev Title 8253:
#  bill heller raises taxes. property taxes. small business taxes. he even wants to tax the internet. mr. heller said no to balancing the federal budget, that puts more debt on our kids.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 391.7574948323658
#
# Dev Title 8105:
#  donald trump would engage in a risky scheme to privatize social security.
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 391.3002527950151
#
# Dev Title 3784:
#  sen. mccain's economic plan gives nearly $4-billion in tax breaks to the oil companies but doesn't provide any tax relief to more than 100-million middle-class families.
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 391.2497279012865
#
# Dev Title 9181:
#  says the national labor relations board told boeing that it couldnt build a factory in south carolina because south carolina is a right-to-work state.
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 390.1025537581895
#
# Dev Title 9903:
#  ninety-six percent of the last session, (u.s. rep. henry cuellar) voted with nancy pelosi.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 389.49579506029966
#
# Dev Title 4469:
#  says she oversaw an audit that won the city $2 million in franchise fees.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 389.1056400567302
#
# Dev Title 6237:
#  obama promised to cut the deficit by half by the end of his first term but he hasnt even come close.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 388.6106856984869
#
# Dev Title 8349:
#  says the nike bill is not a tax break ... this does not lower the taxes that nike will pay nor does it prevent the legislature from raising those taxes in the future.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 388.30816275296837
#
# Dev Title 9290:
#  says rick scott oversaw the largest medicare fraud in the nations history.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 388.0449446186699
#
# Dev Title 7381:
#  i spent 18 months putting together the sanctions against iran so that we could force them to the negotiating table.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 387.39351092003324
#
# Dev Title 3267:
#  most of, if not all of, the [dekalb school construction] projects always came in on or were under budget.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 386.79743079933314
#
# Dev Title 5331:
#  after the shootings of dallas policemen, nearly 500 people applied in just 12 days.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 383.9803177371821
#
# Dev Title 1057:
#  because as a senator toomey stood up for wall street. he wanted to privatize social security and invest it in the stock market. wall street would make billions in fees even if the stock market crashed.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 381.4063123656859
#
# Dev Title 5808:
#  many of the top officials at the port authority earn more money than the governors of the states that have jurisdiction over them.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 375.8231173907644
#
# Dev Title 537:
#  every time weve cut the capital gains tax, the economy has grown. whenever we raise the capital gains tax, its been damaged.
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 371.8928231718289
#
# Dev Title 6457:
#  john mccain decided to stand with george bush 95 percent of the time (last year).
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 371.77938835021916
#
# Dev Title 260:
#  the so-called doc fix in the fiscal cliff deal will cut payments for treating illnesses disproportionately impacting minorities, including end stage renal disease and diabetes.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 371.3774889508002
#
# Dev Title 9090:
#  following the 2009 session, texas house speaker joe straus was acknowledged and thanked for his tireless efforts by planned parenthood, the nations premier abortion provider.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 371.37531045692054
#
# Dev Title 533:
#  says texas gained 21,000 doctors due to tort reform.
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 370.7899860751391
#
# Dev Title 1019:
#  says gov. bob mcdonnells budget would cut pre-kindergarten programs.
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 370.3474992236011
#
# Dev Title 6546:
#  it costs $10,000 a year to keep a child in school; it costs $30,000 a year to keep someone in prison.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 370.09248026355624
#
# Dev Title 2364:
#  says david dewhurst explicitly advocated a guest worker program for all illegal immigrants.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 369.507391284934
#
# Dev Title 7050:
#  u.s. senate candidate michelle nunn earned as much as $300,000 running a nonprofit that had laid off 90 workers.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 369.023702748417
#
# Dev Title 3132:
#  the tax-cut deal adds more than $800 billion to the deficit over two years -- more than the cost of tarp and more than the cost of the recovery act and about the same as health care reform.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 368.8808782874218
#
# Dev Title 1832:
#  the federal government is spending 25 percent of our entire economy versus 100 years ago we spent only 2 percent.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 368.84024707125553
#
# Dev Title 9611:
#  recent solar energy policies in georgia have resulted in rate hikes and did not result in solar becoming any more economically viable.
#
# LABEL = 0
# predicted class = 1
#
# ----------------------------------------------------------------------
# R: 368.2559554703624
#
# Dev Title 8352:
#  obama skips out on condemning left-wing attacks on gen. petraeus despite casting other 'important votes' earlier and later in the day.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 365.663996157418
#
# Dev Title 8952:
#  in 2011, the average annual compensation for a teacher in the milwaukee public schools system will exceed $100,000.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 365.52549566474005
#
# Dev Title 9308:
#  says donaldtrump proposes tax cuts, too -- $3 trillion for millionaires like himself and $2 trillion for corporations like his.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 364.90569388868676
#
# Dev Title 3129:
#  while the sequester is in effect, the federal government is still funding a study on duck penises.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 364.4326751932759
#
# Dev Title 4406:
#  by the end of 2015, more than 1,300 people will have died on georgia roads. one of out evey four fatalities resulted from drunken driving.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 363.7527816722481
#
# Dev Title 9403:
#  this year, the overwhelming majority of new jobs are part time.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 363.4585578826815
#
# Dev Title 3353:
#  the confederate battle flag in south carolina was first flown at the statehouse in 1961.it was flown as a symbol of massive resistance to racial desegregation.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 361.8644373650315
#
# Dev Title 5564:
#  president reagan did it (raised the debt ceiling) 18 times. george w. bush did it seven times.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 361.6642030394105
#
# Dev Title 6007:
#  since january 2010, new jersey has added 103,000 new private sector jobs. the last two years -- 2011 and 2012 -- have been the best two years of private sector job growth since 1999.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 360.5490397658864
#
# Dev Title 1485:
#  over the last 40 years, this countrys prison population has grown by 500 percent.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 359.8999068511732
#
# Dev Title 1942:
#  a bipartisan background check amendment outlawed any (gun) registry. plain and simple, right there in the text.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 359.6673491039705
#
# Dev Title 8900:
#  women make 77 cents for every dollar a man earns.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 359.5050984561923
#
# Dev Title 5179:
#  the black unemployment rate (has) increased since the recovery has begun.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 358.0081897691799
#
# Dev Title 3541:
#  says richard burr was one of only three senators who voted against a ban on insider trading for members of congress. and he called that vote brave.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------
# R: 355.7817018741613
#
# Dev Title 4558:
#  surveys show that many of our citizens think we devote a full quarter or even a third of our federal budget to foreign aid.
#
# LABEL = 1
# predicted class = 0
#
# ----------------------------------------------------------------------

# %%
print(error_df2.size)
print(len(error_df2))
error_df2.head()
# Out:
# 8000
# 2000
#                                                 text  label  pred_class  \
# 0  hospitals, doctors, mris, surgeries and so for...      1           0
# 1  georgia has the most restrictive ballot access...      1           0
# 2  let's pay attention to kids who are not going ...      1           0
# 3  fifty-six percent decline in overall crime. a ...      1           0
# 4  what difference, at this point, does it make? ...      1           0
#
#               R
# 0  1.006827e+39
# 1  4.538944e+31
# 2  5.774790e+27
# 3  9.824992e+22
# 4  2.865032e+22

# %%
error_df2.to_csv('nb_isot_title_to_liar_errors.csv', sep=',')

# %% [markdown]
# ### REVERSE: Using LIAR model, predict the ISOT "title" and score the predictions. (lower case them first...)

# %%
train_data = liar_data.title[liar_data.binary_target != -1].str.lower().values   # full LIAR data
train_labels = liar_data.binary_target[liar_data.binary_target != -1].values 
 
dev_data = train_set.title.str.lower().values                                      # LSOT data
dev_labels = train_set.target.values 


train_labels = train_labels.astype(int)
dev_labels = dev_labels.astype(int)

#train_data.head()
print('train_data shape:', train_data.shape)
#print(train_data[0].shape)
#print(train_data[:1])
print('train_labels shape:', train_labels.shape)
print(train_labels)

print('\ndev_data shape:', dev_data.shape)
#print(dev_data[:1])
print('dev_labels shape:', dev_labels.shape)
print(dev_labels)
# Out:
# train_data shape: (10164,)
# train_labels shape: (10164,)
# [1 0 0 ... 1 0 0]
#
# dev_data shape: (31428,)
# dev_labels shape: (31428,)
# [1 0 1 ... 0 1 0]

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(train_data)           # original ISOT training data
X_dev_transformed = vectorizer.transform(dev_data)

# MultinomialNB
print('\nMultinomialNB using "title" field: Fit using ISOT data; Predict on LIAR data:')
alpha = 1.0
clf = MultinomialNB(alpha=alpha)
clf.fit(X, train_labels)

print('accuracy: %3.3f' %clf.score(X_dev_transformed, dev_labels))
# Out:
# MultinomialNB using "title" field: Fit using ISOT data; Predict on LIAR data:
# accuracy: 0.566

# %% [markdown]
# ### Split LIAR data into Train/Dev/Test, train model, and evaluate on its own type

# %%
#liar_data.head(5)
liar_data = liar_data[liar_data.binary_target != -1]
liar_data.head(5)
# Out:
#            id      target                                              title  \
# 0   6193.json       false  (Environmentalists) said Were only going to st...
# 1  12371.json        true  For the first time in over 40 years, Republica...
# 2  12409.json        true  You can import as many hemp products into this...
# 3   1770.json        true  We can prevent terror suspects from boarding a...
# 4  10700.json  pants-fire  Says Ted Cruz said, There is no place for gays...
#
#                                              subject            speaker  \
# 0                                 energy,environment         ron-ramsey
# 1                                  elections,history       ed-gillespie
# 2                       drugs,legal-issues,marijuana  william-devereaux
# 3                        civil-rights,guns,terrorism  michael-bloomberg
# 4  candidates-biography,gays-and-lesbians,marriag...     facebook-posts
#
#                  speaker_job_title             state        party  \
# 0  Speaker of the Tennessee Senate         Tennessee   republican
# 1            Republican strategist  Washington, D.C.   republican
# 2                           lawyer      Rhode Island         none
# 3                              NaN          New York  independent
# 4             Social media posting               NaN         none
#
#    barely_true_count  false_count  half_true_count  mostly_true_count  \
# 0                0.0          2.0              0.0                0.0
# 1                2.0          3.0              2.0                2.0
# 2                0.0          0.0              0.0                0.0
# 3                0.0          2.0              2.0                3.0
# 4               14.0         18.0             15.0               11.0
#
#    pantsonfire_count                 context  binary_target
# 0                1.0   rally for coal miners              0
# 1                1.0                a speech              1
# 2                0.0  a legislative hearing               1
# 3                0.0        an op ed article              1
# 4               36.0          an online meme              0

# %%
binary_targets = liar_data.binary_target.unique()
print(binary_targets)

print('\nbinary_target,  number of examples')
for binary_target in binary_targets:
    print(binary_target, len(liar_data[liar_data.binary_target==binary_target]))
# Out:
# [0 1]
#
# binary_target,  number of examples
# 0 5657
# 1 4507

# %%
#train/dev/train split
#train_dev_split = 0.8

train_fract = 0.70
dev_fract = 0.15
test_fract = 0.15

if (train_fract+dev_fract+test_fract) == 1.0:
    print('Split fractions add up to 1.0')
else:
    print('SPLIT FRACTIONS DO NOT ADD UP TO 1.0; PLEASE TRY AGAIN.............')

train_set = liar_data[ :int(len(liar_data)*train_fract)].reset_index(drop=True)
dev_set = liar_data[int(len(liar_data)*(train_fract)) : int(len(liar_data)*(train_fract+dev_fract))].reset_index(drop=True)
test_set = liar_data[int(len(liar_data)*(train_fract+dev_fract)) : ].reset_index(drop=True)

print('training set: ',train_set.shape)
print('dev set: ',dev_set.shape)
print('test set: ',test_set.shape)
# Out:
# Split fractions add up to 1.0
# training set:  (7114, 15)
# dev set:  (1525, 15)
# test set:  (1525, 15)

# %%
# print out LIAR dev set
#dev_set.to_csv('liar_dev_set.csv', sep=',')

# %%
train_data = train_set.title[train_set.binary_target != -1].str.lower().values   # full LIAR data
train_labels = train_set.binary_target[train_set.binary_target != -1].values 
 
dev_data = dev_set.title.str.lower().values                                      # LSOT data
dev_labels = dev_set.binary_target[dev_set.binary_target != -1].values 

print('train_data shape:', train_data.shape)
print('train_labels shape:', train_labels.shape)
print('dev_data shape:', dev_data.shape)
print('dev_labels shape:', dev_labels.shape)
# Out:
# train_data shape: (7114,)
# train_labels shape: (7114,)
# dev_data shape: (1525,)
# dev_labels shape: (1525,)

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(train_data)      
print(X.shape)
X_dev_transformed = vectorizer.transform(dev_data)

# MultinomialNB
print('\nMultinomialNB using LIAR training data; Predict on LIAR dev data:')
alpha = 1.0
clf = MultinomialNB(alpha=alpha)
clf.fit(X, train_labels)

print('accuracy: %3.3f' %clf.score(X_dev_transformed, dev_labels))
# Out:
# (7114, 10384)
#
# MultinomialNB using LIAR training data; Predict on LIAR dev data:
# accuracy: 0.627

# %%
# PRINT LIAR DEV TITLES WITH LABELS AND PREDICTED VALUES

cols = ['LIAR title', 'Label', 'Predicted Class']
row_list = []

for i in range(dev_data.shape[0]):
    #print(dev_data[i], dev_labels[i], clf.predict(X_dev_transformed)[i])
    row_list.append(dict( [('LIAR title', dev_data[i]), ('Label', dev_labels[i]), ('Predicted Class', clf.predict(X_dev_transformed)[i])]  ))

dev_set_df = pd.DataFrame(row_list, columns=cols)

# %%
print(dev_set_df.size)
print(len(dev_set_df))
dev_set_df.head()
# Out:
# 4575
# 1525
#                                           LIAR title  Label  Predicted Class
# 0  we did not even have a federal income tax in t...      1                1
# 1  in texas, there are 668 democratic hispanic el...      1                1
# 2  a test last month at the max station at 162nd ...      1                1
# 3  says president barack obama initially said the...      1                0
# 4  the next state budget will begin with a surplu...      0                0

# %%
#dev_set_df.to_csv('liar_dev_set.csv', sep=',')

# %% [markdown]
# #### ONE OFF: Human Baseline Examples: read in LIAR examples previously scored by humans in the project group.   Add the predicted class to the file.

# %%
liar_human = pd.read_csv('human_liar_examples.csv')
liar_human.head()
# Out:
#                                                title
# 0  A new Colorado law literally allows residents ...
# 1  Sixty percent of New Jersey doctors do not acc...
# 2  Austin is a city that has basically doubled in...
# 3  Says U.S. Rep. Stephen Fincher breaks earmark ...
# 4  Of all cities in the United States with more t...

# %%
X_dev_transformed = vectorizer.transform(liar_human.title)

# %%
cols = ['title', 'pred_class']
row_list = []

for i in range(len(liar_human.title)):  
    print('\nDev Title: ', liar_human.title.iloc[i])
    print('predicted class =', clf.predict(X_dev_transformed)[i],'\n' )
    row_list.append(dict( [('title',liar_human.title.iloc[i]), ('pred_class', clf.predict(X_dev_transformed)[i])]  ))


liar_human_df = pd.DataFrame(row_list, columns=cols)
# Out:
# Dev Title:  A new Colorado law literally allows residents to print ballots from their home computers, then encourages them to turn ballots over to collectors.
# predicted class = 0
#
#
# Dev Title:  Sixty percent of New Jersey doctors do not accept Medicaid patients.
# predicted class = 1
#
#
# Dev Title:  Austin is a city that has basically doubled in size every 25 years or so since it was founded.
# predicted class = 1
#
#
# Dev Title:  Says U.S. Rep. Stephen Fincher breaks earmark pledge.
# predicted class = 0
#
#
# Dev Title:  Of all cities in the United States with more than 100,000 people, Providence is the 183rd safest.
# predicted class = 1
#
#
# Dev Title:  When the salmonella source was finally identified, FDA officials had to wait for industry approval before they could go live with the [peanut] recall.
# predicted class = 1
#
#
# Dev Title:  Mr. President, multiple times from your administration there have come statements that Republicans have no ideas and no solutions on health care.
# predicted class = 0
#
#
# Dev Title:  Prior to 1962, everybody prayed before school started, and the Bible was the principal textbook in all schools.
# predicted class = 0
#
#
# Dev Title:  The IRS is already planning on 19,500 new employees to administer Obamas health care mandate.
# predicted class = 0
#
#
# Dev Title:  Wisconsin is one of several states where you can change your early ballot if you think youve made a mistake.
# predicted class = 1
#
#
# Dev Title:  Passage of a referendum on an aquarium for Clearwater means NO future funding for our neighborhoods.
# predicted class = 1
#
#
# Dev Title:  Weve seen a remarkable reduction in the number of Americans being executed -- its down nearly two-thirds over the past generation.
# predicted class = 1
#
#
# Dev Title:  We are taking Virginias investment in public education to the highest level in the commonwealths history.
# predicted class = 1
#
#
# Dev Title:  Ninety percent of the job growth in Virginia has been in the private sector.
# predicted class = 1
#
#
# Dev Title:  Says Barack Obama promised he would cut the deficit in half but didnt.
# predicted class = 0
#
#
# Dev Title:  David Beckhams soccer stadium would get a special tax deal that lets them off the hook for $2 million in taxes every year for 30 years.
# predicted class = 0
#
#
# Dev Title:  John McCain "is one of the few senators of either party who oppose this bill (to expand education aid for veterans) because he thinks it's too generous."
# predicted class = 0
#
#
# Dev Title:  Americans now spend 100 days out of the year working for government before we even start working for ourselves.
# predicted class = 1
#
#
# Dev Title:  Without representation, (the IRS) can increase taxes.
# predicted class = 0
#
#
# Dev Title:  This rule could prevent children under 18 from using such tools as a power screwdriver, a milking machine or something as simple as a wheelbarrow on the family farm . . .
# predicted class = 0
#
#
# Dev Title:  The Texas Department of Transportation... misplaced a billion dollars.
# predicted class = 1
#
#
# Dev Title:  Says because of Hurricane Sandy in Atlantic City much of that boardwalk no longer exists -- just the pillars where the boardwalk used to be.
# predicted class = 0
#
#
# Dev Title:  Sixteen thousand new Internal Revenue Service agents will be empowered to enforce the new health care legislation.
# predicted class = 0
#
#
# Dev Title:  Canada "does spills into their water to practice in the event that this would happen. That is not allowed in the United States."
# predicted class = 1
#
#
# Dev Title:  The tax policies of George W. Bush created a dynamic effect of high growth.
# predicted class = 1
#
#
# Dev Title:  Rhode Islands unemployment insurance system is the most expensive such system in the country.
# predicted class = 1
#
#
# Dev Title:  Under the compromise tax agreement, 99.7% of American families will not pay 1 nickel in an estate tax.
# predicted class = 1
#
#
# Dev Title:  Austin is burdened by the fastest-growing tax increases of any major city in the nation.
# predicted class = 1
#
#
# Dev Title:  The average Georgia family makes $6,000 less than the average family did 10 years ago when inflation is factored in.
# predicted class = 1
#
#
# Dev Title:  Virginia was named best managed state, best state for business and best state toraise a child while I was governor.
# predicted class = 1
#
#
# Dev Title:  Most of, if not all of, the [DeKalb school construction] projects always came in on or were under budget.
# predicted class = 1
#
#
# Dev Title:  Women earn only 77 cents for every dollar earned by men in the same position.
# predicted class = 1
#
#
# Dev Title:  Under my platform, I will make no changes to the current (Medicare) system for current retirees and anyone approaching retirement.
# predicted class = 0
#
#
# Dev Title:  Over the past five years the federal government has paid out $601 million in retirement and disability benefits to deceased former federal employees.
# predicted class = 0
#
#
# Dev Title:  On the success of Cash for Clunkers
# predicted class = 0
#
#
# Dev Title:  The government -- not the armed forces -- is stockpiling hundreds of millions of rounds of ammunition for domestic use.
# predicted class = 0
#
#
# Dev Title:  At least Obama didn't marry his cousin, as Giuliani did.
# predicted class = 1
#
#
# Dev Title:  Says the Republican Party platform says pull back even more of the rules on campaign finance reform, get rid of McCain-Feingold while the Democratic Party platform says we want to find a way to put more fair rules on campaign finance reform.
# predicted class = 1
#
#
# Dev Title:  Said he won the Democratic primary without one ... negative TV spot.
# predicted class = 1
#
#
# Dev Title:  Outside of recall elections, theres never been a public official removed from office in Wisconsin for anything but malfeasance in office.
# predicted class = 0
#
#
# Dev Title:  For the first time in history, Wisconsin has more government jobs than manufacturing jobs.
# predicted class = 1
#
#
# Dev Title:  If you look worldwide, the number of terrorist incidents have not substantially increased.
# predicted class = 1
#
#
# Dev Title:  Says his tax and fee cuts will save households $540 over two years.
# predicted class = 1
#
#
# Dev Title:  Teddy Roosevelt first called for (health care) reform nearly a century ago.
# predicted class = 0
#
#
# Dev Title:  Social Security took seven years before anybody got the first check.
# predicted class = 0
#
#
# Dev Title:  Then, the Republican leader theatrically introduced new bills with stopgap budget language, declaring that we could stay until midnight and pass this compromise. Except under our constitution, a bill has to be read on 3 different days, so thats not possible.
# predicted class = 0
#
#
# Dev Title:  The chairman of the party of Florida, who is an avid and outward supporter of Marco Rubio, gets to appoint 30 of those delegates.
# predicted class = 0
#
#
# Dev Title:  John wasn't this raging populist four years ago when he ran for president.
# predicted class = 1
#
#
# Dev Title:  Says Sen. Ted Cruz used to be in favor of birthright citizenship but is now against it.
# predicted class = 0
#
#
# Dev Title:  The CNBC debate was supposed to be three hours, and he renegotiated it down to two hours.
# predicted class = 0
#
#
# Dev Title:  An amendment inserted by lawmakers into the state budget exempts scientific researchers from all state animal cruelty laws.
# predicted class = 0
#
#
# Dev Title:  Under David Dewhursts leadership, the Texas Senate passed an expansion of in-state tuition and free health care to illegal immigrants.
# predicted class = 0
#
#
# Dev Title:  If you survey, most (North Carolina) Democrats also agree with our (election) laws and voter ID.
# predicted class = 0
#
#
# Dev Title:  We are coming up on our 40th anniversary of electing a Republican to the United States Senate. 1972 was the last time New Jersey sent a Republican to the United States Senate.
# predicted class = 1
#
#
# Dev Title:  DeKalb County has graduated five police academies and three fire academies to help reach its ambitious hiring goals in both departments.
# predicted class = 1
#
#
# Dev Title:  Women are paid 77 cents for every $1 men get for the same work.
# predicted class = 1
#
#
# Dev Title:  Weve lost 26 million jobs since (Obamas) been president.
# predicted class = 0
#
#
# Dev Title:  Says Texas Republican leaders have proposed laying off thousands of teachers.
# predicted class = 0
#
#
# Dev Title:  Says Bernie Sanders opposes requiring all children to have a K-12 education.
# predicted class = 0
#
#
# Dev Title:  No other Northeastern state has passed a photo ID law
# predicted class = 1
#
#
# Dev Title:  Fifty-three percent of teens in Central Falls are getting pregnant.
# predicted class = 1
#
#
# Dev Title:  Our numbers are going up at the airport.
# predicted class = 0
#
#
# Dev Title:  Im the only candidate for governor whos rolled out any policies so far.
# predicted class = 1
#
#
# Dev Title:  When the Republicans were in charge, they actually expanded government health care with the prescription drug program.
# predicted class = 0
#
#
# Dev Title:  Says half the Americans dont pay any income taxes.
# predicted class = 1
#
#
# Dev Title:  I released the most extensive financial review of anybody in the history of politics. You dont learn much in a tax return.
# predicted class = 0
#
#
# Dev Title:  Says David Jolly refused to cut spending for a national greenhouse in D.C.
# predicted class = 0
#
#
# Dev Title:  Rep. Adam Putnam was silent when Rush Limbaugh called Sonia Sotomayor a racist.
# predicted class = 0
#
#
# Dev Title:  The Bundy Ranch deal is all about Nevada Sen. Harry Reid using federal violence to take peoples land in his state so he can package it to re-sell it to the Chinese.
# predicted class = 0
#
#
# Dev Title:  We have spent $350 million to deal with sea-level rise in the Miami area and hundreds of millions of dollars to deal with coral reefs.
# predicted class = 0
#
#
# Dev Title:  Says President Barack Obama promised he would cut the deficit in half, but instead will at least double it.
# predicted class = 0
#
#
# Dev Title:  Were the seventh highest taxed state in America. And thats not just state, its local as well.
# predicted class = 0
#
#
# Dev Title:  The Senate immigration bill has immediate legalization ... and the border security is sometime in the future, and just like in 1986, its designed never to come into being.
# predicted class = 0
#
#
# Dev Title:  Rick Scott "was forced to resign as the head of a company that pled guilty to massive amounts of systematic fraud, including 14 felonies, leading to a historic $1.7 billion fine."
# predicted class = 1
#
#
# Dev Title:  On the night of the Iowa caucuses, Obama promised the nation that he would do health care reform focused on cost containment, he opposed an individual mandate, and he said he was going to do it with Republicans.
# predicted class = 0
#
#
# Dev Title:  Woodrow Wilson borrowed $30 billion to fund World War I in 1917. That money has not been paid back. And we are still paying interest on it.
# predicted class = 1
#
#
# Dev Title:  Since being elected, (Tom Barrett) has dumped 8.2 billion gallons of raw sewage into Lake Michigan.
# predicted class = 0
#
#
# Dev Title:  Two-thirds of the federal budget is permanent law ... its permanently appropriated.
# predicted class = 1
#
#
# Dev Title:  The city of Charlotte passed a bathroom ordinance mandate on every private-sector employer in Charlotte.
# predicted class = 0
#
#
# Dev Title:  Allowing all Bush income tax cuts to expire on Dec. 31 will amount to the largest tax increase in the history of America.
# predicted class = 0
#
#
# Dev Title:  Charlie Crists personal approval numbers are plummeting.
# predicted class = 0
#
#
# Dev Title:  The state is able to sharply curtail contract bargaining rights for state employee unions.
# predicted class = 1
#
#
# Dev Title:  New Jersey has had seven credit downgrades since Chris Christie became governor.
# predicted class = 1
#
#
# Dev Title:  Says his plan to end the toll on Ga. 400 fulfills his campaign promise to commuters.
# predicted class = 0
#
#
# Dev Title:  Joe Garcia raised utility rates on families.
# predicted class = 1
#
#
# Dev Title:  The labor force participation rate -- the share of the potential workforce that is actually working or looking for work-- currently stands below 63%, the lowest level since the 1970s.
# predicted class = 1
#
#
# Dev Title:  Taxpayer money will provide iPod Touch devices to high school students in Utah, BlackBerry smart phones to smokers who kick the habit and funding for a study of exotic ants in East Africa.
# predicted class = 0
#
#
# Dev Title:  The United States is "seeing greater income inequality now than any time since the 1920s."
# predicted class = 1
#
#
# Dev Title:  We had the biggest drop of the rate of unemployment (in)all but 4 states.
# predicted class = 1
#
#
# Dev Title:  Theres not one Democrat who endorses the Romney-Ryan Medicare plan.
# predicted class = 0
#
#
# Dev Title:  Says Jeb Bush has released 10 percent of his emails.
# predicted class = 1
#
#
# Dev Title:  Says Jon Runyan voted to end programs to aid homeless veterans.
# predicted class = 0
#
#
# Dev Title:  Says Mitt Romneys investments created zero jobs.
# predicted class = 1
#
#
# Dev Title:  In the event of a U.S. strike on Syria, the Russians will replace the weapons immediately. Theyve said it on the record. Theyve suggested they might even replace it with better stuff.
# predicted class = 0
#
#
# Dev Title:  We Really Do Have the Highest Corporate Tax Rate in the World.
# predicted class = 1
#
#
# Dev Title:  Independent groups behind ads attacking Democratic candidates are front groups for foreign-controlled companies.
# predicted class = 0
#
#
# Dev Title:  Greece has a GDP the size of the Dallas-Fort Worth Metroplex.
# predicted class = 1
#
#
# Dev Title:  In Miami-Dade County, we spend at our school system over $20 million every year educating recent immigrants.
# predicted class = 1
#
#
# Dev Title:  One-third of the gasoline is purchased by out-of-state people in Virginia
# predicted class = 1
#
#
# Dev Title:  We have one of the most expensive General Assemblies, per capita, in the entire country.
# predicted class = 1

# %%
liar_human_df.head()
# Out:
#                                                title  pred_class
# 0  A new Colorado law literally allows residents ...           0
# 1  Sixty percent of New Jersey doctors do not acc...           1
# 2  Austin is a city that has basically doubled in...           1
# 3  Says U.S. Rep. Stephen Fincher breaks earmark ...           0
# 4  Of all cities in the United States with more t...           1

# %%
liar_human_df.to_csv('human_liar_examples.csv', sep=',')
